# %% [markdown]
# # Test OpenStreetMap data
# In which we look at Puerto Rico's OSM data, downloaded from [here](http://download.geofabrik.de/north-america/us/puerto-rico.html).

# %%
import fiona
import json
import os

# %% [markdown]
# ## Load data

# %%
test_file = '../../data/geo_files/PR_OSM/shp_files/gis.osm_places_a_free_1.shp'
c = fiona.open(test_file, 'r')
print(c)
# Out:
# <open Collection '../../data/geo_files/PR_OSM/shp_files/gis.osm_places_a_free_1.shp:gis.osm_places_a_free_1', mode 'r' at 0x7f92fc136850>

# %%
c_list = list(c)

# %%
print(json.dumps(c_list[0], indent=2, sort_keys=True))
# Out:
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -65.3848792,
#           18.1089953
#         ],
#         [
#           -65.3847676,
#           18.1095664
#         ],
#         [
#           -65.3845959,
#           18.1098356
#         ],
#         [
#           -65.3843985,
#           18.1098764
#         ],
#         [
#           -65.3841239,
#           18.1092646
#         ],
#         [
#           -65.3837634,
#           18.108669
#         ],
#         [
#           -65.3833514,
#           18.1076901
#         ],
#         [
#           -65.3831626,
#           18.107119
#         ],
#         [
#           -65.3828536,
#           18.1064501
#         ],
#         [
#           -65.3825617,
#           18.1060014
#         ],
#         [
#           -65.3827334,
#           18.1060014
#         ],
#         [
#           -65.3830081,
#           18.1061401
#         ],
#         [
#           -65.3833514,
#           18.1059769
#         ],
#         [
#           -65.3836775,
#           18.1057566
#         ],
#         [
#           -65.3841668,
#           18.1058137
#         ],
#         [
#           -65.3842269,
#           18.1060422
#         ],
#         [
#           -65.3843384,
#           18.1062053
#         ],
#         [
#           -65.3842955,
#           18.1065316
#         ],
#         [
#           -65.3841239,
#           18.1067764
#         ],
#         [
#           -65.384038,
#           18.1072659
#         ],
#         [
#           -65.3841668,
#           18.1076574
#         ],
#         [
#           -65.3844844,
#           18.108098
#         ],
#         [
#           -65.3848105,
#           18.1081224
#         ],
#         [
#           -65.3847418,
#           18.1083672
#         ],
#         [
#           -65.3848534,
#           18.1085875
#         ],
#         [
#           -65.3848792,
#           18.1089953
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "0",
#   "properties": {
#     "code": 1020,
#     "fclass": "island",
#     "name": "Isla Chiva",
#     "osm_id": "28332664",
#     "population": 0
#   },
#   "type": "Feature"
# }

# %%
print('\n'.join(map(lambda x: json.dumps(x['properties'], indent=2, sort_keys=True), c_list)))
# Out:
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla Chiva",
#   "osm_id": "28332664",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "28332672",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Rat\u00f3n",
#   "osm_id": "44026832",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayos Geniqu\u00ed",
#   "osm_id": "44026835",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Pelaita",
#   "osm_id": "44026838",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Lobo",
#   "osm_id": "44026839",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Los Gemelos",
#   "osm_id": "44026842",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Botella",
#   "osm_id": "44026845",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayos Geniqu\u00ed",
#   "osm_id": "44026847",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Culebra National Wildlife Refuge",
#   "osm_id": "44026849",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Norte",
#   "osm_id": "44026854",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Yerba",
#   "osm_id": "44026858",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Luis Pe\u00f1a",
#   "osm_id": "44026861",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Sombrerito",
#   "osm_id": "44026867",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Matojo",
#   "osm_id": "44026869",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Culebra National Wildlife Refuge",
#   "osm_id": "44026870",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Culebra National Wildlife Refuge",
#   "osm_id": "44026871",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Alcarraza",
#   "osm_id": "44026873",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Pel\u00e1",
#   "osm_id": "44026874",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Lobito",
#   "osm_id": "44026875",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla Culebrita",
#   "osm_id": "44026878",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Culebra National Wildlife Refuge",
#   "osm_id": "44026881",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44026892",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Pirata",
#   "osm_id": "44026900",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Culebra National Wildlife Refuge",
#   "osm_id": "44026904",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo del Agua",
#   "osm_id": "44026908",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032343",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032344",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Diablo",
#   "osm_id": "44032345",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032347",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032349",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Ratones",
#   "osm_id": "44032353",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032354",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032355",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032356",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032358",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032359",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032360",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032361",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032364",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032365",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032366",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032367",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032369",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla Palominitos",
#   "osm_id": "44032370",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Los Farallones",
#   "osm_id": "44032371",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Icacos",
#   "osm_id": "44032372",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032377",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032378",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032379",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032380",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032381",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032382",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032384",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032385",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032386",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032387",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032388",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032389",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032390",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032391",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032393",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032394",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032395",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032397",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032398",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032399",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032400",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032401",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032402",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032403",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032404",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032405",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032406",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032407",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032408",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032411",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032414",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032415",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032416",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032417",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032418",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032421",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Lobos",
#   "osm_id": "44032422",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032426",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032427",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032429",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032430",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032431",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032432",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032434",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032435",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032436",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032438",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032439",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032440",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032441",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032442",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032443",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "La Blanquilla",
#   "osm_id": "44032444",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032446",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032447",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Arrecifes de La Cordillera",
#   "osm_id": "44032448",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla de Ramos",
#   "osm_id": "44082201",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Cabritas",
#   "osm_id": "44082526",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Santiago",
#   "osm_id": "44082654",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Punta Petrona",
#   "osm_id": "44082657",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Mata",
#   "osm_id": "44082741",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Pi\u00f1erito",
#   "osm_id": "44082823",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de Investigaci\u00f3n Estuarina Bah\u00eda de Jobos",
#   "osm_id": "44083277",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Morrillo",
#   "osm_id": "44083317",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "44106366",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "44106395",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla Morrillito",
#   "osm_id": "44106451",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Don Luis",
#   "osm_id": "44106458",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "44106523",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Mar\u00eda Langa",
#   "osm_id": "44106528",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "44106535",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "44106536",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "44106559",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "44106573",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Palomas",
#   "osm_id": "44106615",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "44106649",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "44106651",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "44106653",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "44106657",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Tres Hermanas",
#   "osm_id": "44106722",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Caribe",
#   "osm_id": "44106723",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "44106732",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla Caja de Muertos",
#   "osm_id": "44106736",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "44106774",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla Guilligan",
#   "osm_id": "44106804",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Parguera",
#   "osm_id": "44106818",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Collado",
#   "osm_id": "44106820",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "44106921",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Berber\u00eda",
#   "osm_id": "44106925",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "44106932",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla Ballena",
#   "osm_id": "44107061",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "44107098",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Caracoles",
#   "osm_id": "272128421",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128422",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128423",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128424",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128425",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128426",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128427",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128428",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128429",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128431",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Mata Seca",
#   "osm_id": "272128434",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128436",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128437",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128438",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128440",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128441",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128442",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128443",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128445",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128446",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128448",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128449",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128450",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128452",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128453",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272128454",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Gu\u00e1nica",
#   "osm_id": "272128455",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128456",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128457",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272128458",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128459",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272128460",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128461",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128462",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272128463",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128464",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128465",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128466",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128467",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128468",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128469",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128470",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128471",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128472",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128473",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128474",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128475",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128476",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128477",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272128478",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128479",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128480",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128481",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128482",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128483",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272128484",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Terremoto",
#   "osm_id": "272129176",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272160500",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272160501",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Bayo",
#   "osm_id": "272966761",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Vieques",
#   "osm_id": "272966762",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla Guayac\u00e1n",
#   "osm_id": "272966763",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272966764",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272966765",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966766",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272966767",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966768",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966769",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966770",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272966771",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966772",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272966773",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966774",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966775",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272966776",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966777",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966778",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272966779",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966780",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272966781",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272966782",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966783",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272966784",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272966785",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272966786",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Boquer\u00f3n",
#   "osm_id": "272966787",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272966788",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "272966789",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "",
#   "osm_id": "272966790",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Cayo Corral",
#   "osm_id": "273193848",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "273194212",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural de La Parguera",
#   "osm_id": "273194213",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Punta Petrona",
#   "osm_id": "273197980",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Punta Petrona",
#   "osm_id": "273197981",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Reserva Natural Punta Petrona",
#   "osm_id": "273197982",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Bosque Estatal de Aguirre",
#   "osm_id": "273389825",
#   "population": 0
# }
# {
#   "code": 1050,
#   "fclass": "locality",
#   "name": "Bermuda Triangle",
#   "osm_id": "321693450",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isle Verde Island",
#   "osm_id": "335937816",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla Guachinanga",
#   "osm_id": "44082455",
#   "population": 0
# }
# {
#   "code": 1010,
#   "fclass": "suburb",
#   "name": "Encantada",
#   "osm_id": "6336386",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla de Culebra",
#   "osm_id": "2747855",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla de Cardona",
#   "osm_id": "432821272",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla de Mona",
#   "osm_id": "456564743",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isleta de San Juan",
#   "osm_id": "7117065",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla Palominos",
#   "osm_id": "44032433",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Isla de Vieques",
#   "osm_id": "253642",
#   "population": 0
# }
# {
#   "code": 1020,
#   "fclass": "island",
#   "name": "Puerto Rico",
#   "osm_id": "7117066",
#   "population": 0
# }

# %% [markdown]
# Cool! Looks like I found the "island and marine area" file.

# %% [markdown]
# What are all shape files?

# %%
all_shape_files = sorted(os.listdir('../../data/geo_files/PR_OSM/shp_files/'))
print('\n'.join(all_shape_files))
# Out:
# gis.osm_buildings_a_free_1.cpg
# gis.osm_buildings_a_free_1.dbf
# gis.osm_buildings_a_free_1.prj
# gis.osm_buildings_a_free_1.shp
# gis.osm_buildings_a_free_1.shx
# gis.osm_landuse_a_free_1.cpg
# gis.osm_landuse_a_free_1.dbf
# gis.osm_landuse_a_free_1.prj
# gis.osm_landuse_a_free_1.shp
# gis.osm_landuse_a_free_1.shx
# gis.osm_natural_a_free_1.cpg
# gis.osm_natural_a_free_1.dbf
# gis.osm_natural_a_free_1.prj
# gis.osm_natural_a_free_1.shp
# gis.osm_natural_a_free_1.shx
# gis.osm_natural_free_1.cpg
# gis.osm_natural_free_1.dbf
# gis.osm_natural_free_1.prj
# gis.osm_natural_free_1.shp
# gis.osm_natural_free_1.shx
# gis.osm_places_a_free_1.cpg
# gis.osm_places_a_free_1.dbf
# gis.osm_places_a_free_1.prj
# gis.osm_places_a_free_1.shp
# gis.osm_places_a_free_1.shx
# gis.osm_places_free_1.cpg
# gis.osm_places_free_1.dbf
# gis.osm_places_free_1.prj
# gis.osm_places_free_1.shp
# gis.osm_places_free_1.shx
# gis.osm_pofw_a_free_1.cpg
# gis.osm_pofw_a_free_1.dbf
# gis.osm_pofw_a_free_1.prj
# gis.osm_pofw_a_free_1.shp
# gis.osm_pofw_a_free_1.shx
# gis.osm_pofw_free_1.cpg
# gis.osm_pofw_free_1.dbf
# gis.osm_pofw_free_1.prj
# gis.osm_pofw_free_1.shp
# gis.osm_pofw_free_1.shx
# gis.osm_pois_a_free_1.cpg
# gis.osm_pois_a_free_1.dbf
# gis.osm_pois_a_free_1.prj
# gis.osm_pois_a_free_1.shp
# gis.osm_pois_a_free_1.shx
# gis.osm_pois_free_1.cpg
# gis.osm_pois_free_1.dbf
# gis.osm_pois_free_1.prj
# gis.osm_pois_free_1.shp
# gis.osm_pois_free_1.shx
# gis.osm_railways_free_1.cpg
# gis.osm_railways_free_1.dbf
# gis.osm_railways_free_1.prj
# gis.osm_railways_free_1.shp
# gis.osm_railways_free_1.shx
# gis.osm_roads_free_1.cpg
# gis.osm_roads_free_1.dbf
# gis.osm_roads_free_1.prj
# gis.osm_roads_free_1.shp
# gis.osm_roads_free_1.shx
# gis.osm_traffic_a_free_1.cpg
# gis.osm_traffic_a_free_1.dbf
# gis.osm_traffic_a_free_1.prj
# gis.osm_traffic_a_free_1.shp
# gis.osm_traffic_a_free_1.shx
# gis.osm_traffic_free_1.cpg
# gis.osm_traffic_free_1.dbf
# gis.osm_traffic_free_1.prj
# gis.osm_traffic_free_1.shp
# gis.osm_traffic_free_1.shx
# gis.osm_transport_a_free_1.cpg
# gis.osm_transport_a_free_1.dbf
# gis.osm_transport_a_free_1.prj
# gis.osm_transport_a_free_1.shp
# gis.osm_transport_a_free_1.shx
# gis.osm_transport_free_1.cpg
# gis.osm_transport_free_1.dbf
# gis.osm_transport_free_1.prj
# gis.osm_transport_free_1.shp
# gis.osm_transport_free_1.shx
# gis.osm_water_a_free_1.cpg
# gis.osm_water_a_free_1.dbf
# gis.osm_water_a_free_1.prj
# gis.osm_water_a_free_1.shp
# gis.osm_water_a_free_1.shx
# gis.osm_waterways_free_1.cpg
# gis.osm_waterways_free_1.dbf
# gis.osm_waterways_free_1.prj
# gis.osm_waterways_free_1.shp
# gis.osm_waterways_free_1.shx

# %% [markdown]
# According to [this manual](http://download.geofabrik.de/osm-data-in-gis-formats-free.pdf), the `poi` files contain points of interest, which seems to be more of what we're looking for. Let's open that up!

# %%
poi_file = '../../data/geo_files/PR_OSM/shp_files/gis.osm_pois_free_1.shp'
poi_collection = fiona.open(poi_file)
poi_list = list(poi_collection)
print('%d POIs'%(len(poi_list)))
# Out:
# 6502 POIs

# %%
def pretty_print(x):
    return json.dumps(x, indent=2, sort_keys=True)

# %%
print('\n'.join(map(lambda x: pretty_print(x), poi_list[:10])))
# Out:
# {
#   "geometry": {
#     "coordinates": [
#       -66.063993,
#       17.961996
#     ],
#     "type": "Point"
#   },
#   "id": "0",
#   "properties": {
#     "code": 2723,
#     "fclass": "monument",
#     "name": "",
#     "osm_id": "237846268"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.0473769,
#       18.2401997
#     ],
#     "type": "Point"
#   },
#   "id": "1",
#   "properties": {
#     "code": 2082,
#     "fclass": "school",
#     "name": "Escuela Pepita Arenas",
#     "osm_id": "238054139"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.0515189,
#       18.11136
#     ],
#     "type": "Point"
#   },
#   "id": "2",
#   "properties": {
#     "code": 2950,
#     "fclass": "tower",
#     "name": "WSRA-FM (Guayama)",
#     "osm_id": "238073429"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.6407374,
#       18.0348221
#     ],
#     "type": "Point"
#   },
#   "id": "3",
#   "properties": {
#     "code": 2012,
#     "fclass": "community_centre",
#     "name": "CIAPR Ponce",
#     "osm_id": "238785590"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.9210103,
#       18.1069048
#     ],
#     "type": "Point"
#   },
#   "id": "4",
#   "properties": {
#     "code": 2082,
#     "fclass": "school",
#     "name": "Escuela Luis M Santiago",
#     "osm_id": "239278917"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -65.6362026,
#       18.3350901
#     ],
#     "type": "Point"
#   },
#   "id": "5",
#   "properties": {
#     "code": 2401,
#     "fclass": "hotel",
#     "name": "Jajardo Inn",
#     "osm_id": "318500696"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.018221,
#       18.3643937
#     ],
#     "type": "Point"
#   },
#   "id": "6",
#   "properties": {
#     "code": 2082,
#     "fclass": "school",
#     "name": "Antilles Military Academy",
#     "osm_id": "357264257"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -67.1126797,
#       18.2057883
#     ],
#     "type": "Point"
#   },
#   "id": "7",
#   "properties": {
#     "code": 2082,
#     "fclass": "school",
#     "name": "Antillian College",
#     "osm_id": "357264264"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -65.7847992,
#       18.3021996
#     ],
#     "type": "Point"
#   },
#   "id": "8",
#   "properties": {
#     "code": 2204,
#     "fclass": "park",
#     "name": "Area de Recreo El Yunque",
#     "osm_id": "357264272"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.1365554,
#       18.4691115
#     ],
#     "type": "Point"
#   },
#   "id": "9",
#   "properties": {
#     "code": 2204,
#     "fclass": "park",
#     "name": "Parque Nacional Isla de Cabras",
#     "osm_id": "357264280"
#   },
#   "type": "Feature"
# }

# %% [markdown]
# Good! These are examples of entities that don't show up in Wikipedia but still exist (e.g., `Escuela Luis M Santiago`).

# %% [markdown]
# Let's check for some of the more obscure entities that we found during annotation:
#
# - `Villa Caribe` (restaurant)
# - `Urbanización Villa Rosa` (apartments)
# - `Coliseo Max Sánchez` (stadium)

# %%
poi_names = sorted(map(lambda x: x['properties']['name'], poi_list))
test_names = ['Villa Caribe', 'Urbanización Villa Rosa', 'Coliseo Max Sánchez']
print(set(poi_names) & set(test_names))
# Out:
# set([])

# %%
test_strs = ['Villa', 'Urb', 'Coliseo']
for test_str in test_strs:
    print('**%s**'%(test_str))
    matching_names = [p for p in poi_names if test_str in p]
    print(u'\n'.join(matching_names))
# Out:
# **Villa**
# Escuela Anselmo Villarrubia
# Escuela Villa Capri
# Escuela Villa Granada (elemental)
# Escuela Villa Granada Intermedia
# Escuela Villa Marisol
# Escuela Villa Marína
# La Villa del Norte Bakery
# Mirador Villalba Orocovis
# Ortodoncistas Dr. C. méndez Villamil, Dr. M. Torres Díaz
# Parador Villa Antonio
# Parador Villa del Mar
# Superfarmacia Villa Toledo
# Tasty Villa Chan
# Villa Carmen Econo Supermarket
# Villa Fontana Park
# Villa Montaña Beach Resort
# Villa Taina
# Villa Verde Inn
# Villa Vigía
# Village Spa
# Villas de Sotomayor
# **Urb**
# Escuela Elemental Urbana
# Escuela Elemental Urbana (escuela nueva)
# Escuela Elemental Urbana K-6
# Escuela Elemental Urbana Nueva
# Escuela Elemental Urbana Nueva
# Escuela Intermedia Urbana
# Escuela Joséfa Vélez Bauza (Superior Urbana)
# Escuela Nueva Elemental Urbana De Guaynabo
# Escuela Nueva Urbana De Ciales
# Escuela Superior Urbana
# Escuela Superior Urbana Nueva
# Nomada Urban Beach Hostel
# Parque Urbano Dora Colón Clavell
# Sabor Urbano
# Urban San Juan
# **Coliseo**
# Coliseo Angel Mercado Vega
# Coliseo Municipal
# Coliseo de Moca

# %% [markdown]
# OK! So maybe some of these are too obscure even for OSM. But we do see the major entities coming out.
#
# What's in the other POI list?

# %%
poi_file_2 = '../../data/geo_files/PR_OSM/shp_files/gis.osm_pois_a_free_1.shp'
poi_collection_2 = fiona.open(poi_file_2)
poi_list_2 = list(poi_collection_2)
print('%d POIs'%(len(poi_list_2)))
# Out:
# 7218 POIs

# %%
print('\n'.join(map(pretty_print, poi_list_2[:10])))
# Out:
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -66.0490623,
#           18.4025492
#         ],
#         [
#           -66.0490312,
#           18.4029692
#         ],
#         [
#           -66.0485621,
#           18.4029378
#         ],
#         [
#           -66.0485584,
#           18.4029878
#         ],
#         [
#           -66.0484696,
#           18.4029819
#         ],
#         [
#           -66.0484771,
#           18.4028803
#         ],
#         [
#           -66.0484569,
#           18.4028789
#         ],
#         [
#           -66.0484822,
#           18.4025378
#         ],
#         [
#           -66.0485024,
#           18.4025392
#         ],
#         [
#           -66.0485137,
#           18.4023866
#         ],
#         [
#           -66.0486474,
#           18.4023956
#         ],
#         [
#           -66.0486381,
#           18.4025208
#         ],
#         [
#           -66.0490623,
#           18.4025492
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "0",
#   "properties": {
#     "code": 2201,
#     "fclass": "theatre",
#     "name": "Teatro UPR",
#     "osm_id": "20887143"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -66.0464999,
#           18.407259
#         ],
#         [
#           -66.0462389,
#           18.4072693
#         ],
#         [
#           -66.0462247,
#           18.4068186
#         ],
#         [
#           -66.0464791,
#           18.4068104
#         ],
#         [
#           -66.0464999,
#           18.407259
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "1",
#   "properties": {
#     "code": 2253,
#     "fclass": "swimming_pool",
#     "name": "",
#     "osm_id": "21588431"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -66.046982,
#           18.4072536
#         ],
#         [
#           -66.0467629,
#           18.4072616
#         ],
#         [
#           -66.0467519,
#           18.4069428
#         ],
#         [
#           -66.0469694,
#           18.4069393
#         ],
#         [
#           -66.046982,
#           18.4072536
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "2",
#   "properties": {
#     "code": 2253,
#     "fclass": "swimming_pool",
#     "name": "",
#     "osm_id": "21588479"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -66.2641834,
#           18.4746787
#         ],
#         [
#           -66.2640555,
#           18.474684
#         ],
#         [
#           -66.2639362,
#           18.4746433
#         ],
#         [
#           -66.2637162,
#           18.4745288
#         ],
#         [
#           -66.263566,
#           18.4743889
#         ],
#         [
#           -66.2635016,
#           18.4742948
#         ],
#         [
#           -66.2634534,
#           18.4741803
#         ],
#         [
#           -66.2634239,
#           18.4740276
#         ],
#         [
#           -66.2636277,
#           18.4740047
#         ],
#         [
#           -66.2638281,
#           18.4739884
#         ],
#         [
#           -66.2640898,
#           18.4739726
#         ],
#         [
#           -66.2641642,
#           18.4740103
#         ],
#         [
#           -66.2641834,
#           18.4746787
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "3",
#   "properties": {
#     "code": 2252,
#     "fclass": "pitch",
#     "name": "",
#     "osm_id": "22148949"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -66.2907113,
#           18.4420175
#         ],
#         [
#           -66.2906899,
#           18.4425505
#         ],
#         [
#           -66.2903988,
#           18.442534
#         ],
#         [
#           -66.2902996,
#           18.4424513
#         ],
#         [
#           -66.2902419,
#           18.4423724
#         ],
#         [
#           -66.2902191,
#           18.4421065
#         ],
#         [
#           -66.2902379,
#           18.4419869
#         ],
#         [
#           -66.2906778,
#           18.4419818
#         ],
#         [
#           -66.2907113,
#           18.4420175
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "4",
#   "properties": {
#     "code": 2252,
#     "fclass": "pitch",
#     "name": "",
#     "osm_id": "22148991"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -66.2782951,
#           18.4208868
#         ],
#         [
#           -66.2780571,
#           18.4216213
#         ],
#         [
#           -66.2777867,
#           18.4215687
#         ],
#         [
#           -66.2776365,
#           18.4215226
#         ],
#         [
#           -66.2774794,
#           18.421413
#         ],
#         [
#           -66.2773962,
#           18.4212398
#         ],
#         [
#           -66.2773638,
#           18.4208956
#         ],
#         [
#           -66.2773684,
#           18.420593
#         ],
#         [
#           -66.2775741,
#           18.420604
#         ],
#         [
#           -66.2782697,
#           18.4208079
#         ],
#         [
#           -66.2782951,
#           18.4208868
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "5",
#   "properties": {
#     "code": 2252,
#     "fclass": "pitch",
#     "name": "",
#     "osm_id": "22150661"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -65.9168223,
#           18.2223404
#         ],
#         [
#           -65.9166782,
#           18.2223515
#         ],
#         [
#           -65.916659,
#           18.2221254
#         ],
#         [
#           -65.9168031,
#           18.2221143
#         ],
#         [
#           -65.9168223,
#           18.2223404
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "6",
#   "properties": {
#     "code": 2252,
#     "fclass": "pitch",
#     "name": "",
#     "osm_id": "22174915"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -67.0719809,
#           18.141628
#         ],
#         [
#           -67.0719689,
#           18.1417732
#         ],
#         [
#           -67.0711811,
#           18.141705
#         ],
#         [
#           -67.0711293,
#           18.1416444
#         ],
#         [
#           -67.0711837,
#           18.140854
#         ],
#         [
#           -67.0712834,
#           18.1408629
#         ],
#         [
#           -67.0716873,
#           18.1410068
#         ],
#         [
#           -67.0718002,
#           18.1410687
#         ],
#         [
#           -67.0718812,
#           18.1411583
#         ],
#         [
#           -67.0719091,
#           18.1412429
#         ],
#         [
#           -67.0719636,
#           18.1414752
#         ],
#         [
#           -67.0719809,
#           18.141628
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "7",
#   "properties": {
#     "code": 2252,
#     "fclass": "pitch",
#     "name": "",
#     "osm_id": "22215303"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -66.1248953,
#           18.471374
#         ],
#         [
#           -66.1248102,
#           18.471572
#         ],
#         [
#           -66.1247532,
#           18.4716829
#         ],
#         [
#           -66.1247174,
#           18.4716968
#         ],
#         [
#           -66.1242814,
#           18.4714268
#         ],
#         [
#           -66.1240428,
#           18.4715027
#         ],
#         [
#           -66.1239624,
#           18.4713805
#         ],
#         [
#           -66.1235147,
#           18.4713625
#         ],
#         [
#           -66.1235044,
#           18.471437
#         ],
#         [
#           -66.1234171,
#           18.4714298
#         ],
#         [
#           -66.1233523,
#           18.4714107
#         ],
#         [
#           -66.1234102,
#           18.4712999
#         ],
#         [
#           -66.1234269,
#           18.4711036
#         ],
#         [
#           -66.1231604,
#           18.4708914
#         ],
#         [
#           -66.1229582,
#           18.4708972
#         ],
#         [
#           -66.1229616,
#           18.4708194
#         ],
#         [
#           -66.1229676,
#           18.4708086
#         ],
#         [
#           -66.1229838,
#           18.4707912
#         ],
#         [
#           -66.1236367,
#           18.4704883
#         ],
#         [
#           -66.1236668,
#           18.4704731
#         ],
#         [
#           -66.1236826,
#           18.4704521
#         ],
#         [
#           -66.1237102,
#           18.4703762
#         ],
#         [
#           -66.123915,
#           18.4698123
#         ],
#         [
#           -66.1239789,
#           18.4697711
#         ],
#         [
#           -66.1242889,
#           18.469924
#         ],
#         [
#           -66.1243439,
#           18.469905
#         ],
#         [
#           -66.1244127,
#           18.4698813
#         ],
#         [
#           -66.1244955,
#           18.4698972
#         ],
#         [
#           -66.1245188,
#           18.4699129
#         ],
#         [
#           -66.1245103,
#           18.4703245
#         ],
#         [
#           -66.1246893,
#           18.4706087
#         ],
#         [
#           -66.1246247,
#           18.470803
#         ],
#         [
#           -66.1246813,
#           18.4708273
#         ],
#         [
#           -66.1246202,
#           18.471002
#         ],
#         [
#           -66.1247254,
#           18.4712632
#         ],
#         [
#           -66.1248953,
#           18.471374
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "8",
#   "properties": {
#     "code": 2731,
#     "fclass": "castle",
#     "name": "Fuerte San Felipe del Morro",
#     "osm_id": "28966285"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -66.1248953,
#           18.471374
#         ],
#         [
#           -66.1248102,
#           18.471572
#         ],
#         [
#           -66.1247532,
#           18.4716829
#         ],
#         [
#           -66.1247174,
#           18.4716968
#         ],
#         [
#           -66.1242814,
#           18.4714268
#         ],
#         [
#           -66.1240428,
#           18.4715027
#         ],
#         [
#           -66.1239624,
#           18.4713805
#         ],
#         [
#           -66.1235147,
#           18.4713625
#         ],
#         [
#           -66.1235044,
#           18.471437
#         ],
#         [
#           -66.1234171,
#           18.4714298
#         ],
#         [
#           -66.1233523,
#           18.4714107
#         ],
#         [
#           -66.1234102,
#           18.4712999
#         ],
#         [
#           -66.1234269,
#           18.4711036
#         ],
#         [
#           -66.1231604,
#           18.4708914
#         ],
#         [
#           -66.1229582,
#           18.4708972
#         ],
#         [
#           -66.1229616,
#           18.4708194
#         ],
#         [
#           -66.1229676,
#           18.4708086
#         ],
#         [
#           -66.1229838,
#           18.4707912
#         ],
#         [
#           -66.1236367,
#           18.4704883
#         ],
#         [
#           -66.1236668,
#           18.4704731
#         ],
#         [
#           -66.1236826,
#           18.4704521
#         ],
#         [
#           -66.1237102,
#           18.4703762
#         ],
#         [
#           -66.123915,
#           18.4698123
#         ],
#         [
#           -66.1239789,
#           18.4697711
#         ],
#         [
#           -66.1242889,
#           18.469924
#         ],
#         [
#           -66.1243439,
#           18.469905
#         ],
#         [
#           -66.1244127,
#           18.4698813
#         ],
#         [
#           -66.1244955,
#           18.4698972
#         ],
#         [
#           -66.1245188,
#           18.4699129
#         ],
#         [
#           -66.1245103,
#           18.4703245
#         ],
#         [
#           -66.1246893,
#           18.4706087
#         ],
#         [
#           -66.1246247,
#           18.470803
#         ],
#         [
#           -66.1246813,
#           18.4708273
#         ],
#         [
#           -66.1246202,
#           18.471002
#         ],
#         [
#           -66.1247254,
#           18.4712632
#         ],
#         [
#           -66.1248953,
#           18.471374
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "9",
#   "properties": {
#     "code": 2721,
#     "fclass": "attraction",
#     "name": "Fuerte San Felipe del Morro",
#     "osm_id": "28966285"
#   },
#   "type": "Feature"
# }

# %% [markdown]
# Maybe the combined list has the missing entities!!

# %%
poi_names_2 = sorted(map(lambda x: x['properties']['name'], poi_list_2))
poi_names_combined = list(set(poi_names + poi_names_2))
test_names = ['Villa Caribe', 'Urbanización Villa Rosa', 'Coliseo Max Sánchez']
print(set(poi_names_combined) & set(test_names))
# Out:
# set([])

# %% [markdown]
# Still nope! These names must be extremely obscure.

# %% [markdown]
# How about other lists?

# %% [markdown]
# ## Traffic

# %%
traffic_file_name = '../../data/geo_files/PR_OSM/shp_files/gis.osm_traffic_free_1.shp'
traffic_collection_1 = fiona.open(traffic_file_name)
traffic_list_1 = list(traffic_collection_1)
print('%d traffic points'%(len(traffic_list_1)))
# Out:
# 2454 traffic points

# %%
print('\n'.join(map(pretty_print, traffic_list_1[:10])))
# Out:
# {
#   "geometry": {
#     "coordinates": [
#       -66.0166962,
#       18.4358875
#     ],
#     "type": "Point"
#   },
#   "id": "0",
#   "properties": {
#     "code": 5206,
#     "fclass": "motorway_junction",
#     "name": "",
#     "osm_id": "114570246"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.0222767,
#       18.4331861
#     ],
#     "type": "Point"
#   },
#   "id": "1",
#   "properties": {
#     "code": 5206,
#     "fclass": "motorway_junction",
#     "name": "",
#     "osm_id": "114596759"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.0763998,
#       18.4282765
#     ],
#     "type": "Point"
#   },
#   "id": "2",
#   "properties": {
#     "code": 5206,
#     "fclass": "motorway_junction",
#     "name": "",
#     "osm_id": "217540324"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.0467208,
#       18.4080458
#     ],
#     "type": "Point"
#   },
#   "id": "3",
#   "properties": {
#     "code": 5206,
#     "fclass": "motorway_junction",
#     "name": "",
#     "osm_id": "219027329"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.0409096,
#       18.4083365
#     ],
#     "type": "Point"
#   },
#   "id": "4",
#   "properties": {
#     "code": 5206,
#     "fclass": "motorway_junction",
#     "name": "",
#     "osm_id": "221391177"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.198611,
#       18.3862395
#     ],
#     "type": "Point"
#   },
#   "id": "5",
#   "properties": {
#     "code": 5207,
#     "fclass": "turning_circle",
#     "name": "",
#     "osm_id": "233310006"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.202242,
#       18.365051
#     ],
#     "type": "Point"
#   },
#   "id": "6",
#   "properties": {
#     "code": 5207,
#     "fclass": "turning_circle",
#     "name": "",
#     "osm_id": "233310205"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -66.1192343,
#       18.2304644
#     ],
#     "type": "Point"
#   },
#   "id": "7",
#   "properties": {
#     "code": 5202,
#     "fclass": "mini_roundabout",
#     "name": "",
#     "osm_id": "237789525"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -67.129468,
#       18.315057
#     ],
#     "type": "Point"
#   },
#   "id": "8",
#   "properties": {
#     "code": 5207,
#     "fclass": "turning_circle",
#     "name": "",
#     "osm_id": "237821421"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       -67.1469355,
#       18.275852
#     ],
#     "type": "Point"
#   },
#   "id": "9",
#   "properties": {
#     "code": 5207,
#     "fclass": "turning_circle",
#     "name": "",
#     "osm_id": "237832465"
#   },
#   "type": "Feature"
# }

# %% [markdown]
# Unnamed motorways. Not interesting.

# %% [markdown]
# ## Roads

# %%
road_file_1 = '../../data/geo_files/PR_OSM/shp_files/gis.osm_roads_free_1.shp'
road_collection_1 = fiona.open(road_file_1)
road_list_1 = list(road_collection_1)
print('%d road entities'%(len(road_list_1)))
# Out:
# 159560 road entities

# %%
print('\n'.join(map(pretty_print, road_list_1[:10])))
# Out:
# {
#   "geometry": {
#     "coordinates": [
#       [
#         -66.0159198,
#         18.4362435
#       ],
#       [
#         -66.0160557,
#         18.4362188
#       ],
#       [
#         -66.016188,
#         18.4361882
#       ],
#       [
#         -66.0163615,
#         18.4360911
#       ],
#       [
#         -66.0165417,
#         18.4359771
#       ],
#       [
#         -66.0166962,
#         18.4358875
#       ]
#     ],
#     "type": "LineString"
#   },
#   "id": "0",
#   "properties": {
#     "bridge": "F",
#     "code": 5111,
#     "fclass": "motorway",
#     "layer": 0,
#     "maxspeed": 0,
#     "name": "",
#     "oneway": "F",
#     "osm_id": "12558468",
#     "ref": "",
#     "tunnel": "F"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         -66.0364784,
#         18.4462158
#       ],
#       [
#         -66.0365735,
#         18.4462263
#       ],
#       [
#         -66.0369382,
#         18.4462657
#       ],
#       [
#         -66.0375344,
#         18.4463144
#       ],
#       [
#         -66.0413925,
#         18.4465811
#       ],
#       [
#         -66.0446203,
#         18.4468035
#       ]
#     ],
#     "type": "LineString"
#   },
#   "id": "1",
#   "properties": {
#     "bridge": "F",
#     "code": 5111,
#     "fclass": "motorway",
#     "layer": 0,
#     "maxspeed": 80,
#     "name": "Expreso Rom\u00e1n Baldorioty de Castro",
#     "oneway": "F",
#     "osm_id": "12558653",
#     "ref": "PR-26",
#     "tunnel": "F"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         -66.0166962,
#         18.4358875
#       ],
#       [
#         -66.0168504,
#         18.4358254
#       ],
#       [
#         -66.0169945,
#         18.4357822
#       ],
#       [
#         -66.0172713,
#         18.4357491
#       ],
#       [
#         -66.0178893,
#         18.4357247
#       ],
#       [
#         -66.0185673,
#         18.4357002
#       ],
#       [
#         -66.0191881,
#         18.4356623
#       ],
#       [
#         -66.0195111,
#         18.435627
#       ],
#       [
#         -66.0196516,
#         18.4355971
#       ],
#       [
#         -66.0200824,
#         18.4354696
#       ]
#     ],
#     "type": "LineString"
#   },
#   "id": "2",
#   "properties": {
#     "bridge": "F",
#     "code": 5111,
#     "fclass": "motorway",
#     "layer": 0,
#     "maxspeed": 0,
#     "name": "",
#     "oneway": "F",
#     "osm_id": "12559678",
#     "ref": "",
#     "tunnel": "F"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         -66.0592969,
#         18.407586
#       ],
#       [
#         -66.0592215,
#         18.4075882
#       ],
#       [
#         -66.0591335,
#         18.4075895
#       ]
#     ],
#     "type": "LineString"
#   },
#   "id": "3",
#   "properties": {
#     "bridge": "F",
#     "code": 5112,
#     "fclass": "trunk",
#     "layer": 0,
#     "maxspeed": 56,
#     "name": "Expreso Jes\u00fas T. Pi\u00f1ero",
#     "oneway": "F",
#     "osm_id": "12559708",
#     "ref": "PR-17",
#     "tunnel": "F"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         -66.0875581,
#         18.4616555
#       ],
#       [
#         -66.0874629,
#         18.4614937
#       ],
#       [
#         -66.0873909,
#         18.4613269
#       ],
#       [
#         -66.0873526,
#         18.4611734
#       ],
#       [
#         -66.0873344,
#         18.461037
#       ],
#       [
#         -66.0873242,
#         18.4609295
#       ]
#     ],
#     "type": "LineString"
#   },
#   "id": "4",
#   "properties": {
#     "bridge": "T",
#     "code": 5113,
#     "fclass": "primary",
#     "layer": 1,
#     "maxspeed": 40,
#     "name": "Avenida de la Constituci\u00f3n",
#     "oneway": "F",
#     "osm_id": "19219481",
#     "ref": "PR-25",
#     "tunnel": "F"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         -66.0865158,
#         18.4603262
#       ],
#       [
#         -66.0866191,
#         18.4604076
#       ],
#       [
#         -66.0866978,
#         18.4604929
#       ],
#       [
#         -66.0867658,
#         18.4605776
#       ],
#       [
#         -66.0868324,
#         18.460627
#       ],
#       [
#         -66.0868979,
#         18.4606621
#       ],
#       [
#         -66.0869727,
#         18.46068
#       ],
#       [
#         -66.0870756,
#         18.460658
#       ],
#       [
#         -66.087146,
#         18.4606036
#       ],
#       [
#         -66.0871784,
#         18.4605605
#       ],
#       [
#         -66.0871941,
#         18.4604998
#       ],
#       [
#         -66.0871926,
#         18.4604435
#       ],
#       [
#         -66.0871816,
#         18.4603605
#       ],
#       [
#         -66.0871441,
#         18.4602598
#       ],
#       [
#         -66.0870942,
#         18.4601739
#       ],
#       [
#         -66.0870098,
#         18.4600835
#       ],
#       [
#         -66.0869208,
#         18.460005
#       ],
#       [
#         -66.0868239,
#         18.4599472
#       ],
#       [
#         -66.0867236,
#         18.4598831
#       ]
#     ],
#     "type": "LineString"
#   },
#   "id": "5",
#   "properties": {
#     "bridge": "F",
#     "code": 5135,
#     "fclass": "tertiary_link",
#     "layer": 0,
#     "maxspeed": 0,
#     "name": "",
#     "oneway": "F",
#     "osm_id": "19219540",
#     "ref": "",
#     "tunnel": "F"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         -66.1101911,
#         18.464692
#       ],
#       [
#         -66.1100423,
#         18.4646853
#       ],
#       [
#         -66.1098915,
#         18.4646774
#       ],
#       [
#         -66.109702,
#         18.4646657
#       ],
#       [
#         -66.109509,
#         18.464655
#       ],
#       [
#         -66.1093134,
#         18.4646433
#       ],
#       [
#         -66.1091367,
#         18.4646339
#       ],
#       [
#         -66.1089465,
#         18.4646237
#       ],
#       [
#         -66.1087704,
#         18.4646121
#       ],
#       [
#         -66.1087323,
#         18.4646413
#       ],
#       [
#         -66.1087166,
#         18.4647025
#       ]
#     ],
#     "type": "LineString"
#   },
#   "id": "6",
#   "properties": {
#     "bridge": "F",
#     "code": 5141,
#     "fclass": "service",
#     "layer": 0,
#     "maxspeed": 0,
#     "name": "",
#     "oneway": "B",
#     "osm_id": "19242825",
#     "ref": "",
#     "tunnel": "F"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         -66.111571,
#         18.4060978
#       ],
#       [
#         -66.1095806,
#         18.4071492
#       ]
#     ],
#     "type": "LineString"
#   },
#   "id": "7",
#   "properties": {
#     "bridge": "F",
#     "code": 5113,
#     "fclass": "primary",
#     "layer": 0,
#     "maxspeed": 0,
#     "name": "Carretera 2",
#     "oneway": "F",
#     "osm_id": "20407429",
#     "ref": "PR-2",
#     "tunnel": "F"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         -66.079333,
#         18.4433741
#       ],
#       [
#         -66.0793729,
#         18.4434613
#       ],
#       [
#         -66.0794428,
#         18.4435083
#       ],
#       [
#         -66.0795449,
#         18.4435847
#       ],
#       [
#         -66.0795837,
#         18.4436215
#       ],
#       [
#         -66.079611,
#         18.443665
#       ],
#       [
#         -66.0796325,
#         18.4437154
#       ],
#       [
#         -66.0796497,
#         18.4437876
#       ],
#       [
#         -66.0796598,
#         18.4438489
#       ],
#       [
#         -66.0796598,
#         18.443921
#       ],
#       [
#         -66.0796469,
#         18.4439796
#       ],
#       [
#         -66.0796124,
#         18.4440667
#       ],
#       [
#         -66.0795665,
#         18.4441362
#       ],
#       [
#         -66.0795091,
#         18.4442029
#       ],
#       [
#         -66.0794301,
#         18.4442615
#       ],
#       [
#         -66.0793598,
#         18.4442901
#       ],
#       [
#         -66.0792794,
#         18.4443118
#       ],
#       [
#         -66.0791933,
#         18.4443159
#       ],
#       [
#         -66.0791287,
#         18.4443091
#       ],
#       [
#         -66.0790583,
#         18.4442914
#       ],
#       [
#         -66.0790052,
#         18.4442683
#       ],
#       [
#         -66.0789464,
#         18.4442342
#       ],
#       [
#         -66.0789019,
#         18.4442029
#       ],
#       [
#         -66.0788516,
#         18.4441566
#       ],
#       [
#         -66.0788129,
#         18.4441144
#       ],
#       [
#         -66.0787827,
#         18.4440695
#       ],
#       [
#         -66.0787612,
#         18.4440164
#       ],
#       [
#         -66.0787483,
#         18.4439578
#       ],
#       [
#         -66.0787454,
#         18.4438952
#       ],
#       [
#         -66.0787468,
#         18.4438461
#       ],
#       [
#         -66.0787569,
#         18.4438026
#       ],
#       [
#         -66.0787712,
#         18.4437427
#       ],
#       [
#         -66.0788043,
#         18.4436582
#       ],
#       [
#         -66.078876,
#         18.4435588
#       ],
#       [
#         -66.0789442,
#         18.4433861
#       ]
#     ],
#     "type": "LineString"
#   },
#   "id": "8",
#   "properties": {
#     "bridge": "F",
#     "code": 5131,
#     "fclass": "motorway_link",
#     "layer": 0,
#     "maxspeed": 0,
#     "name": "",
#     "oneway": "F",
#     "osm_id": "20407836",
#     "ref": "",
#     "tunnel": "F"
#   },
#   "type": "Feature"
# }
# {
#   "geometry": {
#     "coordinates": [
#       [
#         -66.073108,
#         18.4357235
#       ],
#       [
#         -66.0732701,
#         18.4352546
#       ],
#       [
#         -66.0735884,
#         18.4343324
#       ],
#       [
#         -66.0737208,
#         18.4339943
#       ],
#       [
#         -66.0741307,
#         18.4329675
#       ]
#     ],
#     "type": "LineString"
#   },
#   "id": "9",
#   "properties": {
#     "bridge": "F",
#     "code": 5111,
#     "fclass": "motorway",
#     "layer": 0,
#     "maxspeed": 88,
#     "name": "Autopista Jos\u00e9 de Diego",
#     "oneway": "F",
#     "osm_id": "20449862",
#     "ref": "PR-22",
#     "tunnel": "F"
#   },
#   "type": "Feature"
# }

# %% [markdown]
# These roads do have names! Do we have any repeat offenders?

# %%
from collections import Counter
road_names_1 = map(lambda x: x['properties']['name'], road_list_1)
road_counter = Counter(road_names_1)
top_k = 50
print('\n'.join(map(lambda x: '%s,%d'%(x[0],x[1]), road_counter.most_common(top_k))))
# Out:
# ,106345
# Calle 1,1126
# Calle 2,1052
# Calle 3,976
# Calle 4,875
# Calle 5,745
# Calle 6,654
# Calle 7,606
# Calle 8,530
# Calle A,521
# Calle B,448
# Calle 9,425
# Calle 10,398
# Autopista Luis A. Ferré,365
# Calle C,334
# Calle 11,282
# Autopista José de Diego,282
# Calle 12,274
# Calle D,272
# Calle 13,250
# Calle 14,210
# Calle Marginal,195
# Carretera 2,195
# Carretera 3,187
# Calle E,186
# Calle 15,186
# Autopista José Celso Barbosa,172
# Calle F,159
# Expreso Roberto Sánchez Vilella,156
# Calle 16,151
# Calle 17,143
# Calle Principal,140
# Calle 19,128
# Calle 18,126
# Calle 20,115
# Calle 21,111
# Carretera 1,107
# Calle Amapola,105
# Calle G,104
# Calle 22,103
# Expreso Cruz Ortíz Stella,102
# Calle 23,101
# Calle Luis Muñoz Rivera,100
# Autopista Roberto Sánchez Vilella,94
# Calle Gardenia,86
# Calle H,81
# Calle 24,77
# Calle Margarita,76
# Calle Ceiba,72
# Calle 25,71

# %% [markdown]
# OK! The most common street markers are the most obvious ones, stuff like "1st Street", "2nd Street," etc. These streets are probably common across locations, which makes them good candidates for disambiguation!

# %% [markdown]
# ## Natural

# %% [markdown]
# We should make a quick summary function to extract all names from a shape file.

# %%
def get_all_location_names(file_name):
    location_iter = fiona.open(file_name)
    locations = list(location_iter)
    location_names = map(lambda x: x['properties']['name'], locations)
    return location_names

# %%
natural_file_name = '../../data/geo_files/PR_OSM/shp_files/gis.osm_natural_free_1.shp'
natural_location_names_1 = get_all_location_names(natural_file_name)
natural_location_name_counts = Counter(natural_location_names_1)
top_k = 50
print_count = lambda x: '%s,%d'%(x[0],x[1])
print('\n'.join(map(print_count, natural_location_name_counts.most_common(top_k))))
# Out:
# ,9006
# Palma,31
# Palmas,17
# Palma Areca,10
# Roble Rosado,9
# Plátano,9
# Mangó,8
# roble,7
# Palm,7
# Mango,7
# Roble,7
# Roble Lila,6
# Flamboyán,6
# Cerro Gordo,5
# Roble rosado,5
# Cerro Avispa,4
# María,4
# Roble Amarillo,4
# Cerro de las Cuevas,3
# Dracaena,3
# Cerro Magueyes,3
# Cerro Vigía,2
# Ficus,2
# Jatropha,2
# Palma Navidad,2
# Piedra Blanca,2
# Playa Grande,2
# Cerro Lucero,2
# La Ceiba,2
# Cerro Miraflores,2
# Acacia Blanca,2
# Croto,2
# Cerro El Gato,2
# Higuereta,2
# Cerro de la Bandera,2
# Úcar,2
# Cerro Santo Domingo,2
# Cerro Malo,2
# Cerro San José,2
# Cerro Pichón,2
# Cerro de las Avispas,2
# Arbol de María,2
# Pterocarpus,2
# La Torrecilla,2
# Cerro del Muerto,2
# Almácigo,2
# Trinitarias,2
# palm,2
# úcar,2
# Cerro Farallón,2

# %% [markdown]
# The natural locations have a long tail and seem to focus on trees (`palma` => "palm", `roble` => "oak") and physical landmarks (`cerro` => "hill").

# %% [markdown]
# ## Buildings

# %%
building_file_name = '../../data/geo_files/PR_OSM/shp_files/gis.osm_buildings_a_free_1.shp'
building_location_names_1 = get_all_location_names(building_file_name)
building_location_name_counts = Counter(building_location_names_1)
top_k = 50
print_count = lambda x: '%s,%d'%(x[0],x[1])
print('\n'.join(map(print_count, building_location_name_counts.most_common(top_k))))
# Out:
# ,1428913
# Burger King,31
# McDonald's,28
# Walgreens,26
# ruins,18
# Caparra Country Club,14
# Wendy's,13
# Church's Chicken,13
# KFC,13
# Escuela Rosalina C. MartÃ­Â­nez,11
# Pizza Hut,11
# Banco Popular,9
# Caseta Guardia,8
# Shell,8
# ruinss,8
# Mini Almacenes,7
# Villa Rosa,7
# Scotiabank,7
# Condominio Rexville Park,7
# unknown,7
# Cond. Plaza del Mar,7
# Total,7
# Cond. The Falls,6
# Museo Casa Blanca,6
# Iglesia Metodista,6
# Juncos Apartment,6
# Taco Bell,6
# Villas del Sol,6
# Apartamentos,6
# CVS,5
# First Bank,5
# Escuela Superior Tomás Carrión Maduro,5
# Puma,5
# Walmart,5
# Amigo,5
# Econo,5
# Sam's Club,5
# ruinsss,5
# Cabanillas Industrial Park,4
# Centro de Usos Multiples,4
# AutoZone,4
# Academia Sally Olsen,4
# Oficina,4
# smokestack,4
# Club de los Telefónicos,4
# Dr. Facundo Bueso,4
# Subestacion AEE,4
# Banco Popular de Puerto Rico,4
# Terminal de Carros Públicos,4
# Casa Alcaldía,4

# %% [markdown]
# Lots of businesses (`McDonald's`) and a long tail of residential stuff (`Juncos Apartment`).

# %% [markdown]
# ## Test OSM lexicon
# Does using the OSM lexicon make more sense than using the CrossWikis lexicon??

# %%
import re
shape_file_dir = '../../data/geo_files/PR_OSM/shp_files/'
shape_type_matcher = re.compile('(?<=osm_)[a-zA-Z]+(?=_)')
unique_shape_types = sorted(set([shape_type_matcher.findall(f)[0] for f in os.listdir(shape_file_dir)]))
print(unique_shape_types)
# Out:
# ['buildings', 'landuse', 'natural', 'places', 'pofw', 'pois', 'railways', 'roads', 'traffic', 'transport', 'water', 'waterways']

# %% [markdown]
# To start, let's use the land-based shape types.

# %%
shape_types = ['buildings', 'landuse', 'natural', 'places', 'pofw', 'pois', 'roads', 'traffic']
file_base = os.path.join(shape_file_dir, 'gis.osm_%s_free_1.shp')
# get relevant files
shape_file_matcher = re.compile('gis.osm_(%s).*.shp'%('|'.join(shape_types)))
# shape_files = [file_base%(s) for s in shape_types]
shape_files = filter(lambda x: shape_file_matcher.match(x), os.listdir(shape_file_dir))
print(shape_files)
# Out:
# ['gis.osm_buildings_a_free_1.shp', 'gis.osm_landuse_a_free_1.shp', 'gis.osm_natural_a_free_1.shp', 'gis.osm_natural_free_1.shp', 'gis.osm_places_a_free_1.shp', 'gis.osm_places_free_1.shp', 'gis.osm_pofw_a_free_1.shp', 'gis.osm_pofw_free_1.shp', 'gis.osm_pois_a_free_1.shp', 'gis.osm_pois_free_1.shp', 'gis.osm_roads_free_1.shp', 'gis.osm_traffic_a_free_1.shp', 'gis.osm_traffic_free_1.shp']

# %%
import numpy as np
import pandas as pd
def collect_tuples(coord_list):
    """
    Collect all coordinate tuples in list by flattening list.
    """
    full_coord_list = []
    if(type(coord_list[0]) is not list):
        return coord_list
    else:
        for l in coord_list:
            full_coord_list += collect_tuples(l)
    return full_coord_list

def get_geotag_info(f_name):
    """
    Extract name, location, and feature class of 
    OSM items in file.
    
    Parameters:
    -----------
    f_name : str
    
    Returns:
    --------
    geotag_info : pandas.DataFrame
    """
    shape_collection = fiona.open(f_name)
    geotag_info = []
    for i, item in enumerate(shape_collection):
        geometry = item['geometry']
        geometry_type = geometry['type']
        coords = geometry['coordinates']
        if(geometry_type == 'Point'):
            # get point estimate
            lat, lon = coords
        elif(geometry_type == 'LineString' or geometry_type == 'Polygon'):
            # compute average of coord list
            lat_lon_tuples = collect_tuples(coords)
#             print(lat_lon_tuples)
            lat_vals, lon_vals = zip(*lat_lon_tuples)
            lat = np.mean(lat_vals)
            lon = np.mean(lon_vals)
        properties = item['properties']
        name = properties['name']
        osm_id = properties['osm_id']
        feature_class = properties['fclass']
        geo_item = [name, geometry_type, feature_class, osm_id, lat, lon]
        geotag_info.append(geo_item)
    geotag_cols = ['name', 'geometry_type', 'feature_class', 'osm_id', 'lat', 'lon']
    geotag_info = pd.DataFrame(geotag_info, columns=geotag_cols)
    return geotag_info

# %%
geotag_info = []
for s_file in shape_files:
    print('processing shape file %s'%(s_file))
    s_file_full = os.path.join(shape_file_dir, s_file)
    geotag_info_s = get_geotag_info(s_file_full)
    geotag_info.append(geotag_info_s)
geotag_info_df = pd.concat(geotag_info, axis=0)
# Out:
# processing shape file gis.osm_buildings_a_free_1.shp
# processing shape file gis.osm_landuse_a_free_1.shp
# processing shape file gis.osm_natural_a_free_1.shp
# processing shape file gis.osm_natural_free_1.shp
# processing shape file gis.osm_places_a_free_1.shp
# processing shape file gis.osm_places_free_1.shp
# processing shape file gis.osm_pofw_a_free_1.shp
# processing shape file gis.osm_pofw_free_1.shp
# processing shape file gis.osm_pois_a_free_1.shp
# processing shape file gis.osm_pois_free_1.shp
# processing shape file gis.osm_roads_free_1.shp
# processing shape file gis.osm_traffic_a_free_1.shp
# processing shape file gis.osm_traffic_free_1.shp

# %%
print(geotag_info_df.head())
print(geotag_info_df.shape)
# Out:
#                                                name geometry_type  \
# 0                                  Multipisos UPRRP       Polygon
# 1  Escuela de Arquitecura y Escuela de Bellas Artes       Polygon
# 2                           Eugenio María de Hostos       Polygon
# 3                                        Teatro UPR       Polygon
# 4            Complejo Deportivo Cosme Beitía Sálamo       Polygon
#
#   feature_class    osm_id        lat        lon
# 0      building  20885732 -66.044319  18.402406
# 1      building  20887004 -66.046165  18.402295
# 2      building  20887047 -66.047953  18.402395
# 3      building  20887143 -66.048651  18.402701
# 4      building  20887609 -66.046724  18.407594
# (1626213, 6)

# %%
# save to file
geotag_info_file = '../../data/geo_files/PR_OSM/shp_files/combined_shp_data.tsv'
geotag_info_df.to_csv(geotag_info_file, sep='\t', index=False, encoding='utf-8')

# %% [markdown]
# We should test the precision/recall of the OSM lexicon to determine how much improvement we might get.

# %%
OSM_lexicon = sorted(geotag_info_df.loc[:, 'name'].unique().tolist())
print('%d phrases in lexicon'%(len(OSM_lexicon)))
print('\n'.join(OSM_lexicon[100:200]))
# Out:
# 26308 phrases in lexicon
# A4
# AAA
# AAA - Planta de Filtración Miradero
# AAA Cofee Break Services
# ABC Pharmacy
# ABC Veterinary
# ABC Veterinary Clinic
# AEE - NEOS
# AEE- Juan Ruiz Velez Bldg.
# AFDA
# AIB
# ALTURAS DE PIEDRAS BLANCAS
# AM Cafe
# AMA Busway
# AOR Building Supplies
# AR Cellular services
# AT&T
# AT&T Office
# ATC
# ATT Mobility PR inc.
# Aarti
# Abandonado
# Abandoned School
# Abbvie Biologics
# Abitore
# Abitto
# Abracadabra
# Abracadabra Counter Café
# Abraham Lincoln Statue
# Acacia Blanca
# Academia Adventista del Oeste
# Academia Barbara Ann Roessler
# Academia Carlota Alfaro
# Academia Cooperativa De Integración Social (ACIS)
# Academia Cristiana Logos
# Academia Edusapien
# Academia Maria Reina
# Academia Perpetuo Socorro
# Academia Perpetuo Socorro - High School Building
# Academia Rev. Isidro Díaz López
# Academia Sagrado Corazón
# Academia Sally Olsen
# Academia San Agustin
# Academia San Antonio
# Academia San José
# Academia Santa Teresita
# Academia Santo Tomas de Aquino
# Academia de Baile
# Academia de Musica
# Academia de Música
# Academia de la Policia de Puerto Rico
# Academia del Perpetuo Socorro - Elementary School Building
# Academy Drive
# Académico I
# Académico II
# Académico III
# Académico IV
# Acapulco Taquería Mexicana
# Acceso Alturas de Monte Verde
# Ace
# Acosta
# Acqua
# Action Printing
# Acupets
# Adjuntas
# Adjuntas Post Office
# Administracion
# Administracion De Servicios Medicos De PR (ASEM)
# Administracion de Vivienda Publica
# Administración
# Administración Central
# Administración de Compensaciones por Accidentes de Automóviles (ACAA)
# Adolfo's Frozen Drinks
# Adrenaline Group
# Adriel Toyota
# Advance Auto Parts
# Advance Autoparts
# Advanced Cycles
# Aerie 56
# Agencia Hipica 226
# Aggressive Fitness
# Agrocentro
# Aguada
# Aguada Parque de Colón
# Aguadilla
# Aguadilla Ice Skating Arena
# Aguadilla Mall
# Aguadilla Memorial Park
# Aguadilla Nissan
# Aguadilla Post Office
# Aguadilla Skatepark
# Aguardiente
# Aguas Buenas
# Aguas Buenas Post Office
# Aguaviva
# Aguila
# Aguilea
# Aguilita
# Aguirre US Postal Office
# Agustin Stahl

# %%
test_word = 'Urb'
test_phrases = list(filter(lambda x: test_word in x, OSM_lexicon))
print('%d test phrases'%(len(test_phrases)))
print('\n'.join(test_phrases))
# Out:
# 274 test phrases
# Avenida David Urbina
# Bahía Urbana
# Bosque Urbano Doña Inés Mendoza
# Bosque Urbano de San Patricio
# Bosque Urbano del Nuevo Milenio
# Calle Cecilio Urbina
# Calle Paseo Largo Urb. Paseo Alta Vista
# Calle Urb Monserrate
# Calle Urbano Ramírez
# Cancha Urb. Jardines
# Centro Urbano del Condado
# Escuela Elemental Urbana
# Escuela Elemental Urbana (escuela nueva)
# Escuela Elemental Urbana K-6
# Escuela Elemental Urbana Nueva
# Escuela Intermedia Urbana
# Escuela Joséfa Vélez Bauza (Superior Urbana)
# Escuela Nueva Elemental Urbana De Guaynabo
# Escuela Nueva Urbana De Ciales
# Escuela Superior Urbana
# Escuela Superior Urbana Nueva
# Lavander Urban Vintage Boutique
# Nomada Urban Beach Hostel
# Parque Urb. Sol y Mar
# Parque Urbano Dora Colón Clavell
# Sabor Urbano
# Tren Urbano
# Urb Alturas De San Jose
# Urb Colinas 3T
# Urb Colinas De Villa Rosa
# Urb Colinas Verdes
# Urb Country Club
# Urb Cuevas
# Urb El Arrendado
# Urb Estancias Villa Alba
# Urb Extension Jardinesvilla Alba
# Urb Extension San Jose
# Urb Extension San Jose II
# Urb Extension San Jose III
# Urb Jose Palou Castro
# Urb La Alborada
# Urb La Milagrosa
# Urb La Quinta
# Urb Las Palmas
# Urb Mansiones De Sabana Grande
# Urb Pagan
# Urb Palacious del Lago
# Urb Praderas del Rio Flores
# Urb Ramos
# Urb Rivera
# Urb San Antonio
# Urb San Jose
# Urb Sand Andrez
# Urb Santa Ana
# Urb Santa Elena
# Urb Valles del Lago
# Urb Verde Luz
# Urb Villa Alba
# Urb la Arboleda
# Urb. Arboleda
# Urb. Brisa Tropical
# Urb. Ceero Gordo Hills
# Urb. Cielo Dorado
# Urb. Coconut Court
# Urb. Country Club
# Urb. Fajardo Gardens
# Urb. Gran Vista 2
# Urb. Grand Palm
# Urb. John Díaz
# Urb. La Pradera
# Urb. La Vista
# Urb. Las Flores
# Urb. Las Palmas de Cerro Gordo
# Urb. Llanos de Providencia
# Urb. Lucina Franco
# Urb. Paraiso de Mayaguez
# Urb. Portofino
# Urb. Praderas del Sur
# Urb. Prados de Salinas
# Urb. Rexmanor
# Urb. Roosevelt Gardens
# Urb. San Martín
# Urb. Toaville
# Urb. Treasure Point
# Urb. Vega Dorada
# Urb. Velomas
# Urb. Villa Pinares
# Urb. Villas del Rio
# Urb. Vista del Sol
# Urban San Juan
# Urban lot
# Urbanizacion Borinquen
# Urbanizacion Mayaguez Terrace
# Urbanización Altos de San Luis
# Urbanización Altos de la Fuente
# Urbanización Alturas de Beatriz
# Urbanización Alturas de Borinquen/Padre Miguel
# Urbanización Alturas de Caguas (Beatriz)
# Urbanización Alturas de Caguas (Borinquen)
# Urbanización Alturas de Villa del Rey
# Urbanización Arbolada
# Urbanización Baco
# Urbanización Bairoa I
# Urbanización Bairoa II
# Urbanización Bairoa Park
# Urbanización Baldrich
# Urbanización Batista
# Urbanización Bonneville Gardens
# Urbanización Bonneville Hgts. II
# Urbanización Bonneville Manor
# Urbanización Bonneville Terrace
# Urbanización Bonneville Valley
# Urbanización Borinquen Valley
# Urbanización Bosque Verde
# Urbanización Bosques de La Sierra
# Urbanización Brisas del Monte/Parcelas Nuevas
# Urbanización Brisas del Parque
# Urbanización Brisas del Parque II
# Urbanización Caguas Milenio I
# Urbanización Caguas Milenio II
# Urbanización Caguas Norte
# Urbanización Caguas Real
# Urbanización Camino Real
# Urbanización Campo Chico
# Urbanización Campo Real
# Urbanización Caribe Gardens
# Urbanización Chalets de Bairoa
# Urbanización Ciudad Jardín
# Urbanización Colinas de Villa Coquí
# Urbanización Condado
# Urbanización Condado Moderno
# Urbanización Crown Hills
# Urbanización Diamond Village
# Urbanización E. González
# Urbanización El Cerezal
# Urbanización El Conquistador
# Urbanización El Edén
# Urbanización El Escorial
# Urbanización El Paraíso
# Urbanización El Real
# Urbanización El Remanso
# Urbanización El Retiro
# Urbanización El Señorial
# Urbanización El Valle
# Urbanización El Vedado
# Urbanización El Verde Sur
# Urbanización Estancias Degetau
# Urbanización Estancias La Sierra
# Urbanización Estancias de Bairoa
# Urbanización Estancias de Santa Teresa
# Urbanización Estancias del Bosque
# Urbanización Estancias del Lago
# Urbanización Estancias del Turabo
# Urbanización Estancias del Verde
# Urbanización Floral Park
# Urbanización Golden Gate I
# Urbanización Golden Gate II
# Urbanización Hacienda Borinquen
# Urbanización Hacienda Lilimar
# Urbanización Haciendas del Rey
# Urbanización Hillside
# Urbanización Huyke
# Urbanización Hyde Park
# Urbanización Húcares
# Urbanización Idamaris Gardens
# Urbanización Jardines Metropolitanos
# Urbanización Jardines de Caguas
# Urbanización La Cima
# Urbanización La Concepción
# Urbanización La Reserva
# Urbanización La Serranía
# Urbanización La Sierra
# Urbanización La Sierra Alta
# Urbanización La Sierra del Río
# Urbanización Lakeview Estates
# Urbanización Las Colinas
# Urbanización Las Flores de Montehiedra
# Urbanización Las Haciendas
# Urbanización Lomas de La Serrania
# Urbanización Los Ayala
# Urbanización Los Maestros
# Urbanización Los Serrano
# Urbanización Los Árboles de Montehiedra
# Urbanización Machín
# Urbanización Mansiones de Bairoa
# Urbanización Mansiones del Golf
# Urbanización Mansiones del Paraíso
# Urbanización Mirador de Bairoa
# Urbanización Montebrisas
# Urbanización Monticelo
# Urbanización Montifiori
# Urbanización Myrlena
# Urbanización Nazario
# Urbanización Ocean Park
# Urbanización Palmas del Turabo
# Urbanización Paradis
# Urbanización Parque Las Haciendas
# Urbanización Parque Las Mercedes
# Urbanización Parque del Monte
# Urbanización Parque del Río
# Urbanización Paseo del Mar 2
# Urbanización Paseo del Río
# Urbanización Quintas de San Luis
# Urbanización Quintas de San Luis II
# Urbanización Quintas de las Américas
# Urbanización Quinto Centenario
# Urbanización Reparto Aldrich
# Urbanización Reparto San José
# Urbanización Ricón de La Serrania
# Urbanización Roosevelt
# Urbanización Río Piedras Heights
# Urbanización Río Piedras Valley
# Urbanización San Alfonso
# Urbanización San Antonio
# Urbanización San Francisco
# Urbanización San Gerardo
# Urbanización San Ignacio
# Urbanización San Pedro Estates
# Urbanización San Rafael
# Urbanización Santa Ana
# Urbanización Santa Cecilia
# Urbanización Santa Clara
# Urbanización Santa Juana I y II
# Urbanización Santa Juana III
# Urbanización Santa Juana IV
# Urbanización Santa María
# Urbanización Santa Rosa
# Urbanización Santiago Iglesias Pantín
# Urbanización Santo Domingo
# Urbanización Terralinda
# Urbanización Terrazas de Borinquen
# Urbanización Turabo Gardens 1ra, 2da, 3ra Sec.
# Urbanización Turabo Gardens 4ta Sec.
# Urbanización Turabo Gardens 5ta Sec.
# Urbanización Twin Valley
# Urbanización University Gardens
# Urbanización Urb. Jiménez Rosa
# Urbanización Urb. Las Carolinas
# Urbanización Urb. Los Pinos
# Urbanización Valle Hermoso
# Urbanización Valle San Luis
# Urbanización Valle Tolima
# Urbanización Valle Verde
# Urbanización Valle del Lago
# Urbanización Valley View Park
# Urbanización Villa Blanca
# Urbanización Villa Borinquen
# Urbanización Villa Cáliz I
# Urbanización Villa Cáliz II
# Urbanización Villa Esperanza
# Urbanización Villa Flores
# Urbanización Villa Guadalupe
# Urbanización Villa Hermosa
# Urbanización Villa Las Mercedes
# Urbanización Villa María
# Urbanización Villa Nevárez
# Urbanización Villa Nueva
# Urbanización Villa Olga
# Urbanización Villa Turabo
# Urbanización Villa Victoria
# Urbanización Villa del Rey 1ra Sec.
# Urbanización Villa del Rey 3ra Sec.
# Urbanización Villa del Rey 4ta Sec.
# Urbanización Villa del Rey 5ta Sec.
# Urbanización Villas Saurí
# Urbanización Villas de Castro
# Urbanización Villas de Oro
# Urbanización Villas de Paraná
# Urbanización Villas de San Francisco
# Urbanización Villas de San Ignacio
# Urbanización Villas del Río Verde
# Urbanización Vistas De Coamo
# Urbanization Villa Del Carmen
# Yauco Urban Park

# %% [markdown]
# This looks good! It includes a lot of housing complexes that were unavailable in the Wiki lexicon.

# %% [markdown]
# We should still filter out the short stuff.

# %%
min_char_len = 4
OSM_lexicon = filter(lambda x: len(x) >= min_char_len, OSM_lexicon)

# %% [markdown]
# ## Test on annotations

# %% [markdown]
# Let's apply it to the whole annotated dataset and see what happens.

# %%
import codecs
import data_helpers
reload(data_helpers)
from data_helpers import extract_annotations
annotated_file_name = '../../data/facebook-maria/1773209126315380_post_sample_annotated_wiki.txt'
N = 249
all_annotations = extract_annotations(annotated_file_name)
gold_annotations = all_annotations[:N]
print(gold_annotations[:10])
# Out:
# [[(u'Guayama', u'https://en.wikipedia.org/wiki/Guayama,_Puerto_Rico')], [(u'olimpo', u'NIL'), (u'calle 6', u'NIL'), (u'calle 8', u'NIL')], [(u'Guayama', u'https://en.wikipedia.org/wiki/Guayama,_Puerto_Rico'), (u'residencial Villamar', u'NIL')], [(u'Guayama', u'https://en.wikipedia.org/wiki/Guayama,_Puerto_Rico'), (u'Carite', u'NIL')], [(u'calle 54', u'NIL')], [(u'Guayma', u'https://en.wikipedia.org/wiki/Guayama,_Puerto_Rico'), (u'villa Rosa', u'NIL'), (u'calle 2', u'NIL')], [(u'Guayama URB', u'https://en.wikipedia.org/wiki/Guayama,_Puerto_Rico'), (u'Hacienda AS', u'NIL'), (u'19 Calle', u'NIL')], [], [], [(u'barrio mosquito', u'https://es.wikipedia.org/wiki/Mosquito_(Vieques)')]]

# %% [markdown]
# Convert raw text to DTM for easy computation.

# %%
raw_file_name = '../../data/facebook-maria/1773209126315380_post_sample_txt.txt'
raw_txt = [l.strip() for l in codecs.open(raw_file_name, 'r', encoding='utf-8')][:N]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize.casual import TweetTokenizer
min_df = 1
tokenizer = TweetTokenizer()
ngram_range = (1,5)
cv = CountVectorizer(min_df=min_df, tokenizer=tokenizer.tokenize, ngram_range=ngram_range, lowercase=True)
dtm = cv.fit_transform(raw_txt)
ivoc = {v : k for k,v in cv.vocabulary_.iteritems()}
print(dtm.shape)
# Out:
# (249, 45120)

# %%
from itertools import izip
from collections import defaultdict
nonzero_row_cols = dtm.tocoo().nonzero()
ngrams_per_line = defaultdict(list)
for row, col in izip(nonzero_row_cols[0], nonzero_row_cols[1]):
    col_entity = ivoc[col]
    ngrams_per_line[row].append(col_entity)
# convert to list of lists
ngrams_per_line = [ngrams_per_line[n] for n in range(N)]

# %%
OSM_lexicon_lower = set(map(lambda x: x.lower(), OSM_lexicon))
print('%d lowercased OSM lexicon'%(len(OSM_lexicon_lower)))
# Out:
# 26072 lowercased OSM lexicon

# %%
test_word = 'olimpo'
print(filter(lambda x: test_word in x, OSM_lexicon_lower))
# Out:
# [u'olimpo court hotel', u'calle olimpo', u'calle monte olimpo', u'olimpo court hotel parking']

# %%
# look for overlap
OSM_lexicon_per_line = [list(OSM_lexicon_lower & set(l)) for l in ngrams_per_line]
print(OSM_lexicon_per_line[:10])
# Out:
# [[u'guayama'], [u'calle', u'calle 8', u'calle 6', u'arroyo'], [u'villamar', u'guayama'], [u'claro', u'guayama'], [u'calle', u'la hacienda', u'calle 54', u'marta'], [u'calle 2', u'calle', u'villa rosa', u'acosta'], [u'calle', u'calle 46', u'guayama'], [u'mar\xeda'], [], []]

# %% [markdown]
# What is the precision/recall of these extracted locations?

# %%
gold_annotations_txt = map(lambda x: map(lambda y: y[0], x), gold_annotations)
gold_annotations_txt_lower = map(lambda x: map(lambda y: y.lower(), x), gold_annotations_txt)
print(gold_annotations_txt_lower[:10])
# Out:
# [[u'guayama'], [u'olimpo', u'calle 6', u'calle 8'], [u'guayama', u'residencial villamar'], [u'guayama', u'carite'], [u'calle 54'], [u'guayma', u'villa rosa', u'calle 2'], [u'guayama urb', u'hacienda as', u'19 calle'], [], [], [u'barrio mosquito']]

# %%
print(len(gold_annotations_txt))
print(len(OSM_lexicon_per_line))
# Out:
# 249
# 249

# %%
import data_helpers
reload(data_helpers)
from data_helpers import test_precision_recall
false_tags, missed_tags, precision, recall = test_precision_recall(OSM_lexicon_per_line, gold_annotations_txt_lower)
print('OSM lexicon gets precision=%.3f, recall=%.3f'%(precision, recall))
# Out:
# OSM lexicon gets precision=0.347, recall=0.452

# %% [markdown]
# Performance is between the earlier NER and lexicon results that we found (lexicon had high recall and low precision, NER had low recall and higher precision).

# %%
print(false_tags[:100])
print(missed_tags[:100])
# Out:
# [[], [u'calle', u'arroyo'], [u'villamar'], [u'claro'], [u'calle', u'la hacienda', u'marta'], [u'calle', u'acosta'], [u'calle', u'calle 46', u'guayama'], [u'mar\xeda'], [], [], [], [], [u'la principal', u'mar\xeda', u'principal'], [], [u'margarita'], [u'mercado', u'pueblo', u'pl\xe1tano'], [], [u'guayama'], [], [], [], [u'pueblo'], [], [u'calle'], [], [], [u'tel\xe9fonos'], [], [], [u'jardines'], [u'guayama'], [], [], [], [u'guayama'], [], [u'jardines'], [], [u'palmas'], [u'san juan', u'marginal', u'calle 615', u'los dominicos', u'flamboy\xe1n', u'rexville', u'calle aracibo', u'calle morales', u'ponce', u'pharmacy', u'calle gautier ben\xedtez', u'puerto rico', u'jardines', u'calle navarra', u'carolina', u'buildings', u'calle 2', u'encantada', u'san jose', u'calle igualdad', u'pueblo', u'vidal', u'plaza victoria', u'calle casia', u'farmacia', u'burger king', u'calle', u'hostos', u'calle obispado', u'calle villa', u'aguadilla'], [], [], [u'mercado'], [u'school'], [], [], [u'calle', u'entrada'], [u'jardines'], [], [], [], [], [u'correo'], [u'caribe'], [], [], [], [], [], [], [], [u'parque'], [], [u'calle'], [], [u'correo', u'pueblo', u'post office'], [], [], [u'fajardo'], [], [], [], [], [u'calle'], [u'mayag\xfcez'], [], [], [], [u'escuela'], [], [u'puerto rico'], [u'la familia'], [], [], [u'la familia'], [], [], [], [], [], [], [], [], [u'la respuesta'], [], [], [], [], [], []]
# [[], [u'olimpo'], [u'residencial villamar'], [u'carite'], [], [u'guayma'], [u'hacienda as', u'guayama urb', u'19 calle'], [], [], [u'barrio mosquito'], [u'vives'], [u'guamani'], [], [], [u'cariterguayama'], [], [], [], [], [], [u'la carr 15', u'la gran parada'], [u'eu'], [u'borinquen'], [u'guayma'], [u'new york', u'guyama'], [], [u'pto rico'], [], [u'las mareas'], [u'jardines de guamani'], [u'pr', u'bomberos de guayama'], [u'cimarrona'], [], [], [u'la plaza de guayama'], [], [u'jardines de guamani', u'cimarrona'], [u'blondet'], [u'costa azul', u'olimpo', u'palmas bajas'], [u'ave pedro albizu campos', u'rexville plaza', u'calle san millan', u'calle morales bo hato tejas', u'ave. de diego', u'ave magnolia', u'carolina shoppin ctr'], [], [], [], [u'reparto la sabana', u'pueblito del carmen'], [u'borinquen'], [], [u'calle santa balbara'], [u'jardines de guamani'], [], [], [], [u'santa ana'], [], [u'villa caribe', u'calimano'], [], [], [], [], [], [], [], [], [], [], [u'barrio branderi'], [u'estados unidos', u'puerto rico'], [], [], [u'barranca', u'urb vives'], [], [], [], [], [u'santa ana'], [u'yauco'], [], [u'bda santa ana'], [], [u'blondet'], [], [u'pr'], [u'gauayama'], [], [u'la puente'], [u'olimpo'], [u'barrio olimpo', u'santa catalinas'], [], [], [], [], [], [u'olimpo', u'casa paola'], [], [], [u'isla del encanto'], [], [u'pr', u'st lancaster', u'philadelphia pa', u'pensylvannia', u'n.  marshall st', u'wingohoking st'], [], [u'estados unidos'], [u'barrio olimpo']]

# %% [markdown]
# At first glance, it looks like the lexicon overgenerated the obvious locations (`Guayama`) and undergenerated some highly obscure locations (`calle san millan`) as well as coarse-grained entities like neighborhoods (`santa ana`) and countries (`pr`).

# %% [markdown]
# ## Utility of OSM data?
# Ideally we would use the OSM data as targets for the entities, to compensate for the lack of fine-grained entities in Wikipedia. We might need to test on a larger dataset that has more labels, because 250 is not a big number and we need properly agreed-upon labels from annotators.
