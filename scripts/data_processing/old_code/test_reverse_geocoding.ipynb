# %% [markdown]
# # Test reverse geocoding
# In which we try to reverse-geocode locations through Google's API.

# %%
import geocoder
from time import sleep
from json import dumps

# %%
SLEEP_TIME = 5
test_location = 'San Juan'
g = geocoder.google(test_location)
while(not g.ok):
    sleep(SLEEP_TIME)
    g = geocoder.google(test_location)
print(g)
print(dumps(g.geojson, indent=4, sort_keys=True))
# Out:
# <[OK] Google - Geocode [San Juan, Puerto Rico]>
# {
#     "features": [
#         {
#             "bbox": [
#                 -66.1294029,
#                 18.297648,
#                 -65.991542,
#                 18.4808269
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -66.1057355,
#                     18.4655394
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "accuracy": "APPROXIMATE",
#                 "address": "San Juan, Puerto Rico",
#                 "bbox": [
#                     -66.1294029,
#                     18.297648,
#                     -65.991542,
#                     18.4808269
#                 ],
#                 "city": "San Juan",
#                 "confidence": 1,
#                 "country": "PR",
#                 "lat": 18.4655394,
#                 "lng": -66.1057355,
#                 "ok": true,
#                 "place": "ChIJbxlo4m9oA4wR3FqTXA9_a60",
#                 "quality": "locality",
#                 "raw": {
#                     "address_components": [
#                         {
#                             "long_name": "San Juan",
#                             "short_name": "San Juan",
#                             "types": [
#                                 "locality",
#                                 "political"
#                             ]
#                         },
#                         {
#                             "long_name": "San Juan",
#                             "short_name": "San Juan",
#                             "types": [
#                                 "administrative_area_level_1",
#                                 "political"
#                             ]
#                         },
#                         {
#                             "long_name": "Puerto Rico",
#                             "short_name": "PR",
#                             "types": [
#                                 "country",
#                                 "political"
#                             ]
#                         }
#                     ],
#                     "administrative_area_level_1": {
#                         "long_name": "San Juan",
#                         "short_name": "San Juan"
#                     },
#                     "country": {
#                         "long_name": "Puerto Rico",
#                         "short_name": "PR"
#                     },
#                     "formatted_address": "San Juan, Puerto Rico",
#                     "geometry": {
#                         "bounds": {
#                             "northeast": {
#                                 "lat": 18.4808269,
#                                 "lng": -65.991542
#                             },
#                             "southwest": {
#                                 "lat": 18.297648,
#                                 "lng": -66.1294029
#                             }
#                         },
#                         "location": {
#                             "lat": 18.4655394,
#                             "lng": -66.1057355
#                         },
#                         "location_type": "APPROXIMATE",
#                         "viewport": {
#                             "northeast": {
#                                 "lat": 18.4808269,
#                                 "lng": -65.991542
#                             },
#                             "southwest": {
#                                 "lat": 18.297648,
#                                 "lng": -66.1294029
#                             }
#                         }
#                     },
#                     "locality": {
#                         "long_name": "San Juan",
#                         "short_name": "San Juan"
#                     },
#                     "place_id": "ChIJbxlo4m9oA4wR3FqTXA9_a60",
#                     "political": {
#                         "long_name": "Puerto Rico",
#                         "short_name": "PR"
#                     },
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 "state": "San Juan",
#                 "status": "OK"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %% [markdown]
# For an ambiguous name like `San Juan`, we see that the geocoder yields the most likely according to popularity.

# %%
SLEEP_TIME = 5
def get_location(loc_name):
    g = geocoder.google(loc_name)
    while(not g.ok):
        sleep(SLEEP_TIME)
        g = geocoder.google(loc_name)
    return g

# %%
test_locations = ['Houston', 'Rockport', 'Palm Beach', 'Washington, D.C.']
for l in test_locations:
    g_loc = get_location(l)
    g_json = g_loc.geojson['features'][0]['properties']
    print('location string %s => %s'%
          (l, dumps(g_json, indent=2, sort_keys=True)))
# Out:
# location string Houston => {
#   "accuracy": "APPROXIMATE",
#   "address": "Houston, TX, USA",
#   "bbox": [
#     -95.78808690000001,
#     29.523624,
#     -95.014496,
#     30.1107319
#   ],
#   "city": "Houston",
#   "confidence": 1,
#   "country": "US",
#   "county": "Harris County",
#   "lat": 29.7604267,
#   "lng": -95.3698028,
#   "ok": true,
#   "place": "ChIJAYWNSLS4QIYROwVl894CDco",
#   "quality": "locality",
#   "raw": {
#     "address_components": [
#       {
#         "long_name": "Houston",
#         "short_name": "Houston",
#         "types": [
#           "locality",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Harris County",
#         "short_name": "Harris County",
#         "types": [
#           "administrative_area_level_2",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Texas",
#         "short_name": "TX",
#         "types": [
#           "administrative_area_level_1",
#           "political"
#         ]
#       },
#       {
#         "long_name": "United States",
#         "short_name": "US",
#         "types": [
#           "country",
#           "political"
#         ]
#       }
#     ],
#     "administrative_area_level_1": {
#       "long_name": "Texas",
#       "short_name": "TX"
#     },
#     "administrative_area_level_2": {
#       "long_name": "Harris County",
#       "short_name": "Harris County"
#     },
#     "country": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "formatted_address": "Houston, TX, USA",
#     "geometry": {
#       "bounds": {
#         "northeast": {
#           "lat": 30.1107319,
#           "lng": -95.014496
#         },
#         "southwest": {
#           "lat": 29.523624,
#           "lng": -95.78808690000001
#         }
#       },
#       "location": {
#         "lat": 29.7604267,
#         "lng": -95.3698028
#       },
#       "location_type": "APPROXIMATE",
#       "viewport": {
#         "northeast": {
#           "lat": 30.1107319,
#           "lng": -95.014496
#         },
#         "southwest": {
#           "lat": 29.523624,
#           "lng": -95.78808690000001
#         }
#       }
#     },
#     "locality": {
#       "long_name": "Houston",
#       "short_name": "Houston"
#     },
#     "place_id": "ChIJAYWNSLS4QIYROwVl894CDco",
#     "political": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "types": [
#       "locality",
#       "political"
#     ]
#   },
#   "state": "TX",
#   "status": "OK"
# }
# location string Rockport => {
#   "accuracy": "APPROXIMATE",
#   "address": "Rockport, TX 78382, USA",
#   "bbox": [
#     -97.0920938,
#     27.966293,
#     -96.99951999999999,
#     28.0874909
#   ],
#   "city": "Rockport",
#   "confidence": 3,
#   "country": "US",
#   "county": "Aransas County",
#   "lat": 28.0205733,
#   "lng": -97.0544341,
#   "ok": true,
#   "place": "ChIJhxNx92CzaYYRHJaDCjYg6mw",
#   "postal": "78382",
#   "quality": "locality",
#   "raw": {
#     "address_components": [
#       {
#         "long_name": "Rockport",
#         "short_name": "Rockport",
#         "types": [
#           "locality",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Aransas County",
#         "short_name": "Aransas County",
#         "types": [
#           "administrative_area_level_2",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Texas",
#         "short_name": "TX",
#         "types": [
#           "administrative_area_level_1",
#           "political"
#         ]
#       },
#       {
#         "long_name": "United States",
#         "short_name": "US",
#         "types": [
#           "country",
#           "political"
#         ]
#       },
#       {
#         "long_name": "78382",
#         "short_name": "78382",
#         "types": [
#           "postal_code"
#         ]
#       }
#     ],
#     "administrative_area_level_1": {
#       "long_name": "Texas",
#       "short_name": "TX"
#     },
#     "administrative_area_level_2": {
#       "long_name": "Aransas County",
#       "short_name": "Aransas County"
#     },
#     "country": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "formatted_address": "Rockport, TX 78382, USA",
#     "geometry": {
#       "bounds": {
#         "northeast": {
#           "lat": 28.0874909,
#           "lng": -96.99951999999999
#         },
#         "southwest": {
#           "lat": 27.966293,
#           "lng": -97.0920938
#         }
#       },
#       "location": {
#         "lat": 28.0205733,
#         "lng": -97.0544341
#       },
#       "location_type": "APPROXIMATE",
#       "viewport": {
#         "northeast": {
#           "lat": 28.0874909,
#           "lng": -96.99951999999999
#         },
#         "southwest": {
#           "lat": 27.966293,
#           "lng": -97.0920938
#         }
#       }
#     },
#     "locality": {
#       "long_name": "Rockport",
#       "short_name": "Rockport"
#     },
#     "place_id": "ChIJhxNx92CzaYYRHJaDCjYg6mw",
#     "political": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "postal_code": {
#       "long_name": "78382",
#       "short_name": "78382"
#     },
#     "types": [
#       "locality",
#       "political"
#     ]
#   },
#   "state": "TX",
#   "status": "OK"
# }
# location string Palm Beach => {
#   "accuracy": "APPROXIMATE",
#   "address": "Palm Beach, FL, USA",
#   "bbox": [
#     -80.0490629,
#     26.594181,
#     -80.030362,
#     26.7730349
#   ],
#   "city": "Palm Beach",
#   "confidence": 3,
#   "country": "US",
#   "county": "Palm Beach County",
#   "lat": 26.7056206,
#   "lng": -80.0364297,
#   "ok": true,
#   "place": "ChIJhzdSGPbW2IgRGkem18eSoDs",
#   "quality": "locality",
#   "raw": {
#     "address_components": [
#       {
#         "long_name": "Palm Beach",
#         "short_name": "Palm Beach",
#         "types": [
#           "locality",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Palm Beach County",
#         "short_name": "Palm Beach County",
#         "types": [
#           "administrative_area_level_2",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Florida",
#         "short_name": "FL",
#         "types": [
#           "administrative_area_level_1",
#           "political"
#         ]
#       },
#       {
#         "long_name": "United States",
#         "short_name": "US",
#         "types": [
#           "country",
#           "political"
#         ]
#       }
#     ],
#     "administrative_area_level_1": {
#       "long_name": "Florida",
#       "short_name": "FL"
#     },
#     "administrative_area_level_2": {
#       "long_name": "Palm Beach County",
#       "short_name": "Palm Beach County"
#     },
#     "country": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "formatted_address": "Palm Beach, FL, USA",
#     "geometry": {
#       "bounds": {
#         "northeast": {
#           "lat": 26.7730349,
#           "lng": -80.030362
#         },
#         "southwest": {
#           "lat": 26.594181,
#           "lng": -80.0490629
#         }
#       },
#       "location": {
#         "lat": 26.7056206,
#         "lng": -80.0364297
#       },
#       "location_type": "APPROXIMATE",
#       "viewport": {
#         "northeast": {
#           "lat": 26.7730349,
#           "lng": -80.030362
#         },
#         "southwest": {
#           "lat": 26.594181,
#           "lng": -80.0490629
#         }
#       }
#     },
#     "locality": {
#       "long_name": "Palm Beach",
#       "short_name": "Palm Beach"
#     },
#     "place_id": "ChIJhzdSGPbW2IgRGkem18eSoDs",
#     "political": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "types": [
#       "locality",
#       "political"
#     ]
#   },
#   "state": "FL",
#   "status": "OK"
# }
# location string Washington, D.C. => {
#   "accuracy": "APPROXIMATE",
#   "address": "Washington, DC, USA",
#   "bbox": [
#     -77.119759,
#     38.7916449,
#     -76.909393,
#     38.995548
#   ],
#   "city": "Washington",
#   "confidence": 1,
#   "country": "US",
#   "county": "District of Columbia",
#   "lat": 38.9071923,
#   "lng": -77.0368707,
#   "ok": true,
#   "place": "ChIJW-T2Wt7Gt4kRKl2I1CJFUsI",
#   "quality": "locality",
#   "raw": {
#     "address_components": [
#       {
#         "long_name": "Washington",
#         "short_name": "Washington",
#         "types": [
#           "locality",
#           "political"
#         ]
#       },
#       {
#         "long_name": "District of Columbia",
#         "short_name": "District of Columbia",
#         "types": [
#           "administrative_area_level_2",
#           "political"
#         ]
#       },
#       {
#         "long_name": "District of Columbia",
#         "short_name": "DC",
#         "types": [
#           "administrative_area_level_1",
#           "political"
#         ]
#       },
#       {
#         "long_name": "United States",
#         "short_name": "US",
#         "types": [
#           "country",
#           "political"
#         ]
#       }
#     ],
#     "administrative_area_level_1": {
#       "long_name": "District of Columbia",
#       "short_name": "DC"
#     },
#     "administrative_area_level_2": {
#       "long_name": "District of Columbia",
#       "short_name": "District of Columbia"
#     },
#     "country": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "formatted_address": "Washington, DC, USA",
#     "geometry": {
#       "bounds": {
#         "northeast": {
#           "lat": 38.995548,
#           "lng": -76.909393
#         },
#         "southwest": {
#           "lat": 38.7916449,
#           "lng": -77.119759
#         }
#       },
#       "location": {
#         "lat": 38.9071923,
#         "lng": -77.0368707
#       },
#       "location_type": "APPROXIMATE",
#       "viewport": {
#         "northeast": {
#           "lat": 38.995548,
#           "lng": -76.909393
#         },
#         "southwest": {
#           "lat": 38.7916449,
#           "lng": -77.119759
#         }
#       }
#     },
#     "locality": {
#       "long_name": "Washington",
#       "short_name": "Washington"
#     },
#     "place_id": "ChIJW-T2Wt7Gt4kRKl2I1CJFUsI",
#     "political": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "types": [
#       "locality",
#       "political"
#     ]
#   },
#   "state": "DC",
#   "status": "OK"
# }

# %% [markdown]
# All of these locations have "approximate" accuracy but for the most part they're pretty accurate.

# %% [markdown]
# What about street-level locations?

# %%
test_locations = ['Union Square', '5th Street', 'Peachtree Street']
for l in test_locations:
    g_loc = get_location(l)
    g_json = g_loc.geojson['features'][0]['properties']
    print('location string %s => %s'%
          (l, dumps(g_json, indent=2, sort_keys=True)))
# Out:
# location string Union Square => {
#   "accuracy": "APPROXIMATE",
#   "address": "Union Square, New York, NY 10003, USA",
#   "bbox": [
#     -73.993641,
#     40.733992,
#     -73.98697609999999,
#     40.7385105
#   ],
#   "city": "New York",
#   "confidence": 8,
#   "country": "US",
#   "county": "New York County",
#   "lat": 40.7358633,
#   "lng": -73.9910835,
#   "neighborhood": "Union Square",
#   "ok": true,
#   "place": "ChIJi6oUnphZwokRpMog28mvAM0",
#   "postal": "10003",
#   "quality": "neighborhood",
#   "raw": {
#     "address_components": [
#       {
#         "long_name": "Union Square",
#         "short_name": "Union Square",
#         "types": [
#           "neighborhood",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Manhattan",
#         "short_name": "Manhattan",
#         "types": [
#           "political",
#           "sublocality",
#           "sublocality_level_1"
#         ]
#       },
#       {
#         "long_name": "New York",
#         "short_name": "New York",
#         "types": [
#           "locality",
#           "political"
#         ]
#       },
#       {
#         "long_name": "New York County",
#         "short_name": "New York County",
#         "types": [
#           "administrative_area_level_2",
#           "political"
#         ]
#       },
#       {
#         "long_name": "New York",
#         "short_name": "NY",
#         "types": [
#           "administrative_area_level_1",
#           "political"
#         ]
#       },
#       {
#         "long_name": "United States",
#         "short_name": "US",
#         "types": [
#           "country",
#           "political"
#         ]
#       },
#       {
#         "long_name": "10003",
#         "short_name": "10003",
#         "types": [
#           "postal_code"
#         ]
#       }
#     ],
#     "administrative_area_level_1": {
#       "long_name": "New York",
#       "short_name": "NY"
#     },
#     "administrative_area_level_2": {
#       "long_name": "New York County",
#       "short_name": "New York County"
#     },
#     "country": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "formatted_address": "Union Square, New York, NY 10003, USA",
#     "geometry": {
#       "bounds": {
#         "northeast": {
#           "lat": 40.7385105,
#           "lng": -73.98697609999999
#         },
#         "southwest": {
#           "lat": 40.733992,
#           "lng": -73.993641
#         }
#       },
#       "location": {
#         "lat": 40.7358633,
#         "lng": -73.9910835
#       },
#       "location_type": "APPROXIMATE",
#       "viewport": {
#         "northeast": {
#           "lat": 40.7385105,
#           "lng": -73.98697609999999
#         },
#         "southwest": {
#           "lat": 40.733992,
#           "lng": -73.993641
#         }
#       }
#     },
#     "locality": {
#       "long_name": "New York",
#       "short_name": "New York"
#     },
#     "neighborhood": {
#       "long_name": "Union Square",
#       "short_name": "Union Square"
#     },
#     "place_id": "ChIJi6oUnphZwokRpMog28mvAM0",
#     "political": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "postal_code": {
#       "long_name": "10003",
#       "short_name": "10003"
#     },
#     "sublocality": {
#       "long_name": "Manhattan",
#       "short_name": "Manhattan"
#     },
#     "sublocality_level_1": {
#       "long_name": "Manhattan",
#       "short_name": "Manhattan"
#     },
#     "types": [
#       "neighborhood",
#       "political"
#     ]
#   },
#   "state": "NY",
#   "status": "OK",
#   "sublocality": "Manhattan"
# }
# location string 5th Street => {
#   "accuracy": "GEOMETRIC_CENTER",
#   "address": "5th St, Miami Beach, FL 33139, USA",
#   "bbox": [
#     -80.141851,
#     25.7732969197085,
#     -80.1311099,
#     25.7759948802915
#   ],
#   "city": "Miami Beach",
#   "confidence": 7,
#   "country": "US",
#   "county": "Miami-Dade County",
#   "lat": 25.7745796,
#   "lng": -80.1364921,
#   "ok": true,
#   "place": "ChIJieU5ZfO02YgRe6kzNzfVR54",
#   "postal": "33139",
#   "quality": "route",
#   "raw": {
#     "address_components": [
#       {
#         "long_name": "5th Street",
#         "short_name": "5th St",
#         "types": [
#           "route"
#         ]
#       },
#       {
#         "long_name": "Miami Beach",
#         "short_name": "Miami Beach",
#         "types": [
#           "locality",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Miami-Dade County",
#         "short_name": "Miami-Dade County",
#         "types": [
#           "administrative_area_level_2",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Florida",
#         "short_name": "FL",
#         "types": [
#           "administrative_area_level_1",
#           "political"
#         ]
#       },
#       {
#         "long_name": "United States",
#         "short_name": "US",
#         "types": [
#           "country",
#           "political"
#         ]
#       },
#       {
#         "long_name": "33139",
#         "short_name": "33139",
#         "types": [
#           "postal_code"
#         ]
#       }
#     ],
#     "administrative_area_level_1": {
#       "long_name": "Florida",
#       "short_name": "FL"
#     },
#     "administrative_area_level_2": {
#       "long_name": "Miami-Dade County",
#       "short_name": "Miami-Dade County"
#     },
#     "country": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "formatted_address": "5th St, Miami Beach, FL 33139, USA",
#     "geometry": {
#       "bounds": {
#         "northeast": {
#           "lat": 25.7756643,
#           "lng": -80.1311099
#         },
#         "southwest": {
#           "lat": 25.7736275,
#           "lng": -80.141851
#         }
#       },
#       "location": {
#         "lat": 25.7745796,
#         "lng": -80.1364921
#       },
#       "location_type": "GEOMETRIC_CENTER",
#       "viewport": {
#         "northeast": {
#           "lat": 25.7759948802915,
#           "lng": -80.1311099
#         },
#         "southwest": {
#           "lat": 25.7732969197085,
#           "lng": -80.141851
#         }
#       }
#     },
#     "locality": {
#       "long_name": "Miami Beach",
#       "short_name": "Miami Beach"
#     },
#     "place_id": "ChIJieU5ZfO02YgRe6kzNzfVR54",
#     "political": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "postal_code": {
#       "long_name": "33139",
#       "short_name": "33139"
#     },
#     "route": {
#       "long_name": "5th Street",
#       "short_name": "5th St"
#     },
#     "types": [
#       "route"
#     ]
#   },
#   "state": "FL",
#   "status": "OK",
#   "street": "5th St"
# }
# location string Peachtree Street => {
#   "accuracy": "GEOMETRIC_CENTER",
#   "address": "Peachtree St, Jackson, MS, USA",
#   "bbox": [
#     -90.172117,
#     32.3156323,
#     -90.16934719999999,
#     32.3310641
#   ],
#   "city": "Jackson",
#   "confidence": 7,
#   "country": "US",
#   "county": "Hinds County",
#   "lat": 32.3233451,
#   "lng": -90.1710739,
#   "ok": true,
#   "place": "ChIJYacFbvIyKIYR2lsVeg3wZr0",
#   "quality": "route",
#   "raw": {
#     "address_components": [
#       {
#         "long_name": "Peachtree Street",
#         "short_name": "Peachtree St",
#         "types": [
#           "route"
#         ]
#       },
#       {
#         "long_name": "Jackson",
#         "short_name": "Jackson",
#         "types": [
#           "locality",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Hinds County",
#         "short_name": "Hinds County",
#         "types": [
#           "administrative_area_level_2",
#           "political"
#         ]
#       },
#       {
#         "long_name": "Mississippi",
#         "short_name": "MS",
#         "types": [
#           "administrative_area_level_1",
#           "political"
#         ]
#       },
#       {
#         "long_name": "United States",
#         "short_name": "US",
#         "types": [
#           "country",
#           "political"
#         ]
#       }
#     ],
#     "administrative_area_level_1": {
#       "long_name": "Mississippi",
#       "short_name": "MS"
#     },
#     "administrative_area_level_2": {
#       "long_name": "Hinds County",
#       "short_name": "Hinds County"
#     },
#     "country": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "formatted_address": "Peachtree St, Jackson, MS, USA",
#     "geometry": {
#       "bounds": {
#         "northeast": {
#           "lat": 32.3310641,
#           "lng": -90.16934719999999
#         },
#         "southwest": {
#           "lat": 32.3156323,
#           "lng": -90.172117
#         }
#       },
#       "location": {
#         "lat": 32.3233451,
#         "lng": -90.1710739
#       },
#       "location_type": "GEOMETRIC_CENTER",
#       "viewport": {
#         "northeast": {
#           "lat": 32.3310641,
#           "lng": -90.16934719999999
#         },
#         "southwest": {
#           "lat": 32.3156323,
#           "lng": -90.172117
#         }
#       }
#     },
#     "locality": {
#       "long_name": "Jackson",
#       "short_name": "Jackson"
#     },
#     "place_id": "ChIJYacFbvIyKIYR2lsVeg3wZr0",
#     "political": {
#       "long_name": "United States",
#       "short_name": "US"
#     },
#     "route": {
#       "long_name": "Peachtree Street",
#       "short_name": "Peachtree St"
#     },
#     "types": [
#       "route"
#     ]
#   },
#   "state": "MS",
#   "status": "OK",
#   "street": "Peachtree St"
# }

# %% [markdown]
# As expected, `Union Square` resolves to the most well-known entity in NYC (confidence level 8) but the more ambiguous strings `5th Street` and `Peachtree Street` resolve to less-confident entities (confidence level 7).
