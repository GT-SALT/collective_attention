# %% [markdown]
# # Test wiki lexicon
# In which we determine how useful the lexicon of wikipedia references (developed by [Spitkovsky and Chang (2011)](https://nlp.stanford.edu/pubs/crosswikis.pdf)) really is.

# %%
from bz2 import BZ2File
import json
import pandas as pd

# %% [markdown]
# ## Load data

# %%
dict_file_name = '/hg190/corpora/crosswikis-data.tar.bz2/dictionary.bz2'
cutoff = 100
ctr = 0
with BZ2File(dict_file_name, 'r') as dict_file:
    for l in dict_file:
        l = l.strip()
        print(l.split(' '))
        ctr += 1
        if(ctr >= cutoff):
            break
# Out:
# ['0.454197', ',_Saskatchewan', 'R09', 'w:1066/2347']
# ['0.184065', 'List_of_countries_and_capitals_in_native_languages', 'L', 'W08', 'W09', 'WDB', 'l', 'w:432/2347']
# ['0.0528334', 'railway_station', 'W09', 'w:124/2347']
# ['0.0204516', 'Manitoba', 'D', 'KB', 'W08', 'W09', 'WDB', 'w:48/2347']
# ['0.0178952', 'Plus_and_minus_signs', 'W08', 'W09', 'WDB', 'w:42/2347']
# ['0.0127823', 'District', 'W08', 'W09', 'WDB', 'w:30/2347']
# ['0.00894759', 'Department', 'D', 'W08', 'W09', 'WDB', 'w:21/2347']
# ['0.00681721', 'List_of_Saskatchewan_provincial_highways', 'L', 'W08', 'W09', 'WDB', 'l', 'w:16/2347']
# ['0.00596506', 'Wicket-keeper', 'W08', 'W09', 'WDB', 'w:14/2347']
# ['0.00553899', 'Richard_Pankhurst_(academic)', 'W09', 'WDB', 'w:13/2347']
# ['0.00511291', 'National_Parks_and_Wildlife_Service_(New_South_Wales)', 'D', 'W08', 'W09', 'WDB', 'w:12/2347']
# ['0.00426076', 'Doubleday_(publisher)', 'KB', 'W08', 'W09', 'WDB', 'w:10/2347']
# ['0.00426076', 'FC', 'D', 'W08', 'W09', 'WDB', 'w:10/2347']
# ['0.00383468', 'LOL_(album)', 'KB', 'W08', 'W09', 'WDB', 'w:9/2347']
# ['0.00383468', 'Time_(magazine)', 'KB', 'W08', 'W09', 'WDB', 'w:9/2347']
# ['0.00383468', 'Wounded_in_action', 'W08', 'W09', 'WDB', 'w:9/2347']
# ['0.00340861', 'Greece_dialing_codes_beginning_with_243x0', 'w:8/2347']
# ['0.00298253', 'List_of_administrative_divisions_of_Guangdong', 'L', 'W08', 'W09', 'WDB', 'l', 'w:7/2347']
# ['0.00298253', 'Trains_(magazine)', 'KB', 'W08', 'W09', 'WDB', 'w:7/2347']
# ['0.00255646', 'Billboard_(magazine)', 'W08', 'W09', 'WDB', 'w:6/2347']
# ['0.00255646', 'List_of_administrative_divisions_of_Shandong', 'L', 'W08', 'W09', 'WDB', 'l', 'w:6/2347']
# ['0.00255646', 'List_of_religious_houses_in_Scotland', 'L', 'W08', 'W09', 'WDB', 'l', 'w:6/2347']
# ['0.00255646', 'Seat', 'D', 'W08', 'W09', 'WDB', 'w:6/2347']
# ['0.00213038', 'Europa_(web_portal)', 'KB', 'W08', 'W09', 'WDB', 'w:5/2347']
# ['0.00213038', 'List_of_T_postal_codes_of_Canada', 'L', 'W08', 'W09', 'WDB', 'l', 'w:5/2347']
# ['0.00213038', 'National_football_team', 'D', 'W08', 'W09', 'WDB', 'l', 'w:5/2347']
# ['0.00213038', 'WIBC_(FM)', 'KB', 'W08', 'W09', 'WDB', 'w:5/2347']
# ['0.0017043', ',_Alberta', 'w:4/2347']
# ['0.0017043', 'Boston_Post_Road_Historic_District_(New_York)', 'NR', 'RWB', 'W09', 'WDB', 'w:4/2347']
# ['0.0017043', 'East_and_West_Memorial_Buildings', 'W08', 'W09', 'WDB', 'w:4/2347']
# ['0.0017043', 'Fortune_(magazine)', 'KB', 'W08', 'W09', 'WDB', 'w:4/2347']
# ['0.0017043', 'Greece_dialing_codes_beginning_with_265x0', 'w:4/2347']
# ['0.0017043', 'Mesoregion', 'W08', 'W09', 'WDB', 'w:4/2347']
# ['0.0017043', 'The_Stranger_(newspaper)', 'KB', 'W08', 'W09', 'WDB', 'w:4/2347']
# ['0.0017043', 'Variety_(magazine)', 'W08', 'W09', 'WDB', 'w:4/2347']
# ['0.00127823', 'Blender_(magazine)', 'W08', 'W09', 'WDB', 'w:3/2347']
# ['0.00127823', 'Church_of_Christ_(Latter_Day_Saints)', 'W08', 'W09', 'WDB', 'w:3/2347']
# ['0.00127823', 'Monkey_(novel)', 'W08', 'W09', 'WDB', 'w:3/2347']
# ['0.00127823', 'New_York_City', 'D', 'KB', 'W08', 'W09', 'WDB', 'w:3/2347']
# ['0.00127823', 'Science_(journal)', 'KB', 'W08', 'W09', 'WDB', 'w:3/2347']
# ['0.00127823', 'Slate_(magazine)', 'KB', 'W08', 'W09', 'WDB', 'w:3/2347']
# ['0.00127823', 'Union_(American_Civil_War)', 'W08', 'W09', 'WDB', 'w:3/2347']
# ['0.00127823', 'WLS_(AM)', 'KB', 'W08', 'W09', 'WDB', 'w:3/2347']
# ['0.000852152', '(_)', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Alan_Chesters_(bishop)', 'NR', 'RWB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Bank_of_Canada', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'C._D._Howe_Building', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'CBC_Ottawa_Broadcast_Centre', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Crash_(magazine)', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Daily_Times_(Pakistan)', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Dawn_(newspaper)', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Destination_X', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'El_Universal_(Mexico_City)', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Gareth_Roberts_(writer)', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Greenfield_Advisors', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'HTML_element', 'D', 'W08', 'W09', 'WDB', 'l', 'w:2/2347']
# ['0.000852152', 'Joseph_Bates_(Adventist)', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'List_of_abbeys_and_priories_in_Wales', 'L', 'W08', 'W09', 'WDB', 'l', 'w:2/2347']
# ['0.000852152', 'List_of_municipalities_in_the_state_of_S\xc3\xa3o_Paulo_by_population', 'L', 'W08', 'W09', 'WDB', 'l', 'w:2/2347']
# ['0.000852152', 'Ministry_of_Justice_(United_Kingdom)', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'National_Highway_System_(United_States)', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'National_speedway_team', 'w:2/2347']
# ['0.000852152', 'New_International_Encyclopedia', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Paralympic_Games', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Place_de_Ville', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Politis_(France)', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'San_Bruno,_California', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Second', 'D', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Stephen_Hopkins_(director)', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', "Thomas_D'Arcy_McGee_Building", 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Watermark_(newspaper)', 'w:2/2347']
# ['0.000852152', 'Wellington_Building', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'Wisconsin_Public_Television', 'KB', 'W08', 'W09', 'WDB', 'w:2/2347']
# ['0.000852152', 'addition', 'W09', 'w:2/2347']
# ['0.000426076', '(NZ_electorate)', 'w:1/2347']
# ['0.000426076', '(Tsuyoshi_Nagabuchi_album)', 'w:1/2347']
# ['0.000426076', '(U.S._TV_series)', 'w:1/2347']
# ['0.000426076', '-->Monster<!--Need_verification_(Steppenwolf_album)', 'w:1/2347']
# ['0.000426076', '1000_(number)', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', '12_(number)', 'D', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', '182nd_Infantry_Regiment_(United_States)', 'KB', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', '1927', 'CHRON:YEAR', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', '2003', 'CHRON:YEAR', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', '2007-05-07', 'w:1/2347']
# ['0.000426076', '44th_National_Hockey_League_All-Star_Game', 'KB', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', '46th_National_Hockey_League_All-Star_Game', 'KB', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'A_Girl_in_Every_Port_(1952_film)', 'KB', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'Abilene,_Texas', 'KB', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'Al-Adil_Kitbugha', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'Alan_Grant_(writer)', 'KB', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'Alaska_magazine', 'NR', 'RWB', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'Alexis,_Ohio', 'w:1/2347']
# ['0.000426076', 'Anarcho-capitalism', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'Asia_(band)', 'KB', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'Astral_Projection_(group)', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'Atlanta,_Georgia', 'D', 'KB', 'NR', 'R09', 'RDB', 'RWB', 'W08', 'l', 'w:1/2347']
# ['0.000426076', 'Back_and_Forth_(film)', 'KB', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'Banjo_on_My_Knee_(film)', 'w:1/2347']
# ['0.000426076', 'Battle_of_Quebec_(1775)', 'KB', 'W08', 'W09', 'WDB', 'w:1/2347']
# ['0.000426076', 'Bearing_(navigation)', 'W08', 'W09', 'WDB', 'w:1/2347']

# %% [markdown]
# Looks like that file contains the actual URLs. We need the string mentions!
#
# According to [this](https://nlp.stanford.edu/data/crosswikis-data.tar.bz2/READ_ME.txt), the mention string might be blank. So if the first chunk of the string is not a probability then it's probably a mention string.

# %%
import re
ctr = 0
cutoff = 1000
# if the first string is not just a probability then it's a string mention
with BZ2File(dict_file_name, 'r') as dict_file:
    for l in dict_file:
        l = l.strip()
        if(len(l.split('\t')) > 1):
            ctr += 1
            print(l)
        if(ctr >= cutoff):
            break
# Out:
# _og_ eir	0 Þú_og_þeir_(Sókrates) KB W09 W08 WDB c
# _og_ eir_(s krates)	0 Þú_og_þeir_(Sókrates) KB W09 W08 WDB t
# _veistu_svari 	0 Þá_veistu_svarið KB W08 W09 WDB c t
# elstan_i	0 Æthelstan_of_Wessex W08 W09 WDB c t
# ey	0 EY D W08 W09 WDB c t
# igo_arista	0 Íñigo_Arista_of_Pamplona W08 W09 WDB c t
# igo_cervantes-hueg n	0 Iñigo_Cervantes-Huegun c t
# igo_cuesta	0 Íñigo_Cuesta W08 W09 WDB c t
# igo_fern ndez	0 Íñigo_Fernández NR RWB W08 W09 WDB c t
# igo_fern ndez_de_velasco,_2nd_duke_of_fr as	0 Íñigo_Fernández NR RWB W08 W09 WDB c t
# igo_l pez	0 Íñigo_López c t
# igo_l pez_de_mendoza	0 Íñigo_López_de_Mendoza,_marqués_de_Santillana NR RWB W08 W09 WDB c t
# igo_l pez_de_mendoza_y_z  iga	0 Íñigo_López_de_Mendoza_y_Zúñiga W08 W09 WDB c t
# igo_m ndez_de_vigo	0 Íñigo_Méndez_de_Vigo W08 W09 WDB c t
# igo_melchor_de_velasco,_7th_duke_of_fr as	0 Íñigo_Melchor_de_Velasco,_7th_Duke_of_Frias NR RWB W08 W09 WDB c t
# igo_v lez_de_guevara,_8th_count_of_o ate	0 Íñigo_Vélez_de_Guevara,_8th_Count_of_Oñate W08 W09 WDB c t
# igo_v lez_de_guevara,_count_of_o ate	0 Íñigo_Vélez_de_Guevara D W08 W09 WDB c t
# inn_j nsson	0 Óðinn_Jónsson W09 WDB c t
# ins_n fn	0 ��ins_n�fn c t
# mrang	0 Öömrang W08 W09 WDB c t
# nekoski	0 Äänekoski W08 W09 WDB c t
# nekoski_bus_disaster	0 Konginkangas_bus_disaster W08 W09 WDB c t
# ni _y ss 	0 Ääniä_Yössä KB W08 W09 WDB c t
# po maq	0 Öçpoçmaq W08 W09 WDB c t
# r ar_saga_hre u	0 Þórðar_saga_hreðu W08 W09 WDB c t
# r lfsfell	0 Thorolfsfell NR RWB W08 W09 WDB c t
# r lfur_ rnason	0 Þórólfur_Árnason D W08 W09 WDB c t
# r r_kolbeinsson	0 Þórðr_Kolbeinsson W08 W09 WDB c t
# r ttaf lag_hafnarfjar ar	0 Íþróttafélag_Hafnarfjarðar c t
# r ttaf lagi _ r ttur	0 Knattspyrnufélagið_Þróttur W08 W09 WDB c t
# r ttaf lagi _fylkir	0 Fylkir KB W08 W09 WDB c t
# r ttaf lagi _gr tta	0 Íþróttafélagið_Grótta c t
# r ttaf lagi _h ttur	0 Íþróttafélagið_Höttur c t
# r ttaf lagi _v lsungur	0 Íþróttafélagið_Völsungur c t
# r ur_fri j nsson	0 Þórður_Friðjónsson W08 W09 WDB c t
# r ur_gu j nsson	0 Þórður_Guðjónsson W08 W09 WDB c t
# r ur_kakali_sighvatsson	0 Þórður_kakali_Sighvatsson W08 W09 WDB c t
# r_akureyri	0 Þór_Akureyri W08 W09 WDB c t
# r_beck	0 Þór_Beck c t
# r_saari	0 Þór_Saari c t
# r_vilhj lmsson	0 Thor_Vilhjálmsson W08 W09 WDB c t
# ra_bj rg_helgad ttir	0 Þóra_Björg_Helgadóttir c t
# ra_magn sd ttir	0 Þóra_Magnúsdóttir W08 W09 WDB c t
# ra_town-hart	0 Þóra_Town-Hart W08 W09 WDB c t
# rarinn_ orl ksson	0 Þórarinn_B._Þorláksson W08 W09 WDB c t
# rarinn_eldj rn	0 Þórarinn_Eldjárn W08 W09 WDB c t
# rarinn_ingi_valdimarsson	0 Þórarinn_Ingi_Valdimarsson c t
# rarinn_kristj nsson	0 Þórarinn_Kristjánsson c t
# rarinn_loftunga	0 Þórarinn_loftunga W08 W09 WDB c t
# rarinn_skeggjason	0 Þórarinn_Skeggjason W08 W09 WDB c t
# rbergur_  r arson	0 Þórbergur_Þórðarson W08 W09 WDB c t
# reg_nuur	0 Üüreg_Nuur W08 W09 WDB c t
# rhallur_gunnarsson	0 Þórhallur_Gunnarsson KB W08 W09 WDB c t
# rhildur_ orleifsd ttir	0 Þórhildur_Þorleifsdóttir D W08 W09 WDB c t
# riku	0 Riku D W08 W09 WDB c t
# rir_j kull_steinfinnsson	0 Þórir_Jökull_Steinfinnsson W08 W09 WDB c t
# risj kull	0 Þórisjökull c t
# risvatn	0 Þórisvatn KB W08 W09 WDB c t
# rka_ka p rkov 	0 Šárka_Kašpárková W08 W09 WDB c t
# rkell_  rm  sson	0 Þórkell_Þórmóðsson c t
# rrav 	0 Çërravë W09 WDB c t
# rsdr pa	0 Þórsdrápa W08 W09 WDB c t
# rsh fn	0 Þórshöfn W08 W09 WDB c t
# rsh fn_airport	0 Þórshöfn_Airport KB W08 W09 WDB c t
# rsm rk	0 Þórsmörk NR RWB W08 W09 WDB c t
# runn_sveinbjarnard ttir	0 Þórunn_Sveinbjarnardóttir W09 WDB c t
# rvaldr_hjaltason	0 Þórvaldr_Hjaltason W08 W09 WDB c t
# uv k	0 Æðuvík W08 W09 WDB c t
# vere	0 Vere D W08 W09 WDB c t
# "Quick Rock 97" 	0 KQWK_(defunct) KB W09 W08 WDB f
# "quick rock 97" 	0 KQWK_(defunct) KB W08 W09 WDB f
# ,_ fjord	0 Å,_Åfjord W08 W09 WDB c t
# ,_and y	0 Å,_Andøy W08 W09 WDB c t
# ,_denmark	0 Ø,_Denmark W08 W09 WDB c t
# ,_ibestad	0 Å,_Ibestad W08 W09 WDB c t
# ,_lavangen	0 Å,_Lavangen W08 W09 WDB c t
# ,_meldal	0 Å,_Meldal W08 W09 WDB c t
# ,_moskenes	0 Å,_Moskenes W08 W09 WDB c t
# ,_sweden	0 Å,_Sweden W08 W09 WDB c t
# - 1439	0 Anne_of_Veldenz_(_-_1439) f
# - No Label - 	0 Peas_and_Corn_/_So_Fahr_(_-_No_Label_-_) f
# - no label - 	0 Peas_and_Corn_/_So_Fahr_(_-_No_Label_-_) f
# .l ve	0 A-Love W09 WDB c t
# /- album	0 You_Are_Here_(_/-_album) W09 f
# /-_album	0 You_Are_Here_(_/-_album) W09 f
# 1-sequence	0 ±1-sequence c t
# 1631	0 Maria_Magdalena_of_Austria_(_1631) W09 f
# 1692	0 Battle_of_Steenkerque KB W08 W09 WDB f
# 1743	0 Maria_Magdalena_of_Austria_(_1743) W09 f
# 1849 	0 Battle_of_Novara_(1849) KB W08 W09 WDB f
# 1912-1913 	0 Order_of_battle_of_the_Serbian_Army_in_the_First_Balkan_War f
# 1971 film	0 Lawman_(film) KB W08 W09 WDB f
# 1979 film	0 The_Wanderers_(1979_film) KB W08 W09 WDB f
# 1993 	0 Azerbaijan_Communist_Party_(1993) W08 W09 WDB f
# 1998 film	0 Christabel_(film) NR RWB W08 W09 WDB f
# 1999	0 1999_Pacific_typhoon_season KB W08 W09 WDB f
# 1_inforadio	0 Ö1_Inforadio W09 WDB c t
# 2003 film	0 Cheaper_by_the_Dozen_(2003_film) KB W08 W09 WDB f
# 2008 film 	0 Possession_(2009_film) KB W08 W09 WDB f
# 2009	0 The_Wiz KB W08 W09 WDB f
# 2011 TV series	0 The_Time_of_My_Life_(David_Cook_song) KB D W09 W08 WDB f
# 2011 tv series	0 The_Time_of_My_Life_(David_Cook_song) D KB W08 W09 WDB f
# 2012 film	0 The_Pirates!_Band_of_Misfits f
# 30 Rock Episode 	0 List_of_30_Rock_episodes L l W09 W08 WDB f
# 30-30!	0 30-30 D W08 W09 WDB c t
# 3_austria_top_40	0 Ö3_Austria_Top_40 W08 W09 WDB c l t
# 3_austria_top_75	0 Ö3_Austria_Top_40 W08 W09 WDB c l t
# 7 Seconds Album	0 Scream_Real_Loud...Live! W09 W08 WDB f
# 7 seconds album	0 Scream_Real_Loud...Live! W08 W09 WDB f
# 7" EP	0 Starkweather_(_7"_EP) f
# 7" ep	0 Starkweather_(_7"_EP) f
# 883 5100 country code	0 INum_Initiative_(_883_5100_Country_Code) f
# 883_5100_Country_Code	0 INum_Initiative_(_883_5100_Country_Code) f
# 9.50_holidays	0 £9.50_Holidays_(The_Sun) W09 WDB c
# 9.50_holidays_(the_sun)	0 £9.50_Holidays_(The_Sun) W09 WDB t
# 94 KG	0 BARS:_Cup_of_Arbat_Quarter-finals_(_94_KG) f
# 94 kg	0 BARS:_Cup_of_Arbat_Quarter-finals_(_94_KG) f
# A. R. Gurney, Jr play	0 The_Golden_Age_(_A._R._Gurney,_Jr_play) f
# APLAR	0 Asia_Pacific_League_of_Associations_for_Rheumatology W09 W08 WDB f
# APMPPE	0 Acute_posterior_multifocal_placoid_pigment_epitheliopathy W09 W08 WDB f
# ATV	0 Why_can't_I_go_Home_(_ATV) f
# Abolitionist	0 William_Still W09 W08 WDB f
# Al Green song	0 Full_of_Fire_(song) f
# Album	0 Despised_(_Album) RWB f
# American rapper	0 Romeo_(_American_rapper) R09 R08 RDB f
# An Geata Mor 	0 Binghamstown W09 W08 WDB f
# An Geata Mór 	0 Binghamstown W09 W08 WDB f
# Anthony Hamilton album	0 XTC_(album) KB W09 W08 WDB f
# Aphasic Tone 	0 "White_Bird"_-_No_Man's_Religion_Immigrate_Us_p.2_-_(_Aphasic_Tone_) f
# Assembly Constituency	0 Thalassery_(_Assembly_Constituency) WDB NR RWB f
# Assembly constituency	0 Arfon_(Assembly_constituency) W08 W09 WDB f
# Assembly constituency	0 Vale_of_Clwyd_(Assembly_constituency) W08 W09 WDB f
# Australia	0 List_of_former_power_stations_in_Victoria,_Australia L l W09 W08 WDB NR RWB f
# Australia 1970's to Present	0 Stylus_(band) W09 W08 WDB f
# Author and leadership expert 	0 Chris_Widener_(author) f
# Bear Stone	0 Battle_of_Mečkin_Kamen f
# Belo Horizonte	0 Vilarinho_(_Belo_Horizonte) f
# Bergamo 	0 Santa_Maria_Maggiore,_Bergamo W09 W08 WDB f
# Bezmisht	0 St._Demetrius'_Church,_Bezmisht f
# Bihbar lower secondary school 	0 Shree_Bihabar_Lower_Secondary_School f
# Biman Bangladesh Airlines cricketer	0 Mohammad_Rafiqul_Islam W09 W08 WDB f
# Bjoerk DVD 	0 Live_at_Royal_Opera_House KB W08 W09 WDB f
# Bjoerk DVD 	0 Live_in_Cambridge KB W08 W09 WDB f
# Bjoerk DVD 	0 MTV_Unplugged_/_Live W08 W09 WDB f
# Bjoerk DVD 	0 The_Inner_or_Deep_Part_of_an_Animal_or_Plant_Structure KB W08 W09 WDB f
# Bjoerk DVD 	0 Vessel_(DVD) KB W08 W09 WDB f
# Bjork DVD 	0 Live_at_Royal_Opera_House KB W08 W09 WDB f
# Bjork DVD 	0 Live_in_Cambridge KB W08 W09 WDB f
# Bjork DVD 	0 MTV_Unplugged_/_Live W08 W09 WDB f
# Bjork DVD 	0 The_Inner_or_Deep_Part_of_an_Animal_or_Plant_Structure KB W08 W09 WDB f
# Bjork DVD 	0 Vessel_(DVD) KB W08 W09 WDB f
# Björk DVD 	0 Live_at_Royal_Opera_House KB W08 W09 WDB f
# Björk DVD 	0 Live_in_Cambridge KB W08 W09 WDB f
# Björk DVD 	0 MTV_Unplugged_/_Live W08 W09 WDB f
# Björk DVD 	0 The_Inner_or_Deep_Part_of_an_Animal_or_Plant_Structure KB W08 W09 WDB f
# Björk DVD 	0 Vessel_(DVD) KB W08 W09 WDB f
# Bluegrass Artist 	0 Michael_Cleveland_(bluegrass_musician) W09 W08 WDB f
# Boninho 	0 J._B._de_Oliveira_(_Boninho_) f
# Book 	0 The_Lazy_Man's_Guide_to_Enlightenment KB W09 W08 WDB f
# British TV series	0 Blue_Murder_(_British_TV_series) f
# Britney Spears' 	0 Here_I_Come_(_Britney_Spears'_) R09 R08 RDB f
# Brunei TV Series 	0 The_Biggest_Loser_(Brunei_TV_series) f
# Burzum album	0 Fallen_(Burzum_album) f
# Cairo 	0 Chaar_Hachamaim_Synagogue_(Cairo) KB W08 NR RWB R09 RDB f
# Chancellor UNCA	0 Anne_Ponder_(_Chancellor_UNCA) f
# Charleroi 	0 Chatelet_(_Charleroi_) f
# Chattha	0 Thatha_Shamsa_(Chattha) W09 WDB f
# Chengdu Datang	0 Datang_town_(Chengdu_Datang) W09 WDB NR RWB f
# Cleen, Demune 	0 Well_(_Cleen,_Demune_) f
# Colonel	0 James_Johnston_(Colonel) W09 WDB f
# Conservation Biology 	0 Rewilding D W09 W08 WDB f
# Cool Pasture 	0 Malham-arncliffe_(_Cool_Pasture_) f
# DC comics	0 Oblivion_(_DC_comics) f
# DJ Naughty Remix	0 The_Cut_(_DJ_Naughty_Remix) f
# DJ/Producer 	0 Paul_Woolford_(DJ/Producer) W09 W08 WDB NR RWB f
# Danity Kane Song 	0 Bad_Girl_(Danity_Kane_song) KB W09 W08 WDB f
# Daughtry song	0 Crashed_(Daughtry_song) KB W09 W08 WDB f
# Dead Magazine 	0 "Damaged_Good_Nejel_Mongrel_Remix"_-_Dead_Vol_3_(_Dead_Magazine_) f
# Decision Support System	0 Split_Up_(Decision_Support_System) f
# Defunct STudio 23 TV show	0 Men's_Room_(_Defunct_STudio_23_TV_show) f
# Degamve / Devgram 	0 Kamala_Narayana_Temple,_Degaon_(_Degamve_/_Devgram_) W09 W08 WDB NR RWB f
# Desperate Housewives episode 	0 Now_You_Know_(Desperate_Housewives) KB W09 W08 WDB f
# Dhaka Division cricketer	0 Nazmul_Hossain_(Dhaka_cricketer) W08 W09 WDB f
# Dhaka Division cricketer	0 Nazmus_Sadat_(Dhaka_cricketer) W08 W09 WDB f
# Dis Eased Wrekkids, Records 	0 "B._T._U._Mattr_Remix"_-_Healing_Cancer_Sampler_Disc_(_Dis_Eased_Wrekkids,_Records_) f
# Drummer	0 Priestess_(band) KB W09 W08 WDB f
# Elvis Costello album	0 Mighty_Like_a_Rose_Elvis_Costello_album) RWB f
# England	0 Stuart_period_(England) W09 W08 WDB NR RWB f
# FAU	0 Uruguayan_Anarchist_Federation W09 W08 WDB f
# FIHE 	0 Foundation_for_Independent_Higher_Education f
# Falls Church, Virginia	0 Temple_Rodef_Shalom_(Falls_Church,_Virginia) WDB f
# Fashion Designer	0 Odette_Krempin KB W09 W08 WDB f
# Fast food shop	0 Southern_Fried_Chicken_(franchise) f
# Francis Bacon novel	0 The_New_Atlantis KB D W09 W08 WDB f
# Freeze Album	0 Land_of_the_Lost_(The_Freeze_album) f
# Fremont, Ohio	0 Fremont_Ross_HS/St_Joseph_Central_Catholic_HS_(_Fremont,_Ohio) f
# GSM Barcelona 	0 Graduate_School_of_Management_(GSM_Barcelona) f
# Geneology keeper	0 Jagas_(_Geneology_keeper) f
# Georgetown, Ontario	0 Christ_the_King_(Georgetown,_Ontario) W09 W08 WDB NR RWB f
# Georgia 	0 Special_Forces_Brigade_(Georgia) f
# German sports executive	0 Fritz_Walter_(football_executive) W09 W08 WDB f
# Gimnazija Novo mesto 	0 Novo_mesto_Grammar_School KB W09 W08 WDB NR RWB f
# Girda	0 Girish_Tiwari_(Girda) f
# Godrej	0 Nature_Basket_(_Godrej) f
# Greek 	0 Nilus_(mythology) W09 W08 WDB f
# Green Anarchism 	0 Rewilding_(anarchism) W09 WDB f
# Greenwise Records 	0 DSAnalog_EP_/_DSAnalog_(_Greenwise_Records_) f
# HVDC	0 Cometa_(HVDC) f
# Ha'apai	0 Battle_of_Velata_(_Ha'apai) W09 W08 WDB NR RWB f
# Hannah Montana season 4	0 The_Real_Me_(The_Who_song) KB l W09 W08 WDB f
# Hans Holbein the Younger	0 Lais_of_Corinth_(Hans_Holbein_the_Younger) f
# Hardline album	0 Hardline_(band) W09 W08 WDB f
# Hekimhan - Malatya 	0 Karapınar_(Malatya) W08 W09 WDB f
# Hekimhan, Malatya 	0 Karapınar_(Malatya) W09 W08 WDB f
# Hindi Magazine 	0 Sarita_(magazine) f
# Hizb e Islami 	0 Fazal_Haq_Mujahid f
# Ho Chi Minh City, Vietnam	0 Nguyễn_Công_Trứ_High_School W09 WDB f
# House of Theosophy	0 Darul_Hikmah_(_House_of_Theosophy) f
# India 	0 National_Highway_6_(India) W09 WDB f
# India 	0 National_Highway_7_(_India_) f
# India.Arie song	0 Brown_Skin_(song) W09 WDB NR RWB f
# Indiana	0 Salem_Downtown_Historic_District_(Indiana) KB W08 NR RWB R09 RDB f
# Indigenous People's International Centre for Policy Research and Education	0 Tebtebba_Foundation_(_Indigenous_People's_International_Centre_for_Policy_Research_and_Education) f
# Industrial music band 	0 Militia_(band) KB W09 W08 WDB f
# Ireland	0 M1_motorway_(Republic_of_Ireland) W08 W09 WDB f l
# Ireland	0 Newbridge_railway_station_(Ireland) W08 W09 WDB f
# Irish footballer	0 Patrick_O'Connell_(Irish_footballer) W09 W08 WDB f
# Isle of Man 	0 Ballakilpheric f
# Japanese Bonus Tracks	0 Moon_Rock_(_Japanese_Bonus_Tracks) f
# Jin song	0 ABC_(Jin_song) KB W09 W08 WDB RWB f
# Johnny Ace song	0 The_Eraser KB W09 W08 WDB f
# Jon Spencer Blues Explosion	0 Orange_(Jon_Spencer_Blues_Explosion) WDB NR RWB f
# Josh Turner song	0 Your_Man_(song) KB W09 W08 WDB NR RWB f
# Junior Boys album	0 Last_Exit_(Junior_Boys_album) KB W09 W08 WDB f
# Kabbalah	0 Ayin_and_Yesh f
# Kakh-e Morvarid	0 Pearl_Palace WDB f
# Karl O'Connor 	0 Regis_(musician) W09 W08 WDB f
# Kerala	0 State_Highway_17_(_Kerala) W09 WDB NR RWB f
# Kiran 	0 Prem_(film_director) f
# Kitaro 	0 Sacred_Journey_of_Ku-Kai f
# Kool & The Gang song	0 Misled_(Kool_&_the_Gang_song) WDB NR RWB f
# LLH 	0 Lycée_Al_Horreya_Héliopolis W09 WDB NR RWB f
# LSFC 	0 De_La_Salle_Lipa_(_LSFC_) f
# Lake Wales, Florida	0 The_Vanguard_School_(Lake_Wales,_Florida) f
# Las Vegas, NV	0 St._Viator_School_(Las_Vegas,_Nevada) KB W09 W08 WDB f
# Le Sueur County 	0 Lake_Jefferson_(Minnesota) f
# Little Devil	0 Diawl_bach W09 W08 WDB f
# Lombardy	0 A.C._Palazzolo_1913 W09 W08 WDB NR RWB f
# Losang Gyurme	0 Kunga_Rinpoche W09 W08 WDB f
# Lou Gehrig's Disease	0 Amyotrophic_lateral_sclerosis KB D W09 W08 WDB f
# Lt. Col	0 William_Clark_(_Lt._Col) f
# MC Cornfield, DJ Crowse 1, Demune 	0 DSAnalog_(_MC_Cornfield,_DJ_Crowse_1,_Demune_) f
# MP 	0 Giuseppe_Angeli_(_MP_) f
# Madawaska, Maine	0 St._David_Catholic_Church_(Madawaska,_Maine) f
# Magazine	0 The_Beat_Magazine f
# Male 	0 Best_Actor_in_a_Comic_Role_(_Male_) f
# Malinois	0 Belgian_Shepherd_Dog_(Malinois) KB W09 W08 WDB f
# Martins Ferry, Ohio	0 Martins_Ferry_High_School_(_Martins_Ferry,_Ohio) f
# Marty Stuart Album	0 Once_Upon_a_Time_(Marty_Stuart_album) f
# Mattr, Demune 	0 Cloth_(_Mattr,_Demune_) f
# Media Industry	0 Reallocation_(media) f
# Memphis , Tennessee 	0 St._Francis_Hospital_(_Memphis_,_Tennessee_) f
# Miley Cyrus song	0 List_of_Hannah_Montana_songs L l W09 W08 WDB f
# Milled Pavement Records 	0 "Secret_of_the_Past"_with_Roma_and_Andre_Romak-_Goose_Bumps_2.0_(_Milled_Pavement_Records_) f
# Missouri	0 Lafayette_County_Courthouse_(Missouri) W09 WDB f
# Mizhavu 	0 Nambiar_(_Mizhavu_) W09 W08 WDB NR RWB f
# Moetley Cruee album	0 Girls,_Girls,_Girls_(Mötley_Crüe_album) KB W09 W08 WDB f
# Motion Recordings 	0 "F._I._E.,"_"B.T.U.",_and_"Jack_of_All_Trades"_-_The_Cafeteria_(_Motion_Recordings_) f
# Motion Recordings 	0 "Firefly"_-_Tangli_Wheebs_and_the_Mole_present_Maui_(_Motion_Recordings_) f
# Motion Recordings 	0 Bloody_Flags_Maxi_Single_/_Ancient_Mith_(_Motion_Recordings_) f
# Motion Recordings 	0 History_in_the_Faking_/_Ancient_Mith_(_Motion_Recordings_) f
# Motion Recordings 	0 Ho_Ho_Ho_EP/_Cafeteria_(_Motion_Recordings_) f
# Motion Recordings 	0 The_Attack_of_the_Zombie_King.../_Mole_and_Demune_(_Motion_Recordings_) f
# Motion Recordings 	0 Whirlwind_Worlds_/_Mole_(_Motion_Recordings_) f
# Motley Crue album	0 Girls,_Girls,_Girls_(Mötley_Crüe_album) KB W09 W08 WDB f
# Mr. Superman ki Wapsi	0 Return_of_Mr._Superman_(_Mr._Superman_ki_Wapsi) WDB NR RWB f
# Mureş County	0 List_of_Hungarian_exonyms_(Mureş_County) L l f
# Mybrother, Slurs, Demune 	0 Good_Music_(_Mybrother,_Slurs,_Demune_) f
# Mötley Crüe album	0 Girls,_Girls,_Girls_(Mötley_Crüe_album) KB W09 W08 WDB f
# NCOs 	0 Marshal_(Italy) W09 WDB f
# NFC wallet solution provider	0 Toro_(NFC_wallet_solution_provider) f
# NSIT festival	0 Moksha_Festival f
# Navy	0 Port_(_Navy) f
# New Hampshire	0 Webster_Lake_(New_Hampshire) KB W09 W08 WDB f
# New Jersey	0 County_Route_501_(New_Jersey) KB W09 W08 WDB f
# New Stevenston	0 Taylor_High_School_-_New_Stevenston W09 W08 WDB NR RWB f
# New York	0 George_Fisher_(New_York) W09 W08 WDB f
# Newport News, Virginia	0 East_End_(Newport_News,_Virginia) W09 W08 WDB f
# Nigerian movie	0 Games_Men_Play WDB f
# North Auckland	0 11th_(North_Auckland)_Mounted_Rifles KB W09 W08 WDB f
# Nova Scotia	0 Loon_Lake_(Nova_Scotia) W09 WDB f
# Nuclear Reactor	0 Pebble_bed_reactor W09 W08 WDB f
# Ocampo 	0 Las_horas_de_una_estancia_(_Ocampo_) f
# One Amazing Person:	0 Rachel_T._(_One_Amazing_Person:) f
# Pennsylvania	0 Peters_Creek_(Pennsylvania) W09 W08 WDB f
# Philippine TV series	0 The_Time_of_My_Life_(David_Cook_song) KB D W09 W08 WDB f
# Plague Language 	0 Ten_Kings_/_Plague_Language_(_Plague_Language_) f
# Plague Language, Subversiv* Records 	0 "Find_Yourself"_-_Farewell_Archetypes_Vol_2_12"_Vinyl_(_Plague_Language,_Subversiv*_Records_) f
# Plague Language, Subversiv* Records 	0 "Precious"_-_Farewell_Archetypes_CD_(_Plague_Language,_Subversiv*_Records_) f
# Political Commentator	0 Michael_Savage_(commentator) KB D W09 W08 WDB NR RWB f
# Ponowai Flora / Subversiv* 	0 A_Modern_Day_Mcarthy_/_Rushya_(_Ponowai_Flora_/_Subversiv*_) f
# Ponowai Flora Records 	0 "Vent"_-_Ponowai_Flora_Sampler_12"_Vinyl_and_CD_(_Ponowai_Flora_Records_) f
# Ponowai Flora Records 	0 Crossbreeding_and_Grafting_Fossils_/_Demune_(_Ponowai_Flora_Records_) f
# Ponowai Flora Records, Subversiv* Records, Motion Recordings 	0 Crossbreeding_and_Grafting_/_Demune_(_Ponowai_Flora_Records,_Subversiv*_Records,_Motion_Recordings_) f
# Predators 	0 Reintroduction W09 W08 WDB f
# Providence	0 Charles,_Providence,_Rhode_Island W09 W08 WDB f
# Pune 	0 Poona_(_Pune_) f
# Pvt.Ltd.	0 Sagar_Films_(Pvt._Ltd.) W09 W08 WDB NR RWB f
# Qaazbek	0 Ghizel_Bek_Sharaloqa_(_Qaazbek) f
# R 	0 Bahujan_Ekta_Party_(_R_) f
# RPI	0 Recruitment_Process_Insourcing W09 W08 WDB f
# Radio 	0 96.4FM_The_Wave KB W08 NR RWB R09 RDB f
# Radio Program	0 To_the_Best_of_Our_Knowledge W09 W08 WDB f
# Ragnarok 	0 Bozanian_Beast_Fighter_(_Ragnarok_) f
# Rajasthan	0 Pratapgarh_district_(Rajasthan) W09 W08 WDB f
# Rajgarh 	0 Raghunandan_Sharma_(Rajgarh) f
# Rajshahi Division	0 Murad_Khan_(Rajshahi_cricketer) W09 W08 WDB f
# Rajshahi Division cricketer	0 Moniruzzaman_(Rajshahi_cricketer) W09 W08 WDB f
# Ramadan / Subversiv* 	0 Consequence_of_Thoughts_/_Mattr_(_Ramadan_/_Subversiv*_) f
# Ramadan / Subversiv* 	0 Split_Mattr_and_Rushya_12"_Vinyl_/_Mattr,_Rushya_"_(_Ramadan_/_Subversiv*_) f
# Reboot film 	0 Predator_(franchise) KB W09 W08 WDB f
# Redemption album	0 Redemption_(Redemption_album) KB W09 W08 WDB f
# Relaunch Era	0 All_That KB W09 W08 WDB f
# Representativz album	0 Angels_of_Death_(_Representativz_album) f
# Research Scientist 	0 Adnan_Zaidi W09 W08 WDB f
# Richmond, Virginia	0 St._Paul's_Episcopal_Church_(Richmond,_Virginia) W09 W08 WDB f
# Roman Catholic Church	0 Interdict D W09 W08 WDB f
# S	0 List_of_health_topics_(S) L l W08 f
# SCSVMV	0 Sri_Chandrasekharendra_Swaraswathi_Mahavidyalaya W09 W08 WDB NR RWB f
# SHELA 	0 SALLY_RAMAGE_LEGAL_CONSULTANTS_•_Samuel_Rubin_Foundation,_Inc_•_School_for_human_Education_and_Legal_Awareness_(_SHELA_) f
# STAR Tollway	0 Southern_Tagalog_Arterial_Road_(_STAR_Tollway) f
# Saladused 	0 Saladused f
# San Diego, California	0 Balboa_Park,_San_Diego,_California KB W09 W08 WDB RWB f
# Sarkin Yakin Gombe	0 Mohammed_Danjuma_Goje W09 W08 WDB f
# Self Released 	0 "B._T._U."_-_Black_Empty_Bootleg_(_Self_Released_) f
# Self Released 	0 "Branded"_-_New_World_Disorder_Compilation_(_Self_Released_) f
# Serbia 	0 Regional_European_center_(_Serbia_) W09 W08 WDB f
# Snail on a Stick 	0 Nettlesome_/_Tangli_Wheebs_(_Snail_on_a_Stick_) f
# Snail on a Stick Records 	0 Tangli_Wheebs_&_Demune_EP_/_Tangli_&_Demune_(_Snail_on_a_Stick_Records_) f
# Snail on a Stick Records, Agitprop! Records 	0 EXN_EP_/_Demune_(_Snail_on_a_Stick_Records,_Agitprop!_Records_) f
# So Fahr, Demune 	0 Double_Jointed_(_So_Fahr,_Demune_) f
# Soundarya,Abbas	0 Swethanagu_(_Soundarya,Abbas) f
# Soundarya,Saikumar,Jagapathi Babu,Prakash Raj	0 Anthahpuram_(_Soundarya,Saikumar,Jagapathi_Babu,Prakash_Raj) f
# South East Queensland	0 TransLink_(South_East_Queensland) KB l W09 W08 WDB f
# Spiderbaby Grafix	0 Tyrant_(comic) W09 W08 WDB NR RWB f
# Sportscaster	0 Jack_Miller_(sportscaster) f
# Stanley Clarke album	0 At_the_Movies_(Stanley_Clarke_album) KB W09 W08 WDB f
# Stone Temple Pilots song	0 Naked_Sunday_(Stone_Temple_Pilots_song) f
# Subliminal Freedom Records 	0 Funk,_Soul,_Rock_and_Roll_/_Amphibious_Tongues_(_Subliminal_Freedom_Records_) f
# Subliminal Freedom Records 	0 M_A_U_I_/_Buzz_One,_Amphibious_Tongues,_Terms_None_(_Subliminal_Freedom_Records_) f
# Subversiv* 	0 Still_There_/_Xndl_(_Subversiv*_) f
# Suisse 	0 Rivera,_Switzerland KB W09 W08 WDB f
# Syracuse, New York	0 Palace_Theatre,_Syracuse W09 W08 WDB NR RWB f
# TONGA	0 Hala_'o_Vave_(_TONGA) W09 W08 WDB f
# TV Series 	0 Ax_Men KB W09 W08 WDB f
# TV series	0 Lastikman_(TV_series) KB W08 W09 WDB f
# TV series	0 Mud_(TV_series) W08 W09 WDB f
# The Album 	0 The_New_Album KB W09 W08 WDB f
# The Allman Brothers Band Museum	0 The_Allman_Brothers_Band_Museum WDB f
# The Capital of the Republic of Abkhazia 	0 Sukhumi KB W09 W08 WDB f
# The Impressions song	0 Amen_(The_Impressions_song) f
# The Motherboard, Motion Recordings 	0 "Snake_Treaty"_-_Motherboard_E-Comp_(_The_Motherboard,_Motion_Recordings_) f
# The One album	0 SuperPsychoSexy KB W08 f
# The TV Series	0 I_Spy_(_The_TV_Series) f
# The Territorial Magazine	0 Inkundla_Ya_Bantu f
# Tiger	0 Reintroduction W09 W08 WDB f
# Trey Songz	0 I_Need_a_Girl_(Trey_Songz_song) WDB f
# Two Cent Bridge 	0 Two_Cent_Bridge KB W09 W08 WDB f
# Türçmence 	0 Turkmen_language W09 W08 WDB f
# UET Taxila 	0 University_of_Engineering_and_Technology,_Taxila KB W09 W08 WDB f
# UK Parliament constituency	0 Winchelsea_(UK_Parliament_constituency) W09 W08 WDB f
# US Television show 	0 I_Dream_of_Jeannie KB W09 W08 WDB f
# USA	0 Learning_disability KB D W09 W08 WDB f
# Upadhyaya	0 Nalini_Koirala_(_Upadhyaya) f
# Van Buren County, Michigan	0 North_Point_Park_(Van_Buren_County,_Michigan) W09 WDB f
# Vulgar 	0 "Find_Yourself"_-_Orchestrated_B_Boy_Screams_(_Vulgar_) f
# Vyas Gaddi 	0 Rishi_Ved_Vyas_(_Vyas_Gaddi_) f
# W.I.T.C.H 	0 Prince_Phobos W09 W08 WDB f
# Warangal Dist 	0 Thorrur,_Warangal f
# West Coast Pop Art Experimental Band album	0 Volume_One_(West_Coast_Pop_Art_Experimental_Band_album) KB W09 W08 WDB NR RWB f
# Wirral Sound	0 Moreton_Boys_Brigade_&_Girls_Brigade_Band_(_Wirral_Sound) f
# Woetzel 	0 Ebony_Concerto_(_Woetzel_) f
# Z-Ro's album	0 Heroin_(_Z-Ro's_album) RWB f
# \\\ 	0 Three_(_\\\_) f
# _(region)	0 Region D W09 W08 WDB t
# _bao_a_qu	0 Á_Bao_A_Qu W08 W09 WDB c t
# _begl ighinn	0 Ó_Begléighinn c t
# _bl sq_blom	0 Õ_Blésq_Blom KB W08 W09 WDB c t
# _botni	0 Í_Botni W08 W09 WDB c t
# _bout_de_souffle	0 Breathless_(1960_film) KB W08 W09 WDB c t
# _cadhla	0 Ó_Cadhla c t
# _canada!_mon_pays,_mes_amours	0 Ô_Canada!_mon_pays,_mes_amours W08 W09 WDB c t
# _cath in	0 Ó_Cathain NR RWB W08 W09 WDB c t
# _cause_des_gar ons	0 À_cause_des_garçons_(song) KB W09 W08 WDB NR RWB c
# _cause_des_gar ons_(song)	0 À_cause_des_garçons_(song) KB W09 W08 WDB NR RWB t
# _chacun_sa_chanson	0 À_Chacun_Sa_Chanson KB NR R09 RDB RWB W08 c t
# _chaque_pas	0 À_chaque_pas KB W08 W09 WDB c t
# _cian in	0 Ó_Cianáin c t
# _cl irigh	0 Ó_Cléirigh W08 W09 WDB c t
# _cobhthaigh	0 Ó_Cobhthaigh c t
# _coeur_l ger_sommeil_sanglant	0 À_Coeur_Léger_Sommeil_Sanglant KB W08 W09 WDB c t
# _coile in	0 Ó_Coileáin c t
# _contre-courant	0 À_contre-courant W08 W09 WDB c t
# _corps_perdu	0 À_corps_perdu KB W08 W09 WDB c t
# _court_baronets	0 Baron_Heytesbury W08 W09 WDB c t
# _cremnosedum	0 ×_Cremnosedum WDB c t
# _cyathidaria	0 ×_Cyathidaria W08 W09 WDB c t
# _d laigh	0 Ó_Dálaigh W08 W09 WDB c t
# _daimh n	0 Ó_Daimhín W08 W09 WDB c t
# _deriva	0 Adrift_(2009_film) c t
# _domhnall in	0 Ó_Domhnalláin c t
# _double_tour	0 À_double_tour c t
# _duibh_d _bhoireann	0 O'Davoren NR RWB W08 W09 WDB c t
# _duibhgeann in	0 Ó_Duibhgeannáin WDB c t
# _fatshedera_lizei	0 Fatshedera_lizei W08 W09 WDB c t
# _fleur_de_toi	0 �_fleur_de_toi RWB c t
# _gadhra	0 Gadhra KB W08 W09 WDB c t
# _gadhra_chiefs_of_the_name	0 Ó_Gadhra_Chiefs_of_the_Name c t
# _gauche_en_sortant_de_l'ascenseur	0 Door_on_the_Left_as_You_Leave_the_Elevator KB W08 W09 WDB c t
# _gauche_toute!_gen ve	0 À_gauche_toute!_Genève W08 W09 WDB c t
# _gogo:_live_on_tour	0 À_Gogo:_Live_on_Tour KB W08 W09 WDB c t
# _hauteur_d'homme	0 À_Hauteur_d'homme KB W08 W09 WDB c t
# _hos in	0 Hassan_(surname) W08 W09 WDB c t
# _l'amiral	0 À_l'amiral W09 WDB c t
# _l'origine	0 À_l'origine KB W08 W09 WDB c t
# _la_belle_de_mai	0 A_la_Belle_de_Mai KB NR R09 RDB RWB W08 c t
# _la_carte	0 A_la_Carte_(Erste_Allgemeine_Verunsicherung_album) KB W09 W08 WDB NR RWB c
# _la_carte_(erste_allgemeine_verunsicherung_album)	0 A_la_Carte_(Erste_Allgemeine_Verunsicherung_album) KB W09 W08 WDB NR RWB t
# _la_folie..._pas_du_tout	0 He_Loves_Me..._He_Loves_Me_Not_(film) KB W08 W09 WDB c t
# _la_recherche_d'une_musique_concr te	0 In_Search_of_a_Concrete_Music WDB c t
# _la_vie,_ _la_mort_!	0 À_la_vie,_à_la_mort_! W09 WDB c t
# _lorc in	0 Lorcin W09 WDB c t
# _m ti_s l	0 Á_Móti_Sól KB W08 W09 WDB c t
# _ma_mani re...	0 À_ma_manière_(album) KB W09 W08 WDB NR RWB c
# _ma_mani re..._(album)	0 À_ma_manière_(album) KB W09 W08 WDB NR RWB t
# _maolconaire	0 Ó_Maolconaire W08 W09 WDB c t
# _neill_dynasty_today	0 Ó_Neill_Dynasty_Today NR RWB W08 W09 WDB c t
# _nos_actes_manqu s	0 À_nos_actes_manqués KB W08 W09 WDB c t
# _nous_la_libert 	0 À_nous_la_liberté KB W08 W09 WDB c t
# _o_tchan	0 É_o_Tchan! W08 W09 WDB c t
# _off	0 Off D W08 W09 WDB c t
# _pa ,_ 	0 Ó_Paí,_Ó KB W08 W09 WDB c t
# _partir_de_maintenant	0 À_Partir_de_Maintenant c t
# _preciso_saber_viver	0 É_Preciso_Saber_Viver KB W08 W09 WDB c t
# _prendre_ou_ _laisser	0 À_prendre_ou_à_laisser W08 W09 WDB c t
# _proibido_fumar	0 É_Proibido_Fumar c t
# _propos	0 À_Propos W08 W09 WDB c t
# _qui_elle_appartient	0 Veuillez_rendre_l'âme_(à_qui_elle_appartient) KB W09 W08 WDB f
# _raghallaigh	0 Riley_(surname) NR RWB W08 W09 WDB c t
# _rebours	0 À_rebours KB W08 W09 WDB c t
# _rothl in	0 Ó_Rothláin W08 W09 WDB c t
# _rothlain	0 Ó_Rothláin W08 W09 WDB c t
# _siochfhradha	0 �_Siochfhradha c t
# _skugga_hrafnsins	0 Í_skugga_hrafnsins KB NR RWB W08 W09 WDB c t
# _suivre	0 À_Suivre W08 W09 WDB c t
# _tardi	0 È_tardi c
# _tardi_(single)	0 È_tardi t
# _ton_image	0 À_ton_image KB W08 W09 WDB c t
# _tout_de_suite	0 À_tout_de_suite NR RWB W08 W09 WDB c t
# _toute_allure	0 À_toute_allure c t
# _travers_la_for t	0 À_travers_la_forêt KB W08 W09 WDB c t
# _vendre	0 For_Sale_(film) c t
# _vi_ _aik	0 Allmänna_Idrottsklubben W08 W09 WDB c t
# _y n_district	0 Ý_Yên_District W09 WDB c t
# ` 	0 Grave_accent W09 W08 WDB f
# a Stone cross	0 Cruzeiro_(_a_Stone_cross) f
# a lady journalist from Saudi Arabia	0 Sameera_Aziz f
# a lady journalist from saudi arabia	0 Sameera_Aziz f
# a stone cross	0 Cruzeiro_(_a_Stone_cross) f
# a. r. gurney, jr play	0 The_Golden_Age_(_A._R._Gurney,_Jr_play) f
# a_luchar!	0 ¡A_Luchar! W08 W09 WDB c t
# a_n'finira_jamais	0 Ça_n'finira_jamais W09 WDB c t
# a_ne_change_pas_un_homme	0 Ça_ne_change_pas_un_homme W09 WDB c t
# a_plane_pour_moi	0 Ça_plane_pour_moi KB W08 W09 WDB c t
# a_qui n_le_importa?	0 ¿A_quién_le_importa? KB W08 W09 WDB c t
# a_va	0 Ça_Va KB W08 W09 WDB c t
# abbas_ibn_ abd_al-muttalib	0 ‘Abbas_ibn_‘Abd_al-Muttalib W09 WDB c t
# abhadh	0 Forfeda W09 W08 WDB c
# abhadh_(letter)	0 Forfeda W09 W08 WDB t
# abolitionist	0 William_Still W08 W09 WDB f
# adios_amigos!	0 ¡Adios_Amigos! KB W08 W09 WDB c t
# admiral	0 Chaloner_Ogle W08 W09 WDB f
# aircraft	0 Northrop_Grumman_Firebird f
# akiai	0 Šakiai KB W08 W09 WDB c t
# akotis	0 Šakotis W08 W09 WDB c t
# akovica	0 Đakovica KB W08 W09 WDB c t
# akse	0 Öakse c t
# akyamuni	0 Çakyamuni W08 W09 WDB c t
# al green song	0 Full_of_Fire_(song) f
# alarma!	0 ¡Alarma!_(album) KB W08 W09 WDB c
# alarma!	0 ¡Alarma!_(magazine) W08 W09 WDB c
# alarma!_(album)	0 ¡Alarma!_(album) KB W09 W08 WDB t
# alarma!_(magazine)	0 ¡Alarma!_(magazine) W09 W08 WDB t
# alarma!_records	0 Alarma_Records KB W08 W09 WDB c t
# album	0 Despised_(_Album) RWB f
# album	0 Gold_(_album) W09 f
# album	0 Time_Exposure_(Little_River_Band_album) KB W08 W09 WDB f
# alik_enerji	0 Çalık_Enerji W08 W09 WDB c t
# all _t !	0 ¡Allá_tú! W08 W09 WDB c t
# all-time_quarterback!	0 ¡All-Time_Quarterback! W08 W09 WDB c t
# aloire	0 Caloire R08 W09 WDB c t
# alovci	0 Šalovci W08 W09 WDB c t
# altys	0 Žaltys W08 W09 WDB c t
# alvarinis	0 �alvarinis RWB c t
# alxanqala	0 Çalxanqala KB W08 W09 WDB c t
# am ri	0 Chameria W08 W09 WDB c t
# am ria	0 Chameria W08 W09 WDB c t
# american rapper	0 Romeo_(_American_rapper) R08 R09 RDB f
# amigos!	0 ¡Amigos! KB W08 W09 WDB c t
# amoluk	0 Çamoluk KB W08 W09 WDB c t
# amon_de_buitl ar	0 Éamon_de_Buitléar W08 W09 WDB c t
# amon_de_valera	0 Éamon_de_Valera KB W08 W09 WDB c t
# amon_gilmore	0 Eamon_Gilmore KB W08 W09 WDB c t
# amon_rooney	0 Éamon_Rooney W08 W09 WDB c t
# amon_zayed	0 Éamon_Zayed W08 W09 WDB c t
# amonn_burns	0 Éamonn_Burns KB W08 W09 WDB c t
# amonn_ceannt	0 Éamonn_Ceannt KB W08 W09 WDB c t
# amonn_corcoran	0 Éamonn_Corcoran KB W08 W09 WDB c t
# amonn_de_bh l	0 Éamonn_de_Bhál c t
# amonn_fitzmaurice	0 Éamonn_Fitzmaurice W09 WDB c t
# amonn_grimes	0 Éamonn_Grimes KB W08 W09 WDB c t
# amonn_lawlor	0 Éamonn_Lawlor KB W08 W09 WDB c t
# amonn_macthom is	0 Éamonn_MacThomáis NR RWB W09 WDB c t
# amonn_mongey	0 Éamonn_Mongey c t
# amonn_morrissey	0 Éamonn_Morrissey c t
# amonn_o'donoghue	0 Éamonn_O'Donoghue KB W08 W09 WDB c t
# amonn_o'shea	0 Éamonn_O'Shea c t
# amonn_taaffe	0 Éamonn_Taaffe W09 WDB c t
# amyuva	0 Çamyuva KB W08 W09 WDB c t
# an geata mor 	0 Binghamstown W08 W09 WDB f
# an geata mór 	0 Binghamstown W08 W09 WDB f
# anakkale	0 Çanakkale W08 W09 WDB c t
# anakkale_dardanelspor	0 Dardanel_Spor_A.Ş. W09 WDB c t
# anakkale_martyrs'_memorial	0 Çanakkale_Martyrs'_Memorial W08 W09 WDB c t
# anakkale_onsekiz_mart_university	0 COMU KB RWB W08 W09 WDB c t
# anakkale_province	0 Çanakkale_Province KB W08 W09 WDB c t
# andahar	0 Çandahar KB W08 W09 WDB c t
# andarli_ali_pasha	0 Çandarlı_Ali_Paşa NR RWB W08 W09 WDB c t
# ando_bien_pedo!	0 ¡Ando_Bien_Pedo! c t
# andu	0 Rhea_(bird) W08 W09 WDB c t
# andut 	0 Ñandutí W08 W09 WDB c t
# anita,_no_te_rajes!	0 ¡Anita,_no_te_rajes! c t
# ankaya	0 Çankaya D W08 W09 WDB c t
# ankaya,_ankara	0 Çankaya,_Ankara KB W08 W09 WDB c t
# ankaya_ niversitesi	0 Çankaya_University KB W08 W09 WDB c t
# ankaya_university	0 Çankaya_University KB W08 W09 WDB c t
# ankiri	0 Çankırı D KB W08 W09 WDB c t
# ankiri_province	0 Çankırı_Province KB W08 W09 WDB c t
# anthony hamilton album	0 XTC_(album) KB W08 W09 WDB f
# anyataq	0 Çanyataq KB W08 W09 WDB c t
# aphasic tone 	0 "White_Bird"_-_No_Man's_Religion_Immigrate_Us_p.2_-_(_Aphasic_Tone_) f
# aplar	0 Asia_Pacific_League_of_Associations_for_Rheumatology W08 W09 WDB f
# apmppe	0 Acute_posterior_multifocal_placoid_pigment_epitheliopathy W08 W09 WDB f
# aprand	0 Çaprand W09 WDB c t
# ar_mac_dedad	0 Íar_mac_Dedad c t
# architecture and interior design office in swizzerland	0 Architecture_Retail_Rites_(_architecture_and_interior_design_office_in_swizzerland) W09 f
# ardak	0 Çardak KB W08 W09 WDB c t
# ardak_airport	0 Denizli_Çardak_Airport KB W08 W09 WDB c t
# ardak_han	0 Çardak KB W08 W09 WDB c t
# arlaid	0 Èarlaid W08 W09 WDB c t
# arnovica_district	0 Žarnovica_District KB W08 W09 WDB c t
# aro ice	0 Žarošice c t
# aro,_pyr n es-atlantiques	0 Çaro,_Pyrénées-Atlantiques W08 W09 WDB c t
# arshov 	0 Çarshovë W09 WDB c t
# as Sakuni 	0 ETV's_Sri_Bhagavatam_(_as_Sakuni_) f
# as sakuni 	0 ETV's_Sri_Bhagavatam_(_as_Sakuni_) f
# ask_a_mexican!	0 ¡Ask_a_Mexican! W08 W09 WDB c t
# assembly constituency	0 Arfon_(Assembly_constituency) W08 W09 WDB f
# assembly constituency	0 Thalassery_(_Assembly_Constituency) NR RWB WDB f
# assembly constituency	0 Vale_of_Clwyd_(Assembly_constituency) W08 W09 WDB f
# atal_h y k	0 Çatalhöyük W08 W09 WDB c t
# atalada	0 Çatalada W08 W09 WDB c t
# atalca	0 Çatalca W08 W09 WDB c t
# atalh y k	0 Çatalhöyük W08 W09 WDB c t
# atalsu	0 Çatalsu W08 W09 WDB c t
# atalzeytin	0 Çatalzeytin W08 W09 WDB c t
# atv	0 Why_can't_I_go_Home_(_ATV) f
# australia	0 List_of_former_power_stations_in_Victoria,_Australia L NR RWB W08 W09 WDB f l
# australia 1970's to present	0 Stylus_(band) W08 W09 WDB f
# author	0 William_Bell_(author) f
# author and leadership expert 	0 Chris_Widener_(author) f
# auze_cathedral	0 Eauze_Cathedral NR RWB W08 W09 WDB c t
# avdarhisar	0 Çavdarhisar W08 W09 WDB c t
# ay,_caramba!	0 ¡Ay,_caramba! W08 W09 WDB c t
# ay,_carmela!	0 ¡Ay_Carmela!_(film) KB W09 W08 WDB c
# ay,_carmela!_(film)	0 ¡Ay_Carmela!_(film) KB W09 W08 WDB t
# ay,_qu _deseo!	0 ¡Ay,_qué_deseo! c t
# ay,_se or,_se or!	0 ¡Ay,_Señor,_Señor! W08 W09 WDB c t
# ay_carmela!	0 ¡Ay_Carmela!_(film) KB W09 W08 WDB c
# ay_carmela!_(film)	0 ¡Ay_Carmela!_(film) KB W09 W08 WDB t
# ayeli_mine	0 Çayeli_mine c t
# aykara	0 Çaykara W08 W09 WDB c t
# aykur_rizespor	0 Çaykur_Rizespor W08 W09 WDB c t
# ayrud	0 Çayrud KB W08 W09 WDB c t
# b niste	0 Ébéniste W08 W09 WDB c t
# b_pau-orthez	0 Élan_Béarnais_Pau-Orthez W08 W09 WDB c t
# bach-palenberg	0 Übach-Palenberg KB W08 W09 WDB c t
# balos	0 Abalos W08 W09 WDB c t
# band	0 Pru_(Thai_band) KB RWB W08 W09 WDB f
# band	0 The_Video_Dead_(band) f
# band	0 U_Totem_(band) f
# bar_of_killibar_beg	0 Íbar_of_Killibar_Beg c t
# barok	0 Óbarok KB W08 W09 WDB c t
# basta_ya!	0 ¡Basta_Ya! W08 W09 WDB c t
# basta_ya!	0 ¡Basta_ya!_(song) c
# basta_ya!_(song)	0 ¡Basta_ya!_(song) t
# bastardos!	0 ¡Bastardos! KB W09 W08 WDB c
# bastardos!_(album)	0 ¡Bastardos! KB W09 W08 WDB t
# bastardos_en_vivo!	0 ¡Bastardos_en_Vivo! KB W08 W09 WDB c t
# baty	0 Ébaty W08 W09 WDB c t
# bauche	0 Ébauche D W08 W09 WDB c t
# bb_638	0 Prussian_P_8 KB W08 W09 WDB c t
# bbe_of_oxford	0 Æbbe_of_Oxford c t
# bbe_the_younger	0 Aebbe_the_Younger KB NR R09 RDB RWB W08 c t
# bbingas	0 Æbbingas c t
# bear stone	0 Battle_of_Mečkin_Kamen f
# becse	0 Bečej KB W08 W09 WDB c t
# bel_blatt	0 Übel_Blatt W08 W09 WDB c t
# belbach	0 Übelbach KB W08 W09 WDB c t
# belo horizonte	0 Vilarinho_(_Belo_Horizonte) f
# bendi Kosovar	0 Troja_(bendi_kosovar) WDB f
# bendi kosovar	0 Troja_(bendi_kosovar) WDB f
# beni_flue	0 Ebnefluh KB W08 W09 WDB c t
# benr 	0 Aabenraa W08 W09 WDB c t
# ber_alles	0 Über_Alles KB W08 W09 WDB c t
# ber_das_farbige_licht_der_doppelsterne_und_einiger_anderer_gestirne_des_himmels	0 Über_das_farbige_Licht_der_Doppelsterne_und_einiger_anderer_Gestirne_des_Himmels W08 W09 WDB c t
# ber_die_ sthetische_erziehung_des_menschen	0 On_the_Aesthetic_Education_of_Man c t
# ber_die_von_der_molekularkinetischen_theorie_der_w rme_geforderte_bewegung_von_in_ruhenden_fl ssigkeiten_suspendierten_teilchen	0 Über_die_von_der_molekularkinetischen_Theorie_der_Wärme_geforderte_Bewegung_von_in_ruhenden_Flüssigkeiten_suspendierten_Teilchen W08 W09 WDB c t
# ber_donn	0 Donn D W08 W09 WDB c t
# ber_finn	0 Eber_Finn W08 W09 WDB c t
# ber_goober	0 Über_Goober KB W08 W09 WDB c t
# ber_quantentheoretische_umdeutung_kinematischer_und_mechanischer_beziehungen	0 Über_quantentheoretische_Umdeutung_kinematischer_und_mechanischer_Beziehungen W08 W09 WDB c t
# berackern	0 Überackern KB W08 W09 WDB c t
# bereisenbach	0 Übereisenbach KB W08 W09 WDB c t
# beretsch-unterland	0 Überetsch-Unterland W08 W09 WDB c t
# berfremdung	0 Überfremdung W08 W09 WDB c t
# bergamo 	0 Santa_Maria_Maggiore,_Bergamo W08 W09 WDB f
# berherrn	0 Überherrn KB W08 W09 WDB c t
# berjam	0 Überjam KB W08 W09 WDB c t
# bermensch	0 Übermensch W08 W09 WDB c t
# berplay	0 Überplay W08 W09 WDB c t
# bers_ende_der_welt	0 Übers_Ende_der_Welt KB W08 W09 WDB c t
# bersaxen	0 Übersaxen KB W08 W09 WDB c t
# bersbach	0 Übersbach KB W08 W09 WDB c t
# berschall_1996	0 �berschall_1996 c t
# bersee_museum_bremen	0 Übersee_Museum_Bremen c t
# berseering_bv_v_nordic_construction_company_baumanagement_gmbh	0 Überseering_BV_v_Nordic_Construction_Company_Baumanagement_GmbH c t
# bersoldier	0 ÜberSoldier KB W08 W09 WDB c t
# bersviller	0 Ébersviller W08 W09 WDB c t
# berwald	0 Überwald_(Bergstraße) W09 W08 WDB c
# berwald_(bergstra e)	0 Überwald_(Bergstraße) W09 W08 WDB t
# berzone	0 Überzone KB W08 W09 WDB c t
# berzone_presents:_y4k	0 Überzone_Presents:_Y4K KB W08 W09 WDB c t
# bezmisht	0 St._Demetrius'_Church,_Bezmisht f
# bidos,_brazil	0 Óbidos,_Brazil W08 W09 WDB c t
# bidos,_par 	0 Óbidos,_Brazil W08 W09 WDB c t
# bidos,_portugal	0 Óbidos,_Portugal KB W08 W09 WDB c t
# bihbar lower secondary school 	0 Shree_Bihabar_Lower_Secondary_School f
# bila_cb	0 Óbila_CB c t
# biman bangladesh airlines cricketer	0 Mohammad_Rafiqul_Islam W08 W09 WDB f
# biology	0 Family_(biology) W09 W08 WDB f
# birr100	0 Birhane_getachew_(_birr100) f
# bishop	0 Manfred_Müller_(_bishop) f
# bishop of Rochester	0 Waermund_II KB W09 W08 WDB NR RWB f
# bishop of rochester	0 Waermund_II KB NR RWB W08 W09 WDB f
# bj r	0 Åbjør W08 W09 WDB c t
# bj rvatnet	0 Åbjørvatnet KB W08 W09 WDB c t
# bjoerk dvd 	0 Live_at_Royal_Opera_House KB W08 W09 WDB f
# bjoerk dvd 	0 Live_in_Cambridge KB W08 W09 WDB f
# bjoerk dvd 	0 MTV_Unplugged_/_Live W08 W09 WDB f
# bjoerk dvd 	0 The_Inner_or_Deep_Part_of_an_Animal_or_Plant_Structure KB W08 W09 WDB f
# bjoerk dvd 	0 Vessel_(DVD) KB W08 W09 WDB f
# bjork dvd 	0 Live_at_Royal_Opera_House KB W08 W09 WDB f
# bjork dvd 	0 Live_in_Cambridge KB W08 W09 WDB f
# bjork dvd 	0 MTV_Unplugged_/_Live W08 W09 WDB f
# bjork dvd 	0 The_Inner_or_Deep_Part_of_an_Animal_or_Plant_Structure KB W08 W09 WDB f
# bjork dvd 	0 Vessel_(DVD) KB W08 W09 WDB f
# björk dvd 	0 Live_at_Royal_Opera_House KB W08 W09 WDB f
# björk dvd 	0 Live_in_Cambridge KB W08 W09 WDB f
# björk dvd 	0 MTV_Unplugged_/_Live W08 W09 WDB f
# björk dvd 	0 The_Inner_or_Deep_Part_of_an_Animal_or_Plant_Structure KB W08 W09 WDB f
# björk dvd 	0 Vessel_(DVD) KB W08 W09 WDB f
# blange	0 Éblange W08 W09 WDB c t
# blarn	0 Öblarn KB W08 W09 WDB c t
# bluegrass artist 	0 Michael_Cleveland_(bluegrass_musician) W08 W09 WDB f
# bo_academy	0 Åbo_Akademi_University KB W08 W09 WDB c t
# bo_akademi	0 Åbo_Akademi_University KB W08 W09 WDB c t
# bo_akademi_university	0 Åbo_Akademi_University KB W08 W09 WDB c t
# bo_and_bj rneborg_county	0 �bo_and_Bj�rneborg_County RWB c t
# bo_bloodbath	0 Åbo_Bloodbath c t
# bo_castle	0 Turku_Castle W08 W09 WDB c t
# bo_landtag	0 Diet_of_Finland W08 W09 WDB c t
# bo_lantdag	0 Diet_of_Finland W08 W09 WDB c t
# bo_nation	0 Åbo_Nation c t
# bo_underr ttelser	0 Åbo_Underrättelser KB W08 W09 WDB c t
# boninho 	0 J._B._de_Oliveira_(_Boninho_) f
# book	0 Coq_Rouge_(novel) W08 W09 WDB f
# book 	0 Chandler_College_(book) NR RWB W08 W09 WDB f
# book 	0 The_Lazy_Man's_Guide_to_Enlightenment KB W08 W09 WDB f
# bouleau	0 Ébouleau KB W08 W09 WDB c t
# boy band	0 Big_Four_(band) f
# br on	0 Ébréon W08 W09 WDB c t
# brah m_ganz	0 Ábrahám_Ganz W08 W09 WDB c t
# brah m_lederer	0 Abraham_Lederer NR RWB W08 W09 WDB c t
# brah mhegy	0 Ábrahámhegy KB W08 W09 WDB c t
# braham_olano	0 Abraham_Olano KB W08 W09 WDB c t
# brand	0 O'Neill_(brand) W08 W09 WDB f
# bri _lagoon	0 Ébrié_Lagoon W08 W09 WDB c t
# british tv series	0 Blue_Murder_(_British_TV_series) f
# britney spears' 	0 Here_I_Come_(_Britney_Spears'_) R08 R09 RDB f
# brunei tv series 	0 The_Biggest_Loser_(Brunei_TV_series) f
# brystir	0 Ábrystir c t
# budav r	0 Óbudavár KB W08 W09 WDB c t
# burzum album	0 Fallen_(Burzum_album) f
# by,_v xj 	0 Åby,_Växjö WDB c t
# by_if	0 Åby_IF c t
# by_racetrack	0 Åby_Racetrack W09 WDB c t
# byggeby	0 Åbyggeby WDB c t
# byh j	0 Aabyhøj W08 W09 WDB c t
# c ne	0 CNE D W08 W09 WDB c t
# c_eo	0 Óc_Eo W08 W09 WDB c t
# c_eo_culture	0 Óc_Eo W08 W09 WDB c t
# cailles_de_lune	0 Écailles_de_Lune c t
# caillon	0 Écaillon W08 W09 WDB c t
# cairo 	0 Chaar_Hachamaim_Synagogue_(Cairo) KB NR R09 RDB RWB W08 f
# calles-alix	0 Écalles-Alix W08 W09 WDB c t
# camarero!,_ camarero!	0 ¡Camarero!,_¡Camarero! c t
# card game	0 Snap_(card_game) KB NR RWB W08 W09 WDB f
# cardenville-la-campagne	0 Écardenville-la-Campagne W08 W09 WDB c t
# cardenville-sur-eure	0 Écardenville-sur-Eure W08 W09 WDB c t
# caro_passos_de_oliveira	0 Ícaro_Passos_de_Oliveira W08 W09 WDB c t
# catering Arts , Science , Commerce etc. 	0 Feroz_Gandhi_Degree_College_(_catering_Arts_,_Science_,_Commerce_etc._) f
# catering arts , science , commerce etc. 	0 Feroz_Gandhi_Degree_College_(_catering_Arts_,_Science_,_Commerce_etc._) f
# causseville	0 Écausseville W08 W09 WDB c t
# caussinnes	0 Écaussinnes KB W08 W09 WDB c t
# cdm	0 Clean_Development_Mechanism D W08 W09 WDB c t
# chalas	0 Échalas W08 W09 WDB c t
# challat	0 Échallat W08 W09 WDB c t
# challon	0 Échallon KB W08 W09 WDB c t
# chalou	0 Échalou W08 W09 WDB c t
# chancellor unca	0 Anne_Ponder_(_Chancellor_UNCA) f
# chandelys	0 Échandelys W08 W09 WDB c t
# changistes	0 Échangistes c t
# charcon	0 Écharcon W08 W09 WDB c t
# charleroi 	0 Chatelet_(_Charleroi_) f
# chassi res	0 Échassières KB W08 W09 WDB c t
# chattha	0 Thatha_Shamsa_(Chattha) W09 WDB f
# chauffour	0 Échauffour W08 W09 WDB c t
# chauguette	0 Bartizan W08 W09 WDB c t
# chebrune	0 Échebrune W08 W09 WDB c t
# chemines	0 Échemines KB W08 W09 WDB c t
# chemir 	0 Échemiré W08 W09 WDB c t
# chenans	0 Échenans W08 W09 WDB c t
# chenans-sous-mont-vaudois	0 Échenans-sous-Mont-Vaudois W08 W09 WDB c t
# chenevex	0 Échenevex KB W08 W09 WDB c t
# chengdu datang	0 Datang_town_(Chengdu_Datang) NR RWB W09 WDB f
# chenoz-la-m line	0 Échenoz-la-Méline W08 W09 WDB c t
# chenoz-le-sec	0 Échenoz-le-Sec W08 W09 WDB c t
# cher_platt	0 Aachen_dialect W08 W09 WDB c t
# chevannes,_c te-d'or	0 Échevannes,_Côte-d'Or W08 W09 WDB c t
# chevannes,_doubs	0 Échevannes,_Doubs W08 W09 WDB c t
# chevis	0 Échevis W08 W09 WDB c t
# chevronne	0 Échevronne W08 W09 WDB c t
# chezeaux	0 Échezeaux W08 W09 WDB c t
# chigey	0 Échigey W08 W09 WDB c t
# chilenenses	0 Æchilenenses W08 W09 WDB c t
# chilleuses	0 Échilleuses W08 W09 WDB c t
# chir 	0 Échiré W08 W09 WDB c t
# chirolles	0 Échirolles W08 W09 WDB c t
# choppe	0 Etching D W08 W09 WDB c t
# chouboulains	0 Échouboulains W08 W09 WDB c t
# chsle	0 Oechsle_scale D W08 W09 WDB c t
# chtelhausen	0 Üchtelhausen KB W08 W09 WDB c t
# cia tistico!	0 ¡Ciaütistico! KB W08 W09 WDB c t
# cido_argentino	0 Ácido_Argentino KB W08 W09 WDB c t
# cija	0 Écija W08 W09 WDB c t
# cija_balompi 	0 Écija_Balompié W08 W09 WDB c t
# cker _if	0 Öckerö_IF c t
# cker _municipality	0 Öckerö_Municipality KB W08 W09 WDB c t
# ckeritz	0 Ückeritz KB W08 W09 WDB c t
# ckerm nde	0 Ueckermünde KB W08 W09 WDB c t
# clade_des_moules	0 Seafood_boil W08 W09 WDB c t
# claibes	0 Éclaibes W08 W09 WDB c t
# clair	0 Éclair_(Kiddy_Grade) KB W08 W09 WDB c
# clair	0 Éclair_(pastry) W08 W09 WDB c
# clair_(kiddy_grade)	0 Éclair_(Kiddy_Grade) KB W09 W08 WDB t
# clair_(pastry)	0 Éclair_(pastry) W09 W08 WDB t
# claireurs_of_the_guard	0 Éclaireurs_of_the_Guard W09 WDB c t
# claireuses_et_ claireurs_de_france	0 Éclaireuses_et_Éclaireurs_de_France KB R09 RDB RWB W08 c t
# clairs_sur_l'au-del  	0 Éclairs_sur_l'au-delà… RWB W08 W09 WDB c t
# clance	0 Éclance KB W08 W09 WDB c t
# clans-nenon	0 Éclans-Nenon W08 W09 WDB c t
# claron-braucourt-sainte-livi re	0 Éclaron-Braucourt-Sainte-Livière W08 W09 WDB c t
# cleen, demune 	0 Well_(_Cleen,_Demune_) f
# cleux	0 Écleux W08 W09 WDB c t
# climeux	0 Éclimeux W08 W09 WDB c t
# club 	0 Soho_House_(club) W08 W09 WDB f
# clusier-vaux	0 Éclusier-Vaux W08 W09 WDB c t
# cluzelles	0 Écluzelles W08 W09 WDB c t
# cly	0 Calvi_-_Sainte-Catherine_Airport KB NR RWB W08 W09 WDB c t
# coivres	0 Écoivres W08 W09 WDB c t
# cole-valentin	0 École-Valentin W08 W09 WDB c t
# cole_ l mentaire_catholique_ lisabeth-bruy re	0 École_élémentaire_catholique_Élisabeth-Bruyère KB W08 W09 WDB c t
# cole_ l mentaire_catholique_pierre-elliott-trudeau	0 École_élémentaire_catholique_Pierre-Elliott-Trudeau W08 W09 WDB c t
# cole_ l mentaire_champlain	0 École_élémentaire_Champlain KB W08 W09 WDB c t
# cole_ l mentaire_jeanne-lajoie	0 École_élémentaire_Jeanne-Lajoie KB NR RWB W08 W09 WDB c t
# cole_ l mentaire_l'h ritage	0 École_élémentaire_L'Héritage KB W08 W09 WDB c t
# cole_ l mentaire_la_source	0 École_élémentaire_La_Source W08 W09 WDB c t
# cole_ l mentaire_les_rapides	0 École_élémentaire_Les_Rapides KB W08 W09 WDB c t
# cole_ l mentaire_marie-curie	0 École_élémentaire_Marie-Curie KB W08 W09 WDB c t
# cole_ l mentaire_nouvel_horizon	0 École_élémentaire_Nouvel_Horizon KB W08 W09 WDB c t
# cole_ l mentaire_pierre-elliott-trudeau	0 École_élémentaire_Pierre-Elliott-Trudeau KB W08 W09 WDB c t
# cole_active_bilingue_jeannine_manuel	0 École_Active_Bilingue_Jeannine_Manuel W08 W09 WDB c t
# cole_aux_quatre_vents	0 École_Aux_quatre_vents c t
# cole_biblique	0 École_Biblique WDB c t
# cole_bois-joli	0 École_Bois-Joli KB W08 W09 WDB c t
# cole_c sar_franck	0 École_César_Franck W08 W09 WDB c t
# cole_camondo	0 École_Nissim_de_Camondo RWB W08 W09 WDB c t
# cole_catholique_des_arts_et_m tiers	0 École_Catholique_des_Arts_et_Métiers W08 W09 WDB c t
# cole_cedardale_elementary	0 �cole_Cedardale_Elementary RWB c t
# cole_centrale_de_lyon	0 École_centrale_de_Lyon KB W08 W09 WDB c t
# cole_centrale_de_marseille	0 École_centrale_de_Marseille KB W08 W09 WDB c t
# cole_centrale_de_nantes	0 École_centrale_de_Nantes KB W08 W09 WDB c t
# cole_centrale_de_p kin	0 École_centrale_de_Pékin KB W08 W09 WDB c t
# cole_centrale_paris	0 École_centrale_Paris KB W08 W09 WDB c t
# cole_d'architecture_marne-la-vall e	0 École_d'Architecture_Marne-la-Vallée W09 WDB c t
# cole_d'informatique_d' lectronique_et_d'expertise_comptable	0 École_d'Informatique_d'Électronique_et_d'Expertise_comptable W08 W09 WDB c t
# cole_de_biologie_industrielle	0 École_de_Biologie_Industrielle KB W08 W09 WDB c t
# cole_de_l'air	0 Salon-de-Provence_Air_Base KB W08 W09 WDB c t
# cole_de_l'infanterie	0 École_de_l'infanterie c t
# cole_de_management_de_lyon	0 École_de_management_de_Lyon KB W08 W09 WDB c t
# cole_de_management_strasbourg	0 Institut_Européen_d'Etudes_Commerciales_Supérieures_de_Strasbourg NR RWB W08 W09 WDB c t
# cole_de_nancy	0 École_de_Nancy c t
# cole_de_physique_des_houches	0 École_de_Physique_des_Houches c t
# cole_de_technologie_sup rieure	0 École_de_technologie_supérieure KB W08 W09 WDB c t
# cole_de_th ologie_ vang lique_de_montr al	0 École_de_Théologie_Évangélique_de_Montréal KB W08 W09 WDB c t
# cole_des_arts_d coratifs	0 École_nationale_supérieure_des_arts_décoratifs W08 W09 WDB c t
# cole_des_chartes	0 École_Nationale_des_Chartes W08 W09 WDB c t
# cole_des_hautes_ tudes_commerciales	0 HEC_School_of_Management NR RDB RWB W08 W09 c t
# cole_des_hautes_ tudes_en_sciences_sociales	0 École_des_hautes_études_en_sciences_sociales NR RWB W08 W09 WDB c t
# cole_des_hautes_etudes	0 École_pratique_des_hautes_études W08 W09 WDB c t
# cole_des_jeunes_de_langues	0 École_des_Jeunes_de_langues W08 W09 WDB c t
# cole_des_mines	0 Groupe_des_écoles_des_mines W08 W09 WDB c t
# cole_des_mines_de_douai	0 École_des_Mines_de_Douai KB W08 W09 WDB c t
# cole_des_mines_de_nantes	0 École_des_mines_de_Nantes W08 W09 WDB c t
# cole_des_officiers_de_la_gendarmerie_nationale	0 Ecole_des_Officiers_de_la_Gendarmerie_Nationale NR RWB W08 W09 WDB c t
# cole_des_pionniers	0 École_des_Pionniers D W08 W09 WDB c t
# cole_des_pionniers	0 École_des_Pionniers_(BC) KB NR RDB RWB W08 W09 c
# cole_des_pionniers_(bc)	0 École_des_Pionniers_(BC) KB W09 W08 NR RWB RDB t
# cole_des_pionniers_(disambiguation)	0 École_des_Pionniers D W09 W08 WDB t
# cole_des_trois_gourmandes	0 École_des_trois_gourmandes W08 W09 WDB c t
# cole_des_voyageurs	0 École_des_Voyageurs KB W08 W09 WDB c t
# cole_du_carrefour	0 École_du_Carrefour KB W08 W09 WDB c t
# cole_du_louvre	0 École_du_Louvre KB W08 W09 WDB c t
# cole_du_pacifique	0 École_du_Pacifique KB W08 W09 WDB c t
# cole_estienne	0 École_Estienne c t
# cole_fran aise_d'ath nes	0 French_School_at_Athens W08 W09 WDB c t
# cole_fran aise_du_maine	0 École_Française_du_Maine c t
# cole_franco-nord	0 École_Franco-Nord KB W08 W09 WDB c t
# cole_franco-polonaise	0 École_Franco-Polonaise W08 W09 WDB c t
# cole_freudienne_de_paris	0 École_Freudienne_de_Paris W08 W09 WDB c t
# cole_golden_gate_middle_school	0 École_Golden_Gate_Middle_School KB W08 W09 WDB c t
# cole_h teli re_de_lausanne	0 École_hôtelière_de_Lausanne KB W08 W09 WDB c t
# cole_highland_secondary_school	0 École_Highland_Secondary_School KB W08 W09 WDB c t
# cole_internationale_de_cr ation_audiovisuelle_et_de_r alisation	0 Ecole_Internationale_de_Creation_Audiovisuelle_et_de_Réalisation NR RWB W08 W09 WDB c t
# cole_internationale_primaire_de_greenfield_park	0 Greenfield_Park_Primary_International_School KB W08 W09 WDB c t
# cole_j._h._picard_school	0 École_J._H._Picard_School KB W08 W09 WDB c t
# cole_l'odyss e	0 École_L'Odyssée W08 W09 WDB c t
# cole_libre_des_sciences_politiques	0 École_Libre_des_Sciences_Politiques W08 W09 WDB c t
# cole_margaret-underhill	0 École_Margaret-Underhill W08 W09 WDB c t
# cole_marie_brosset	0 École_Marie_Brosset W08 W09 WDB c t
# cole_mathieu-martin	0 École_Mathieu-Martin KB W08 W09 WDB c t
# cole_militaire	0 École_Militaire W08 W09 WDB c t
# cole_militaire	0 École_Militaire_(Paris_Métro) KB W08 W09 WDB c
# cole_militaire_(paris_m tro)	0 École_Militaire_(Paris_Métro) KB W09 W08 WDB t
# cole_mondiale_world_school	0 École_Mondiale_World_School W08 W09 WDB c t
# cole_munroe_junior_high_school	0 École_Munroe_Junior_High_School W08 W09 WDB c t
# cole_nationale_d'administration_publique	0 École_nationale_d'administration_publique KB W08 W09 WDB c t
# cole_nationale_d'ing nieurs_de_tarbes	0 École_nationale_d'ingénieurs_de_Tarbes KB W08 W09 WDB c t
# cole_nationale_de_cirque	0 École_nationale_de_cirque W08 W09 WDB c t
# cole_nationale_de_l'aviation_civile	0 École_nationale_de_l'aviation_civile W08 W09 WDB c t
# cole_nationale_de_la_france_d'outre-mer	0 École_Nationale_de_la_France_d'Outre-Mer W08 W09 WDB c t
# cole_nationale_de_la_magistrature	0 Grandes_écoles W08 W09 WDB c t
# cole_nationale_de_la_statistique_et_de_l'administration_ conomique	0 École_nationale_de_la_statistique_et_de_l'administration_économique KB W08 W09 WDB c t
# cole_nationale_de_m decine_et_pharmacie	0 École_nationale_de_médecine_et_pharmacie_(Senegal) W09 W08 WDB c
# cole_nationale_de_m decine_et_pharmacie_(senegal)	0 École_nationale_de_médecine_et_pharmacie_(Senegal) W09 W08 WDB t
# cole_nationale_des_beaux-arts_de_lyon	0 École_nationale_des_beaux-arts_de_Lyon W09 WDB c t
# cole_nationale_sup rieure_agronomique_de_montpellier	0 Agropolis_Fondation W08 W09 WDB c t
# cole_nationale_sup rieure_agronomique_de_rennes	0 École_Nationale_Supérieure_Agronomique_de_Rennes W08 W09 WDB c t
# cole_nationale_sup rieure_d' lectrochimie_et_d' lectrom tallurgie_de_grenoble	0 École_Nationale_Supérieure_d'Électrochimie_et_d'Électrométallurgie_de_Grenoble W08 W09 WDB c t
# cole_nationale_sup rieure_d' lectronique,_d' lectrotechnique,_d'informatique,_d'hydraulique,_et_de_t l communications	0 École_nationale_supérieure_d'électronique,_d'électrotechnique,_d'informatique,_d'hydraulique,_et_de_télécommunications KB NR RWB W08 W09 WDB c t
# cole_nationale_sup rieure_d' lectronique,_d' lectrotechnique,_d'informatique,_d'hydraulique_et_des_t l communications	0 École_nationale_supérieure_d'électronique,_d'électrotechnique,_d'informatique,_d'hydraulique,_et_de_télécommunications KB NR RWB W08 W09 WDB c t
# cole_nationale_sup rieure_d' lectronique,_informatique_et_radiocommunications_de_bordeaux	0 École_Nationale_Supérieure_d'Électronique,_Informatique_et_Radiocommunications_de_Bordeaux NR RWB W08 W09 WDB c t
# cole_nationale_sup rieure_d' lectronique_et_de_radio lectricit _de_grenoble	0 École_nationale_supérieure_d'électronique_et_de_radioélectricité_de_Grenoble KB W08 W09 WDB c t
# cole_nationale_sup rieure_d'agronomie_et_des_industries_alimentaires	0 École_Nationale_Supérieure_d'Agronomie_et_des_Industries_Alimentaires W08 W09 WDB c t
# cole_nationale_sup rieure_d'architecture_de_versailles	0 École_Nationale_Supérieure_d'Architecture_de_Versailles NR RWB W08 W09 WDB c t
# cole_nationale_sup rieure_d'arts_ _la_villa_arson	0 Villa_Arson WDB c t
# cole_nationale_sup rieure_d'informatique_et_de_math matiques_appliqu es_de_grenoble	0 École_nationale_supérieure_d'informatique_et_de_mathématiques_appliquées_de_Grenoble KB W08 W09 WDB c t
# cole_nationale_sup rieure_d'informatique_pour_l'industrie_et_l'enterprise	0 École_nationale_supérieure_d'informatique_pour_l'industrie_et_l'enterprise KB NR R09 RDB RWB W08 c t
# cole_nationale_sup rieure_d'ing nieurs_de_constructions_a ronautiques	0 École_nationale_supérieure_d'ingénieurs_de_constructions_aéronautiques KB W08 W09 WDB c t
# cole_nationale_sup rieure_d'ing nieurs_du_mans	0 Ensim KB W08 W09 WDB c t
# cole_nationale_sup rieure_d'ing nieurs_en_construction_a ronautique	0 École_nationale_supérieure_d'ingénieurs_de_constructions_aéronautiques KB W08 W09 WDB c t
# cole_nationale_sup rieure_d'ing nieurs_en_informatique_automatique_m canique_ nerg tique_ lectronique	0 École_Nationale_Supérieure_d'Ingénieurs_en_Informatique_Automatique_Mécanique_Énergétique_Électronique W08 W09 WDB c t
# cole_nationale_sup rieure_de_chimie_de_lille	0 École_nationale_supérieure_de_chimie_de_Lille W09 WDB c t
# cole_nationale_sup rieure_de_chimie_de_montpellier	0 École_nationale_supérieure_de_chimie_de_Montpellier W08 W09 WDB c t
# cole_nationale_sup rieure_de_chimie_de_paris	0 École_nationale_supérieure_de_chimie_de_Paris KB W08 W09 WDB c t
# cole_nationale_sup rieure_de_chimie_et_de_physique_de_bordeaux	0 École_nationale_supérieure_de_chimie_et_de_physique_de_Bordeaux W08 W09 WDB c t
# cole_nationale_sup rieure_de_l'a ronautique_et_de_l'espace	0 École_nationale_supérieure_de_l'aéronautique_et_de_l'espace KB W08 W09 WDB c t
# cole_nationale_sup rieure_de_m canique_et_d'a rotechnique	0 École_nationale_supérieure_de_mécanique_et_d'aérotechnique KB W08 W09 WDB c t
# cole_nationale_sup rieure_de_m canique_et_des_microtechniques	0 École_Nationale_Supérieure_de_Mécanique_et_des_Microtechniques W08 W09 WDB c t
# cole_nationale_sup rieure_de_physique,_ lectronique_et_mat riaux	0 École_nationale_supérieure_de_physique,_électronique_et_matériaux c t
# cole_nationale_sup rieure_de_physique_de_strasbourg	0 École_Nationale_Supérieure_de_Physique_de_Strasbourg W08 W09 WDB c t
# cole_nationale_sup rieure_de_techniques_avanc es	0 École_nationale_supérieure_de_techniques_avancées W08 W09 WDB c t
# cole_nationale_sup rieure_de_techniques_avanc es_de_bretagne	0 École_nationale_supérieure_des_ingénieurs_des_études_et_techniques_d'armement NR RWB W08 W09 WDB c t
# cole_nationale_sup rieure_des_arts_appliqu s_et_des_m tiers_d'art	0 École_nationale_supérieure_des_arts_appliqués_et_des_métiers_d'art c t
# cole_nationale_sup rieure_des_arts_d coratifs	0 École_nationale_supérieure_des_arts_décoratifs W08 W09 WDB c t
# cole_nationale_sup rieure_des_industries_agricoles_et_alimentaires	0 École_Nationale_Supérieure_des_Industries_Agricoles_et_Alimentaires W08 W09 WDB c t
# cole_nationale_sup rieure_des_industries_chimiques	0 École_Nationale_Supérieure_des_Industries_Chimiques W08 W09 WDB c t
# cole_nationale_sup rieure_des_ing nieurs_en_arts_chimiques_et_technologiques	0 École_nationale_supérieure_des_ingénieurs_en_arts_chimiques_et_technologiques W08 W09 WDB c t
# cole_nationale_sup rieure_des_m tiers_de_l'image_et_du_son	0 La_Fémis NR R08 W09 WDB c t
# cole_nationale_sup rieure_des_mines_de_nancy	0 École_Nationale_Supérieure_des_Mines_de_Nancy NR RWB W08 W09 WDB c t
# cole_nationale_sup rieure_des_mines_de_paris	0 École_nationale_supérieure_des_mines_de_Paris KB W08 W09 WDB c t
# cole_nationale_sup rieure_des_mines_de_saint- tienne	0 École_Nationale_Supérieure_des_Mines_de_Saint-Étienne KB W08 W09 WDB c t
# cole_nationale_sup rieure_des_t l communications_de_bretagne	0 École_nationale_supérieure_des_télécommunications_de_Bretagne KB W08 W09 WDB c t
# cole_nationale_v t rinaire_d'alfort	0 École_nationale_vétérinaire_d'Alfort W09 WDB c t
# cole_navale	0 École_Navale W08 W09 WDB c t
# cole_normale_de_musique	0 École_Normale_de_Musique_de_Paris W08 W09 WDB c t
# cole_normale_h bra que	0 École_Normale_Hébraïque W08 W09 WDB c t
# cole_normale_sup rieure	0 École_Normale_Supérieure W08 W09 WDB c t
# cole_normale_sup rieure_de_cachan	0 École_Normale_Supérieure_de_Cachan W08 W09 WDB c t
# cole_normale_sup rieure_de_fontenay-aux-roses	0 École_Normale_Supérieure_Lettres_et_Sciences_Humaines W08 W09 WDB c t
# cole_normale_sup rieure_de_fontenay-saint-cloud	0 École_Normale_Supérieure_Lettres_et_Sciences_Humaines W08 W09 WDB c t
# cole_normale_sup rieure_de_lyon	0 École_Normale_Supérieure_de_Lyon W08 W09 WDB c t
# cole_normale_sup rieure_lettres_et_sciences_humaines	0 École_Normale_Supérieure_Lettres_et_Sciences_Humaines W08 W09 WDB c t
# cole_notre-dame	0 Notre_Dame_High_School D W08 W09 WDB c t
# cole_nouvelle_de_la_suisse_romande	0 Ecole_Nouvelle_de_la_Suisse_Romande W08 W09 WDB c t
# cole_pauline_johnson_elementary_school	0 École_Pauline_Johnson_Elementary_School KB W08 W09 WDB c t
# cole_polytechnique	0 École_Polytechnique KB W08 W09 WDB c t
# cole_polytechnique_de_l'universit _de_nantes	0 École_polytechnique_de_l'université_de_Nantes KB W08 W09 WDB c t
# cole_polytechnique_de_montr al	0 École_Polytechnique_de_Montréal KB W08 W09 WDB c t
# cole_polytechnique_massacre	0 École_Polytechnique_massacre W08 W09 WDB c t
# cole_pour_l'informatique_et_les_techniques_avanc es	0 École_Pour_l'Informatique_et_les_Techniques_Avancées KB W08 W09 WDB c t
# cole_publique_l'odyss e	0 École_publique_l'Odyssée KB W08 W09 WDB c t
# cole_publique_renaissance	0 École_Publique_Renaissance W08 W09 WDB c t
# cole_rose_des_vents	0 École_Rose_Des_Vents NR RWB W08 W09 WDB c t
# cole_sainte-anne	0 École_Sainte-Anne W08 W09 WDB c t
# cole_samuel-de-champlain	0 École_Samuel-de-Champlain W08 W09 WDB c t
# cole_secondaire_ tienne-br l 	0 École_secondaire_Étienne-Brûlé KB W08 W09 WDB c t
# cole_secondaire_catholique_b atrice-desloges	0 École_secondaire_catholique_Béatrice-Desloges KB W08 W09 WDB c t
# cole_secondaire_catholique_franco-cit 	0 École_secondaire_catholique_Franco-Cité KB W08 W09 WDB c t
# cole_secondaire_catholique_garneau	0 École_secondaire_catholique_Garneau KB W08 W09 WDB c t
# cole_secondaire_catholique_marie-rivier	0 École_secondaire_catholique_Marie-Rivier KB W08 W09 WDB c t
# cole_secondaire_catholique_th riault	0 École_secondaire_catholique_Thériault W08 W09 WDB c t
# cole_secondaire_conf d ration	0 École_secondaire_Confédération KB W08 W09 WDB c t
# cole_secondaire_de_par-en-bas	0 École_secondaire_de_Par-en-Bas KB W08 W09 WDB c t
# cole_secondaire_e.j._lajeunesse	0 École_secondaire_E.J._Lajeunesse c t
# cole_secondaire_e.j.lajeunesse	0 École_secondaire_E.J._Lajeunesse c t
# cole_secondaire_franco-cit 	0 École_secondaire_Franco-cité KB NR RWB W08 W09 WDB c t
# cole_secondaire_franco-jeunesse	0 École_secondaire_Franco-Jeunesse KB W08 W09 WDB c t
# cole_secondaire_gabriel-dumont	0 École_secondaire_Gabriel-Dumont KB W08 W09 WDB c t
# cole_secondaire_georges-p.-vanier	0 École_secondaire_Georges-P.-Vanier KB W08 W09 WDB c t
# cole_secondaire_georges-vanier	0 École_secondaire_Georges-Vanier KB W08 W09 WDB c t
# cole_secondaire_grande-rivi re	0 École_secondaire_Grande-Rivière KB W08 W09 WDB c t
# cole_secondaire_jeunesse_nord	0 École_Secondaire_Jeunesse_Nord W08 W09 WDB c t
# cole_secondaire_l'essor	0 École_secondaire_l'Essor KB W08 W09 WDB c t
# cole_secondaire_l'horizon	0 École_secondaire_l'Horizon KB W08 W09 WDB c t
# cole_secondaire_le_caron	0 École_secondaire_Le_Caron KB W08 W09 WDB c t
# cole_secondaire_n pisiguit	0 École_secondaire_Népisiguit KB NR RWB W08 W09 WDB c t
# cole_secondaire_p re-ren -de-galin e	0 École_secondaire_Père-René-de-Galinée KB W08 W09 WDB c t
# cole_secondaire_publique_de_la_salle	0 École_secondaire_publique_De_La_Salle KB W08 W09 WDB c t
# cole_secondaire_publique_deslauriers	0 École_secondaire_publique_Deslauriers KB W08 W09 WDB c t
# cole_secondaire_publique_louis-riel	0 École_secondaire_publique_Louis-Riel KB W08 W09 WDB c t
# cole_secondaire_publique_mille-iles	0 École_secondaire_publique_Mille-Iles KB W08 W09 WDB c t
# cole_sir_john_franklin_high_school	0 Sir_John_Franklin_High_School KB W08 W09 WDB c t
# cole_sp ciale_d'architecture	0 École_Spéciale_d'Architecture W08 W09 WDB c t
# cole_sp ciale_des_travaux_publics	0 École_spéciale_des_travaux_publics NR RWB W08 W09 WDB c t
# cole_sp ciale_militaire_de_saint-cyr	0 �cole_sp�ciale_militaire_de_Saint-Cyr c t
# cole_sup rieure_d' lectricit 	0 Supélec KB W08 W09 WDB c t
# cole_sup rieure_d' tudes_cin matographiques	0 École_supérieure_d'études_cinématographiques c t
# cole_sup rieure_d'informatique_et_applications_de_lorraine	0 École_Supérieure_d'Informatique_et_Applications_de_Lorraine KB W08 W09 WDB c t
# cole_sup rieure_d'ing nieurs_d'annecy	0 École_Supérieure_d'Ingénieurs_d'Annecy W08 W09 WDB c t
# cole_sup rieure_d'ing nieurs_en_ lectronique_et_ lectrotechnique	0 École_supérieure_d'ingénieurs_en_électronique_et_électrotechnique RWB W08 W09 WDB c t
# cole_sup rieure_d'ing nieurs_en_informatique_et_g nie_des_t l communications	0 École_supérieure_d'ingénieurs_en_informatique_et_génie_des_télécommunications W08 W09 WDB c t
# cole_sup rieure_d'ingenieur_en_ lectronique_et_ lectrotechnique	0 École_supérieure_d'ingénieurs_en_électronique_et_électrotechnique RWB W08 W09 WDB c t
# cole_sup rieure_de_chimie_et_physique_de_la_ville_de_paris	0 École_supérieure_de_physique_et_de_chimie_industrielles_de_la_ville_de_Paris W08 W09 WDB c t
# cole_sup rieure_de_chimie_physique_ lectronique_de_lyon	0 École_supérieure_de_chimie_physique_électronique_de_Lyon KB W08 W09 WDB c t
# cole_sup rieure_de_commerce_de_paris	0 ESCP-EAP_European_School_of_Management KB NR RDB RWB W08 W09 c t
# cole_sup rieure_de_commerce_de_pau	0 École_supérieure_de_commerce_de_Pau W08 W09 WDB c t
# cole_sup rieure_de_commerce_de_reims	0 École_supérieure_de_commerce_de_Reims W08 W09 WDB c t
# cole_sup rieure_de_commerce_de_rouen	0 École_supérieure_de_commerce_de_Rouen W08 W09 WDB c t
# cole_sup rieure_de_physique_et_de_chimie_industrielles_de_la_ville_de_paris	0 École_supérieure_de_physique_et_de_chimie_industrielles_de_la_ville_de_Paris W08 W09 WDB c t
# cole_sup rieure_des_beaux-arts_de_l'indochine	0 Hanoi_College_of_Fine_Arts W08 W09 WDB c t
# cole_sup rieure_des_sciences_ conomiques_et_commerciales	0 École_supérieure_des_sciences_économiques_et_commerciales KB W08 W09 WDB c t
# cole_sup rieure_des_sciences_et_technologies_de_l'ing nieur_de_nancy	0 École_Supérieure_des_Sciences_et_Technologies_de_l'Ingénieur_de_Nancy W08 W09 WDB c t
# cole_sup rieure_internationale_de_bruxelles	0 École_supérieure_internationale_de_Bruxelles W08 W09 WDB c t
# cole_technique_officielle	0 Ecole_Technique_Officielle NR RWB W08 W09 WDB c t
# cole_v t rinaire_de_maisons-alfort	0 École_Vétérinaire_de_Maisons-Alfort_(Paris_Métro) R09 R08 RDB c
# cole_v t rinaire_de_maisons-alfort_(paris_m tro)	0 École_Vétérinaire_de_Maisons-Alfort_(Paris_Métro) R09 R08 RDB t
# cole_victoria_school	0 Nutana,_Saskatoon KB W08 W09 WDB c t
# cole_william_ponty	0 École_normale_supérieure_William_Ponty W08 W09 WDB c t

# %% [markdown]
# This looks good! Let's collect all the possible entity mentions.

# %%
from collections import Counter
string_mentions = Counter()
# 30 minutes to load ;_;
dict_file_name = '/hg190/corpora/crosswikis-data.tar.bz2/dictionary.bz2'
with BZ2File(dict_file_name, 'r') as dict_file:
    line_generator = (l for l in dict_file if len(l.split('\t')) > 0)
    for i, l in enumerate(line_generator):
        string_mentions[l.split('\t')[0]] += 1
        if(i % 1000000 == 0):
            print('processed %d dict lines'%(i))
# Out:
# processed 0 dict lines
# processed 1000000 dict lines
# processed 2000000 dict lines
# processed 3000000 dict lines
# processed 4000000 dict lines
# processed 5000000 dict lines
# processed 6000000 dict lines
# processed 7000000 dict lines
# processed 8000000 dict lines
# processed 9000000 dict lines
# processed 10000000 dict lines
# processed 11000000 dict lines
# processed 12000000 dict lines
# processed 13000000 dict lines
# processed 14000000 dict lines
# processed 15000000 dict lines
# processed 16000000 dict lines
# processed 17000000 dict lines
# processed 18000000 dict lines
# processed 19000000 dict lines
# processed 20000000 dict lines
# processed 21000000 dict lines
# processed 22000000 dict lines
# processed 23000000 dict lines
# processed 24000000 dict lines
# processed 25000000 dict lines
# processed 26000000 dict lines
# processed 27000000 dict lines
# processed 28000000 dict lines
# processed 29000000 dict lines
# processed 30000000 dict lines
# processed 31000000 dict lines
# processed 32000000 dict lines
# processed 33000000 dict lines
# processed 34000000 dict lines
# processed 35000000 dict lines
# processed 36000000 dict lines
# processed 37000000 dict lines
# processed 38000000 dict lines
# processed 39000000 dict lines
# processed 40000000 dict lines
# processed 41000000 dict lines
# processed 42000000 dict lines
# processed 43000000 dict lines
# processed 44000000 dict lines
# processed 45000000 dict lines
# processed 46000000 dict lines
# processed 47000000 dict lines
# processed 48000000 dict lines
# processed 49000000 dict lines
# processed 50000000 dict lines
# processed 51000000 dict lines
# processed 52000000 dict lines
# processed 53000000 dict lines
# processed 54000000 dict lines
# processed 55000000 dict lines
# processed 56000000 dict lines
# processed 57000000 dict lines
# processed 58000000 dict lines
# processed 59000000 dict lines
# processed 60000000 dict lines
# processed 61000000 dict lines
# processed 62000000 dict lines
# processed 63000000 dict lines
# processed 64000000 dict lines
# processed 65000000 dict lines
# processed 66000000 dict lines
# processed 67000000 dict lines
# processed 68000000 dict lines
# processed 69000000 dict lines
# processed 70000000 dict lines
# processed 71000000 dict lines
# processed 72000000 dict lines
# processed 73000000 dict lines
# processed 74000000 dict lines
# processed 75000000 dict lines
# processed 76000000 dict lines
# processed 77000000 dict lines
# processed 78000000 dict lines
# processed 79000000 dict lines
# processed 80000000 dict lines
# processed 81000000 dict lines
# processed 82000000 dict lines
# processed 83000000 dict lines
# processed 84000000 dict lines
# processed 85000000 dict lines
# processed 86000000 dict lines
# processed 87000000 dict lines
# processed 88000000 dict lines
# processed 89000000 dict lines
# processed 90000000 dict lines
# processed 91000000 dict lines
# processed 92000000 dict lines
# processed 93000000 dict lines
# processed 94000000 dict lines
# processed 95000000 dict lines
# processed 96000000 dict lines
# processed 97000000 dict lines
# processed 98000000 dict lines
# processed 99000000 dict lines
# processed 100000000 dict lines
# processed 101000000 dict lines
# processed 102000000 dict lines
# processed 103000000 dict lines
# processed 104000000 dict lines
# processed 105000000 dict lines
# processed 106000000 dict lines
# processed 107000000 dict lines
# processed 108000000 dict lines
# processed 109000000 dict lines
# processed 110000000 dict lines
# processed 111000000 dict lines
# processed 112000000 dict lines
# processed 113000000 dict lines
# processed 114000000 dict lines
# processed 115000000 dict lines
# processed 116000000 dict lines
# processed 117000000 dict lines
# processed 118000000 dict lines
# processed 119000000 dict lines
# processed 120000000 dict lines
# processed 121000000 dict lines
# processed 122000000 dict lines
# processed 123000000 dict lines
# processed 124000000 dict lines
# processed 125000000 dict lines
# processed 126000000 dict lines
# processed 127000000 dict lines
# processed 128000000 dict lines
# processed 129000000 dict lines
# processed 130000000 dict lines
# processed 131000000 dict lines
# processed 132000000 dict lines
# processed 133000000 dict lines
# processed 134000000 dict lines
# processed 135000000 dict lines
# processed 136000000 dict lines
# processed 137000000 dict lines
# processed 138000000 dict lines
# processed 139000000 dict lines
# processed 140000000 dict lines
# processed 141000000 dict lines
# processed 142000000 dict lines
# processed 143000000 dict lines
# processed 144000000 dict lines
# processed 145000000 dict lines
# processed 146000000 dict lines
# processed 147000000 dict lines
# processed 148000000 dict lines
# processed 149000000 dict lines
# processed 150000000 dict lines
# processed 151000000 dict lines
# processed 152000000 dict lines
# processed 153000000 dict lines
# processed 154000000 dict lines
# processed 155000000 dict lines
# processed 156000000 dict lines
# processed 157000000 dict lines
# processed 158000000 dict lines
# processed 159000000 dict lines
# processed 160000000 dict lines
# processed 161000000 dict lines
# processed 162000000 dict lines
# processed 163000000 dict lines
# processed 164000000 dict lines
# processed 165000000 dict lines
# processed 166000000 dict lines
# processed 167000000 dict lines
# processed 168000000 dict lines
# processed 169000000 dict lines
# processed 170000000 dict lines
# processed 171000000 dict lines
# processed 172000000 dict lines
# processed 173000000 dict lines
# processed 174000000 dict lines
# processed 175000000 dict lines
# processed 176000000 dict lines
# processed 177000000 dict lines
# processed 178000000 dict lines
# processed 179000000 dict lines
# processed 180000000 dict lines
# processed 181000000 dict lines
# processed 182000000 dict lines
# processed 183000000 dict lines
# processed 184000000 dict lines
# processed 185000000 dict lines
# processed 186000000 dict lines
# processed 187000000 dict lines
# processed 188000000 dict lines
# processed 189000000 dict lines
# processed 190000000 dict lines
# processed 191000000 dict lines
# processed 192000000 dict lines
# processed 193000000 dict lines
# processed 194000000 dict lines
# processed 195000000 dict lines
# processed 196000000 dict lines
# processed 197000000 dict lines
# processed 198000000 dict lines
# processed 199000000 dict lines
# processed 200000000 dict lines
# processed 201000000 dict lines
# processed 202000000 dict lines
# processed 203000000 dict lines
# processed 204000000 dict lines
# processed 205000000 dict lines
# processed 206000000 dict lines
# processed 207000000 dict lines
# processed 208000000 dict lines
# processed 209000000 dict lines
# processed 210000000 dict lines
# processed 211000000 dict lines
# processed 212000000 dict lines
# processed 213000000 dict lines
# processed 214000000 dict lines
# processed 215000000 dict lines
# processed 216000000 dict lines
# processed 217000000 dict lines
# processed 218000000 dict lines
# processed 219000000 dict lines
# processed 220000000 dict lines
# processed 221000000 dict lines
# processed 222000000 dict lines
# processed 223000000 dict lines
# processed 224000000 dict lines
# processed 225000000 dict lines
# processed 226000000 dict lines
# processed 227000000 dict lines
# processed 228000000 dict lines
# processed 229000000 dict lines
# processed 230000000 dict lines
# processed 231000000 dict lines
# processed 232000000 dict lines
# processed 233000000 dict lines
# processed 234000000 dict lines
# processed 235000000 dict lines
# processed 236000000 dict lines
# processed 237000000 dict lines
# processed 238000000 dict lines
# processed 239000000 dict lines
# processed 240000000 dict lines
# processed 241000000 dict lines
# processed 242000000 dict lines
# processed 243000000 dict lines
# processed 244000000 dict lines
# processed 245000000 dict lines
# processed 246000000 dict lines
# processed 247000000 dict lines
# processed 248000000 dict lines
# processed 249000000 dict lines
# processed 250000000 dict lines
# processed 251000000 dict lines
# processed 252000000 dict lines
# processed 253000000 dict lines
# processed 254000000 dict lines
# processed 255000000 dict lines
# processed 256000000 dict lines
# processed 257000000 dict lines
# processed 258000000 dict lines
# processed 259000000 dict lines
# processed 260000000 dict lines
# processed 261000000 dict lines
# processed 262000000 dict lines
# processed 263000000 dict lines
# processed 264000000 dict lines
# processed 265000000 dict lines
# processed 266000000 dict lines
# processed 267000000 dict lines
# processed 268000000 dict lines
# processed 269000000 dict lines
# processed 270000000 dict lines
# processed 271000000 dict lines
# processed 272000000 dict lines
# processed 273000000 dict lines
# processed 274000000 dict lines
# processed 275000000 dict lines
# processed 276000000 dict lines
# processed 277000000 dict lines
# processed 278000000 dict lines
# processed 279000000 dict lines
# processed 280000000 dict lines
# processed 281000000 dict lines
# processed 282000000 dict lines
# processed 283000000 dict lines
# processed 284000000 dict lines
# processed 285000000 dict lines
# processed 286000000 dict lines
# processed 287000000 dict lines
# processed 288000000 dict lines
# processed 289000000 dict lines
# processed 290000000 dict lines
# processed 291000000 dict lines
# processed 292000000 dict lines
# processed 293000000 dict lines
# processed 294000000 dict lines
# processed 295000000 dict lines
# processed 296000000 dict lines
# processed 297000000 dict lines

# %%
print(len(string_mentions))
# Out:
# 175335446

# %%
top_k = 100
print('\n'.join(map(lambda x: '='.join([x[0], str(x[1])]), string_mentions.most_common(top_k))))
# Out:
# View original Wikipedia Article=3436372
# Wikipedia=3397331
# Wikipedia article=3092369
# View on Wikipedia=3016510
# original Wikipedia article=2913987
# View article on Wikipedia=2832128
# here=2502891
# wikipedia=2126682
# View article on Wikipedia »=2087905
# Source: Wikipedia=1824735
# en.wikipedia.org=1524449
# http://en, uh-hah-hah-hah.wikipedia.org=1484944
# View this article at Wikipedia=1449314
# Desktop View=1292791
# English=1232446
# Original document=1197531
# Read=1016083
# More from Wikipedia.org »=1013554
# view article=805097
# 위키피디아에서 보기=783987
# click here=678243
# ウィキペディアを見る=608600
# Français=604819
# Images from Wikipedia=597798
# Deutsch=580641
# Article on Wikipedia=553388
# Version Imprimable=494283
# Read Article on Wikipedia=479402
# More @Wikipedia=467159
# Wikipedia.org=457026
# Wikipedię=456533
# Read article at Wikipedia=449392
# wikipedia.de=438921
# contenido=438163
# Italiano=436802
# Quelle: Wikipedia=436036
# Español=434783
# source=425356
# Original Page=418075
# Source=413224
# Wikipedia Article=412082
# Nederlands=410842
# cette adresse=405820
# Article=402222
# Português=399399
# Polski=395587
# French Wikipedia=368287
# Full Article=365063
# Wikipedii, otwartej encyklopedii=364902
# View Live Article=359830
# Ask Encyclopedia=354865
# Русский=351802
# Auf Wikipedia anzeigen=347858
# German Wikipedia=346782
# Ver este articulo en Wikipedia=343406
# Read More=340106
# Please go here...=336241
# [1]=325201
# Consulter sur Wikipédia=321451
# [2]=320810
# See live article=299748
# Ver en la Wikipedia=286227
# 日本語=278986
# Open in a New Window=273283
# wikipedia.org=272667
# Italian Wikipedia=266071
# [3]=262781
# Spanish Wikipedia=261872
# [4]=261309
# Read More...=260111
# 参阅维基百科=256885
# read on=252516
# Portugese Wikipedia=249928
# Deutsh=249050
# more...=244519
# - Читать статью в википедии=240524
# Svenska=237641
# [6]=228806
# more at wikipedia »=228508
# [5]=226202
# Originaldokument=222344
# Посмотреть в Википедии=210603
# こちら=210056
# Wiki=209998
# [7]=205972
# Itawiano=204366
# WP=203089
# wikipediaの元記事をチェックする=202571
# Russian Wikipedia=201934
# View Website=200614
# En.wikipedia.org=200355
# Españow=196804
# [8]=196713
# Op Wikipedia bekijken=196691
# Japanese Wikipedia=194356
# Wikipedia page=191563
# more »=191361
# Català=188936
# página original=186807
# ( Go to wikipedia )=184225

# %% [markdown]
# How many of these mentions are location-specific?

# %%
# write to file first lol
import pandas as pd
from bz2 import BZ2File
from itertools import izip
string_mentions_series = pd.Series(string_mentions).sort_values(inplace=False, ascending=False)
string_mention_file_name = '/hg190/corpora/crosswikis-data.tar.bz2/string_mention_counts.bz2'
with BZ2File(string_mention_file_name, 'w') as string_mention_file:
    for i_str, i_count in izip(string_mentions_series.index, string_mentions_series):
        string_mention_file.write('%s,%d\n'%(i_str, i_count))

# %%
print(len(string_mentions_series))
# Out:
# 175335446

# %%
import pandas as pd
import re
string_mentions_series = pd.Series(string_mentions)
string_mentions_idx = string_mentions_series.index.tolist()
location_words = ['street', 'road', 'house', 'building', 'neighborhood', 'town', 'city', 'county']
location_matcher = re.compile('|'.join(location_words))
string_mentions_location = filter(lambda x: len(location_matcher.findall(x.lower())) > 0, string_mentions_idx)
string_mentions_location = string_mentions_series.loc[string_mentions_location].sort_values(inplace=False, ascending=False)
print(string_mentions_location.head(100))
# Out:
# City Info                                          5026
# County Page at Wikipedia                           2200
# city overview                                      2138
# city                                               1761
# town                                               1708
# rcity overview                                     1675
# Cities and towns                                   1629
# About This City                                     833
# City                                                797
# Town Info                                           770
# House                                               725
# Twin towns                                          675
# house                                               650
# New York City                                       622
# Cities/Towns/Townships                              574
# Buildings                                           574
# county                                              560
# 4 Cities and towns                                  559
# building                                            515
# County                                              499
# 3 Cities and towns                                  470
# neighborhood                                        436
# broadcaster                                         434
# road                                                417
# Building                                            410
# hometown                                            393
# {{Read more about %s on Wikipedia}$webcam['city     380
# new york city                                       377
# New_York_City                                       376
# new_york_city                                       372
#                                                    ...
# Roads                                               203
# new_york_city_subway                                201
# new york city subway                                201
# City Overview                                       201
# lighthouse                                          191
# Broadcasters                                        184
# Jackson Township                                    182
# Georgetown                                          178
# Broadcasting career                                 175
# my hometown                                         173
# small town                                          171
# Broadcast                                           166
# electricity                                         164
# railroad                                            162
# Camden County, New Jersey                           157
# camden_county,_new_jersey                           156
# Camden_County,_New_Jersey                           156
# camden county, new jersey                           156
# Crossroads                                          154
# Cumberland County, New Jersey                       149
# cumberland county, new jersey                       149
# Cumberland_County,_New_Jersey                       149
# cumberland_county,_new_jersey                       149
# Newtown                                             149
# White House                                         148
# City Council                                        146
# city hall                                           145
# 4.2 Federal, state and county representation        145
# U.S. House                                          140
# Malheur County, Oregon                              134
# Length: 100, dtype: int64

# %% [markdown]
# ## Build lexicon extractor
# Let's build a giant regex to extract potential entities from text, because that's what previous work seems to rely on.

# %%
print(string_mentions_series.index[-10:])
# Out:
# Index([u'󾮗デューク', u'􀂃 Consejo Escolar', u'�re', u'�verfurir', u'�verste',
#        u'�re', u'�', u'�r�n', u'�stra', u'�orramatur'],
#       dtype='object')

# %%
print('blah'.encode('utf-8'))
# Out:
# blah

# %%
# filter functions
def test_unicode(x):
    try:
        x.encode('utf-8')
        return True
    except Exception, e:
        return False
MAX_LENGTH=5
def test_length(x):
    x_tokens = x.split(' ')
    return len(x_tokens) <= MAX_LENGTH
noise_chars = ['\|', '\(', '\)', '\+', '\*', '?', '\[', '\]', '\^', '\$']
noise_finder = re.compile('[%s]'%(noise_chars))
def clean_mention(x):
    x_clean = x.strip()
    x_noise = noise_finder.findall(x_clean)
    for n in x_noise:
        x_clean.replace(n, '\%s'%(n))
    return x_clean
def test_regex(x):
    try:
        re.compile(x)
        return True
    except Exception, e:
        return False

# %%
# string_mentions = string_mentions_series.index.tolist()
print('start with %d string mentions'%(len(string_mentions)))
string_mentions_clean = map(clean_mention, string_mentions)
# unicode
string_mentions_filtered = filter(test_unicode, string_mentions_clean)
print('now have %d filtered string mentions after Unicode'%(len(string_mentions_filtered)))
# length
string_mentions_filtered = filter(test_length, string_mentions_filtered)
print('now have %d filtered string mentions after length'%(len(string_mentions_filtered)))
# regex
string_mentions_filtered = filter(test_regex, string_mentions_filtered)
# Out:
# start with 175335446 string mentions
# now have 143451251 filtered string mentions after Unicode
# now have 122270880 filtered string mentions after length
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-68c67c456b2e> in <module>()
#       9 print('now have %d filtered string mentions after length'%(len(string_mentions_filtered)))
#      10 # regex
# ---> 11 string_mentions_filtered = filter(test_regex, string_mentions_filtered)
#
# <ipython-input-74-3cc9c2bee270> in test_regex(x)
#      20 def test_regex(x):
#      21     try:
# ---> 22         re.compile(x)
#      23         return True
#      24     except Exception, e:
#
# /usr/local/lib/python2.7/re.pyc in compile(pattern, flags)
#     192 def compile(pattern, flags=0):
#     193     "Compile a regular expression pattern, returning a pattern object."
# --> 194     return _compile(pattern, flags)
#     195
#     196 def purge():
#
# /usr/local/lib/python2.7/re.pyc in _compile(*key)
#     247         raise TypeError, "first argument must be string or compiled pattern"
#     248     try:
# --> 249         p = sre_compile.compile(pattern, flags)
#     250     except error, v:
#     251         raise error, v # invalid expression
#
# /usr/local/lib/python2.7/sre_compile.pyc in compile(p, flags)
#     570     if isstring(p):
#     571         pattern = p
# --> 572         p = sre_parse.parse(p, flags)
#     573     else:
#     574         pattern = None
#
# /usr/local/lib/python2.7/sre_parse.pyc in parse(str, flags, pattern)
#     714     pattern.str = str
#     715
# --> 716     p = _parse_sub(source, pattern, 0)
#     717
#     718     tail = source.get()
#
# /usr/local/lib/python2.7/sre_parse.pyc in _parse_sub(source, state, nested)
#     322     sourcematch = source.match
#     323     while 1:
# --> 324         itemsappend(_parse(source, state))
#     325         if sourcematch("|"):
#     326             continue
#
# /usr/local/lib/python2.7/sre_parse.pyc in _parse(source, state)
#     427
#     428         if this and this[0] not in SPECIAL_CHARS:
# --> 429             subpatternappend((LITERAL, ord(this)))
#     430
#     431         elif this == "[":
#
# KeyboardInterrupt:

# %%
print('ending up with %d filtered mentions'%(len(string_mentions_filtered)))
# Out:
# ending up with 122270880 filtered mentions

# %% [markdown]
# Let's get a wide sample of these mentions.

# %%
chunks = 10
chunk_size = int(len(string_mentions_filtered) / chunks)
top_k = 20
for i in range(chunks):
    print(string_mentions_filtered[i*chunk_size:i*chunk_size+top_k])
# Out:
# ['', '', '_og_ eir', '_og_ eir_(s krates)', '_veistu_svari', 'elstan_i', 'ey', 'igo_arista', 'igo_cervantes-hueg n', 'igo_cuesta', 'igo_fern ndez', 'igo_fern ndez_de_velasco,_2nd_duke_of_fr as', 'igo_l pez', 'igo_l pez_de_mendoza', 'igo_l pez_de_mendoza_y_z  iga', 'igo_m ndez_de_vigo', 'igo_melchor_de_velasco,_7th_duke_of_fr as', 'igo_v lez_de_guevara,_8th_count_of_o ate', 'igo_v lez_de_guevara,_count_of_o ate', 'inn_j nsson']
# ['Annie Awards', 'Annie Awards (Wikipedia)', 'Annie Awards - Wikipedia', 'Annie Awards 1999', 'Annie Awards 2011', 'Annie Awards Wikipedia page.', 'Annie Awards,', 'Annie Awards:', 'Annie B Sweet', 'Annie B.', 'Annie B. Crockett-Stark', 'Annie B. Sweet', 'Annie Baker', 'Annie Balestra', 'Annie Banannie Promo', 'Annie Bandez', 'Annie Baobei', 'Annie Barabe', 'Annie Barker', 'Annie Barnes']
# ['Etymology and sentiment', 'Etymology and spelling', 'Etymology and spelling variations', 'Etymology and spellings', 'Etymology and spread', 'Etymology and state name', 'Etymology and study', 'Etymology and symbol', 'Etymology and symbolism', 'Etymology and symbols', 'Etymology and synonyms', 'Etymology and taxonomic history', 'Etymology and taxonomy', 'Etymology and terminology', 'Etymology and the ...', 'Etymology and toponymic history', 'Etymology and toponymy', 'Etymology and translation', 'Etymology and transliterations', 'Etymology and uncertain meanings']
# ['Lamia boulkacem', 'Lamia by wikipedia', 'Lamia city', 'Lamia da mitologia grega', 'Lamia de ley', 'Lamia el habz', 'Lamia en Wikipedia', 'Lamia esaadi', 'Lamia essaadi', 'Lamia f.c.', 'Lamia fc', 'Lamia from Wikipedia', 'Lamia in popular culture', 'Lamia indoor hall', 'Lamia indoor hall halkiopoulio', 'Lamia loveless', 'Lamia mitologia greziarreko pertsonaia da.', 'Lamia mohamed el-noshy', 'Lamia mythology', 'Lamia nights studios']
# ['R mering', 'R mering-l s-puttelange', 'R merstadt', 'R merstein', 'R merswil LU - Vikipedio', 'R mhild', 'R mi Gaillard Wikip dia', 'R mi Gaillard Wikipedia', 'R mi Pauriol Wikipedia', 'R mi bujold', 'R mi casty', 'R mi cilia', 'R mi fournier', 'R mi gaulin', 'R mi joseph isidore exelmans', 'R mi paul', 'R mi pauriol', 'R michael beanan', 'R michael dewine', 'R michael young']
# ['Vida Guerra', 'Vida Guerra (wikipedia)', 'Vida Guerra - Wikipedia', 'Vida Guerra @ WP', 'Vida Guerra @ Wikipedia', 'Vida Guerra On Wikipedia', 'Vida Guerra Wiki', 'Vida Guerra Wikip dia', 'Vida Guerra Wikip dia Wikipedia', 'Vida Guerra Wikipedia', 'Vida Guerra at Wikipedia', 'Vida Guerra bio', 'Vida Guerra in Fake Preacher', 'Vida Guerra on Wikipedia', 'Vida Guerra su Wikipedia', "Vida Guerra's", "Vida Guerra's Wiki page", 'Vida Guerra.', 'Vida GuerraWikipedia, the free encyclopedi', 'Vida GuerraWikipedia, the free encyclopedia']
# ['Woodpecker Records', 'Woodpecker Ridge', 'Woodpecker Signal', 'Woodpecker Song', 'Woodpecker Wanted', 'Woodpecker Wikipedia the free encyclopedia', 'Woodpecker auf Wikipedia', 'Woodpecker bay', 'Woodpecker cider', 'Woodpecker cigar', 'Woodpecker disambiguation', 'Woodpecker finch', 'Woodpecker from Mars', 'Woodpecker from Mars (cartoon)', 'Woodpecker from mars', 'Woodpecker from mars (cartoon)', 'Woodpecker in the Moon', 'Woodpecker in the Rough', 'Woodpecker in the moon', 'Woodpecker in the rough']
# ['fi:Suomenruotsalaiset', 'fi:Suomenusko', 'fi:Suomenvedenpohja', 'fi:Suomettuminen', 'fi:Suomi Eurovision laulukilpailussa', 'fi:Suomi Eurovision tanssikilpailussa', 'fi:Suomi talviolympialaisissa 2010', 'fi:Suomi-Ruotsi-maaottelu', 'fi:Suomi-neito', 'fi:Suomiart', 'fi:Suomirock', 'fi:Suomisaundi', 'fi:Suomuerakkokolibri', 'fi:Suomukipuajat', 'fi:Suomukirjotikka', 'fi:Suomukorppikotka', 'fi:Suomukyyhky', 'fi:Suomuluri', 'fi:Suomuotsakutojat', 'fi:Suomupaksujalka']
# ['http://eo.wikipedia.org/wiki/Berninapasejo', 'http://eo.wikipedia.org/wiki/Bernissart', 'http://eo.wikipedia.org/wiki/Bernitt', 'http://eo.wikipedia.org/wiki/Berno', 'http://eo.wikipedia.org/wiki/Berno_(distrikto)', 'http://eo.wikipedia.org/wiki/Bernol%C3%A1kovo', 'http://eo.wikipedia.org/wiki/Bernold', 'http://eo.wikipedia.org/wiki/Bernsbach', 'http://eo.wikipedia.org/wiki/Bernsdorf_(Oberlausitz)', 'http://eo.wikipedia.org/wiki/Bernstadt_auf_dem_Eigen', 'http://eo.wikipedia.org/wiki/Bernstorf', 'http://eo.wikipedia.org/wiki/Bernterode', 'http://eo.wikipedia.org/wiki/Bernterode_(apud_Heiligenstadt)', 'http://eo.wikipedia.org/wiki/Bero', 'http://eo.wikipedia.org/wiki/Berod_bei_Hachenburg', 'http://eo.wikipedia.org/wiki/Berod_bei_Wallmerod', 'http://eo.wikipedia.org/wiki/Berom%C3%BCnster', 'http://eo.wikipedia.org/wiki/Berounka', 'http://eo.wikipedia.org/wiki/Berra', 'http://eo.wikipedia.org/wiki/Berrioz%C3%A1bal_']
# ['no:Koeberg kjernekraftverk', 'no:Koeberliniaceae', 'no:Koeffisient', 'no:Koei', 'no:Koekelbergbasilikaen', 'no:Koelreuteria', 'no:Koen de Kort', 'no:Koerich', 'no:Koeru kommune', 'no:Koettlitzbreen', 'no:Koevolusjon', 'no:Kofaktor', 'no:Koffert', 'no:Koforidua', 'no:Kogalym', 'no:Kogan Creek kullkraftverk', 'no:Kogelbergfjellene', 'no:Kogge', 'no:Kognat (lingvistikk)', 'no:Kognisjon']

# %% [markdown]
# Are all these strings regex-friendly?

# %%
fail_ctr = 0
fail_cutoff = 50
for s in string_mentions_filtered:
    try:
        re.compile(s)
    except Exception, e:
        print('%s failed to compile'%(s))
        fail_ctr += 1
        if(fail_ctr >= fail_cutoff):
            break

# %%
lexicon_matcher = re.compile('|'.join(string_mentions_series.index.tolist()))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-65-70214d085757> in <module>()
# ----> 1 lexicon_matcher = re.compile('|'.join(string_mentions_series.index.tolist()))
#
# /usr/local/lib/python2.7/re.pyc in compile(pattern, flags)
#     192 def compile(pattern, flags=0):
#     193     "Compile a regular expression pattern, returning a pattern object."
# --> 194     return _compile(pattern, flags)
#     195
#     196 def purge():
#
# /usr/local/lib/python2.7/re.pyc in _compile(*key)
#     249         p = sre_compile.compile(pattern, flags)
#     250     except error, v:
# --> 251         raise error, v # invalid expression
#     252     if not bypass_cache:
#     253         if len(_cache) >= _MAXCACHE:
#
# error: unbalanced parenthesis

# %% [markdown]
# Looks like there is some mention string that still makes the regex fail.
#
# Let's try to recreate this failure iteratively.

# %%
full_regex = ''
for i, s in enumerate(string_mentions_series.index):
    if(i == 0):
        full_regex = s
    else:
        full_regex += '|%s'%(s)
    try:
        lexicon_matcher = re.compile(full_regex)
    except Exception, e:
        print('regex fails at string mention %s'%(s))
        break

# %%
print('processed %d mentions'%(i))
# Out:
# processed 2003 mentions

# %% [markdown]
# Update: this ran for an hour over 2000 mentions without any noticeable failure.
#
# I don't think we'll be able to use a regex.

# %% [markdown]
# Let's take a subset of this lexicon and use it for text matching.

# %% [markdown]
# ## Test entity extraction from text
# Can we just apply the lexicon to raw Twitter data and extract entities? This seems way too optimistic.

# %%
import gzip
test_data_file = '../../data/mined_tweets/HurricaneHarvey_ids_rehydrated_clean.txt.gz'
harvey_txt = [l.strip() for l in gzip.open(test_data_file, 'r')]
print('\n'.join(harvey_txt[:10]))
# Out:
# Somebody tell POTUS historic #HoustonFloods larger than him &amp; FEMA 🙏🏽
# @ChrisGroove1 @Bea_Bells We'll keep our paws crossed that that's what #Harvey  does! #nipclub
# Why does @realDonaldTrump make #HurricaneHarvey sound like the most successful hurricane in the history of hurricanes???
# "The EPA and TCEQ said Saturday that 161 drinking water systems have boil-water notices, and another 52 are shut do…
# #EarlyMorningEveningNews w: @DaRealMonieLove: Southeast Texas Slammed By #HurricaneHarvey; Over 5K Evacuees Head To…
# The Brookwoods Group team is not in the office. DM if you need to reach me. Or any of us, for that matter. #Houston #Harvey @brookwoodsgroup
# Its all about #hurricaneharvey #katrina #texasfloods on this ep on #souncloud #blackmedia #podsincolor #podernfamily
# “We are just returning to our houses and trying to figure out what to do next." #HurricaneHarvey #Harvey2017
# crimethinc: Our hearts go out to those in the path of #Harvey and all impacted by climate change. We count on gras…
# Here's How You Can Help With Hurricane Harvey Relief @Thrillist  #harvey #hurricaneharvey #texas #weather #fema #tx

# %% [markdown]
# Just use a sample of the tweets to stay sane.

# %%
sample_size = 10000
tweet_sample = pd.np.random.choice(harvey_txt, size=sample_size, replace=False)

# %%
lexicon_set = set(string_mentions_filtered)

# %% [markdown]
# Extract all 1,2,3-grams from data and compare overlap with lexicon.

# %%
print(tweet_sample[0])
# Out:
# #airbnb is offering help for #Harvey evacuees

# %%
from nltk.tokenize.casual import TweetTokenizer
from sklearn.feature_extraction.text import CountVectorizer
ngram_range = (1,3)
tokenizer = TweetTokenizer()
cv = CountVectorizer(min_df=1, ngram_range=ngram_range, tokenizer=tokenizer.tokenize)
tweet_dtm = cv.fit_transform(tweet_sample)
ivoc_lookup = {v : k for k,v in cv.vocabulary_.iteritems()}
top_k = 10
top_k_ngrams = [ivoc_lookup[x] for x in pd.np.array(tweet_dtm.sum(axis=0).argsort())[0][-top_k:]]
print(','.join(top_k_ngrams))
# Out:
# !,…,in,of,,,#hurricaneharvey,the,#harvey,to,.

# %%
# get overlap
tweet_lexicon_overlap = set(cv.vocabulary_.keys()) & set(lexicon_set)
print('got %d lexicon overlap'%(len(tweet_lexicon_overlap)))
# Out:
# got 24700 lexicon overlap

# %%
top_k = 10
print(','.join(sorted(tweet_lexicon_overlap)[:top_k]))
# Out:
# !,! &,! link,"," "," and "," by," here,#,# 1

# %% [markdown]
# This isn't great! How can these strings be part of the lexicon?

# %%
tweet_lexicon_overlap_sorted = sorted(tweet_lexicon_overlap, key=lambda x: len(x), reverse=True)
print(tweet_lexicon_overlap_sorted[:top_k])
# Out:
# [u'american watchmakers-clockmakers institute', u'conservatives and libertarians', u'federal disaster declaration', u'jefferson county courthouse', u'mental health professionals', u'strategic petroleum reserve', u'emergency operations center', u'emergency management agency', u'international space station', u'major disaster declaration']

# %% [markdown]
# These look less bad!
#
# Let's see which were the most common.

# %%
from itertools import izip
tweet_ngram_totals = pd.np.array(tweet_dtm.sum(axis=0))[0]
tweet_lexicon_counts = [tweet_ngram_totals[cv.vocabulary_[x]] for x in tweet_lexicon_overlap]
tweet_lexicon_sorted = sorted(izip(tweet_lexicon_overlap, tweet_lexicon_counts), key=lambda x: x[1], reverse=True)

# %%
print(tweet_lexicon_sorted[:10])
print(tweet_lexicon_sorted[100:110])
print(tweet_lexicon_sorted[500:510])
# Out:
# [(u'.', 6550), (u'to', 4289), (u'the', 3949), (u',', 3174), (u'of', 2513), (u'in', 2511), (u'!', 2303), (u'for', 2104), (u'a', 2068), (u'and', 1961)]
# [(u'there', 210), (u'this is', 208), (u'good', 207), (u'he', 206), (u'been', 206), (u'their', 206), (u'an', 205), (u'everyone', 204), (u'for the', 203), (u'some', 195)]
# [(u'continues', 44), (u'resources', 43), (u'americans', 43), (u'lot of', 43), (u'safety', 43), (u'oil', 43), (u'instead', 43), (u'we can', 43), (u'a lot of', 43), (u'info', 43)]

# %% [markdown]
# Seems like the entity strings exist mainly on the long tail of mentions.

# %% [markdown]
# TODO: kill stop words!!
